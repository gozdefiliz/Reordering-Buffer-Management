# %%
#creates inputs according to the written algorithm inside
#to have color size of 5 n needs to be 4
def inputs(n, p, size, text):
    import scipy.stats as sct
    import numpy as np
    import csv
    
    input_1= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_1)
    
    input_2= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_2)
    
    input_3= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_3)
    
    input_4= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_4)
    
    input_5= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_5)
    
    input_6= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_6)
    
    input_7= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_7)
    
    input_8= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_8)
    
    input_9= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_9)
    
    input_10= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_10)

    input_11= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_11)
    
    input_12= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_12)
    
    input_13= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_13)
    
    input_14= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_14)
    
    input_15= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_15)
    
    input_16= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_16)
    
    input_17= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_17)
    
    input_18= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_18)
    
    input_19= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_19)
    
    input_20= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_20)

    input_21= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_21)
    
    input_22= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_22)
    
    input_23= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_23)
    
    input_24= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_24)
    
    input_25= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_25)
    
    input_26= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_26)
    
    input_27= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_27)
    
    input_28= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_28)
    
    input_29= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_29)
    
    input_30= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_30)
    
    input_31= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_31)
    
    input_32= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_32)
    
    input_33= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_33)
    
    input_34= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_34)
    
    input_35= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_35)
    
    input_36= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_36)
    
    input_37= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_37)
    
    input_38= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_38)
    
    input_39= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_39)
    
    input_40= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_40)
    
    input_41= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_41)
    
    input_42= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_42)
    
    input_43= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_43)
    
    input_44= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_44)
    
    input_45= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_45)
    
    input_46= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_46)
    
    input_47= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_47)
    
    input_48= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_48)
    
    input_49= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_49)
    
    input_50= (np.random.binomial(n, p, size)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_50)

# %%
#n=color-1, p=probability, size
inputs(9, 0.5, 1000, 'Binom_c:10_p:0.3_s:1000.csv')

# %%
#n=color-1, p=probability, size
inputs(19, 0.5, 1000, 'Binom_c:20_p:0.3_s:1000.csv')

# %%
#n=color-1, p=probability, size
inputs(49, 0.5, 1000, 'Binom_c:50_p:0.3_s:1000.csv')

# %%
#n=color-1, p=probability, size
inputs(49, 0.5, 5000, 'Binom_c:50_p:0.3_s:5000.csv')

# %%
#n=color-1, p=probability, size
inputs(99, 0.5, 5000, 'Binom_c:100_p:0.3_s:5000.csv')

# %%
#n=color-1, p=probability, size
inputs(249, 0.5, 5000, 'Binom_c:250_p:0.3_s:5000.csv')

# %%
#n=color-1, p=probability, size
inputs(99, 0.5, 10000, 'Binom_c:100_p:0.3_s:10000.csv')

# %%
#n=color-1, p=probability, size
inputs(199, 0.5, 10000, 'Binom_c:200_p:0.3_s:10000.csv')

# %%
#n=color-1, p=probability, size
inputs(499, 0.5, 10000, 'Binom_c:500_p:0.3_s:10000.csv')
