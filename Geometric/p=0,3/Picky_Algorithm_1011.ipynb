# %%
#all necessary side algorithms

#finds the number of color changes in a given list
def nb_of_change(x):
    count=0
    i=0
    while i<(len(x)-1):
        if x[i]!=x[i+1]:
            count=count+1
            i=i+1
        else:
            i=i+1
    return count

#adds k items to the buffer from the input
def add(k, data,buffer):
    while k>0:
        buffer.append(data.pop(0))
        k=k-1
        
#finds and lists the unique items in a given list
def unique(list1): 
    unique_list = [] 
    for x in list1: 
        if x not in unique_list: 
            unique_list.append(x)
    return unique_list

#finds the most freq color in buffer
def most_freq(List): 
    return max(set(List), key = List.count)

#evicts c_act, appends output, removes from buffer, fills buffer till there is no c_act in buffer 
def evict(c_act, data, buffer,output_,k):
    while (c_act in buffer)==True:
        count=0
        buffer.remove(c_act)
        count=count+1
        for i in range(0,count):
            output_.append(c_act)
        while len(buffer)<k and len(data)!=0:
            add(k-len(buffer), data,buffer)
    return output_

#finds the second most frequent color in a given list
def second_most_freq(List): 
    from collections import Counter 
    occurence_count = Counter(List) 
    if len(occurence_count)>=2:
        return occurence_count.most_common(2)[1][0]
    else:
        return -1
    
#finds the occurence of a given color in a given list      
def occurence(List, x): 
    count=0
    for i in range (0, len(List)):
        if List[i]==x:
            count=count+1
    return count


#finds the least freq color in buffer
def least_freq(List): 
    return min(set(List), key = List.count)

# %%
def picky(k,input_):
    import numpy as np
    import math
    buffer=input_[0:0]
    output_=input_[0:0]
    data=input_[:]
    nb_of_delays=0
    c_act=-1
    result=[0]*2
    

    while len(data)!=0:
        ex=0
        while len(buffer)<k and len(data)!=0:

            add(min((k-len(buffer)), len(data)), data, buffer)
            

            if (c_act!=-1 and (c_act in buffer)==True):
                while (c_act in buffer)==True:
                    buffer.remove(c_act)
                    output_.append(c_act)

                    add(min(1,len(data)), data, buffer)
            else:
                continue
            if len(buffer)==0:
                break
                
            #nb of colors in the buffer is sigma
            sigma=len(unique(buffer))
            #most frequent color in the buffer
            o_1=most_freq(buffer)
            size_of_o1=occurence(buffer,o_1)
        

            while (size_of_o1 >= 2 * (math.ceil(len(buffer)/sigma))) and ex<len(data):

                delayed=least_freq(buffer)
                while (delayed in buffer)==True:
                    nb_of_delays=nb_of_delays+1
                    ex=ex+1
                    buffer.remove(delayed)
                    data.append(delayed)
                if len(buffer)==0:
                    break
                    
                    

        if len(buffer)!=0:
            c_act=most_freq(buffer)
            while(c_act in buffer)==True:
                buffer.remove(c_act)
                output_.append(c_act)
            

    while len(buffer)!=0:
        c_act=most_freq(buffer)
        while (c_act in buffer)==True:
            buffer.remove(c_act)
            output_.append(c_act)
            
    result[0]=float(nb_of_change(output_)/nb_of_change(input_))
    result[1]=float(nb_of_delays/len(input_))
    print(result)

# %%
#reads data from given text and makes test of delay alg.
def picky_test(k,text):
    import pandas as pd
    data=pd.read_csv(text, header=None)

    input_1=(data.iloc[0]).tolist()
    input_2=(data.iloc[1]).tolist()
    input_3=(data.iloc[2]).tolist()
    input_4=(data.iloc[3]).tolist()
    input_5=(data.iloc[4]).tolist()
    input_6=(data.iloc[5]).tolist()
    input_7=(data.iloc[6]).tolist()
    input_8=(data.iloc[7]).tolist()
    input_9=(data.iloc[8]).tolist()
    input_10=(data.iloc[9]).tolist()

    input_11=(data.iloc[10]).tolist()
    input_12=(data.iloc[11]).tolist()
    input_13=(data.iloc[12]).tolist()
    input_14=(data.iloc[13]).tolist()
    input_15=(data.iloc[14]).tolist()
    input_16=(data.iloc[15]).tolist()
    input_17=(data.iloc[16]).tolist()
    input_18=(data.iloc[17]).tolist()
    input_19=(data.iloc[18]).tolist()
    input_20=(data.iloc[19]).tolist()

    input_21=(data.iloc[20]).tolist()
    input_22=(data.iloc[21]).tolist()
    input_23=(data.iloc[22]).tolist()
    input_24=(data.iloc[23]).tolist()
    input_25=(data.iloc[24]).tolist()
    input_26=(data.iloc[25]).tolist()
    input_27=(data.iloc[26]).tolist()
    input_28=(data.iloc[27]).tolist()
    input_29=(data.iloc[28]).tolist()
    input_30=(data.iloc[29]).tolist()

    input_31=(data.iloc[30]).tolist()
    input_32=(data.iloc[31]).tolist()
    input_33=(data.iloc[32]).tolist()
    input_34=(data.iloc[33]).tolist()
    input_35=(data.iloc[34]).tolist()
    input_36=(data.iloc[35]).tolist()
    input_37=(data.iloc[36]).tolist()
    input_38=(data.iloc[37]).tolist()
    input_39=(data.iloc[38]).tolist()
    input_40=(data.iloc[39]).tolist()

    input_41=(data.iloc[40]).tolist()
    input_42=(data.iloc[41]).tolist()
    input_43=(data.iloc[42]).tolist()
    input_44=(data.iloc[43]).tolist()
    input_45=(data.iloc[44]).tolist()
    input_46=(data.iloc[45]).tolist()
    input_47=(data.iloc[46]).tolist()
    input_48=(data.iloc[47]).tolist()
    input_49=(data.iloc[48]).tolist()
    input_50=(data.iloc[49]).tolist()

    picky(k,input_1)
    picky(k,input_2)
    picky(k,input_3)
    picky(k,input_4)
    picky(k,input_5)
    picky(k,input_6)
    picky(k,input_7)
    picky(k,input_8)
    picky(k,input_9)
    picky(k,input_10)

    picky(k,input_11)
    picky(k,input_12)
    picky(k,input_13)
    picky(k,input_14)
    picky(k,input_15)
    picky(k,input_16)
    picky(k,input_17)
    picky(k,input_18)
    picky(k,input_19)
    picky(k,input_20)

    picky(k,input_21)
    picky(k,input_22)
    picky(k,input_23)
    picky(k,input_24)
    picky(k,input_25)
    picky(k,input_26)
    picky(k,input_27)
    picky(k,input_28)
    picky(k,input_29)
    picky(k,input_30)

    picky(k,input_31)
    picky(k,input_32)
    picky(k,input_33)
    picky(k,input_34)
    picky(k,input_35)
    picky(k,input_36)
    picky(k,input_37)
    picky(k,input_38)
    picky(k,input_39)
    picky(k,input_40)

    picky(k,input_41)
    picky(k,input_42)
    picky(k,input_43)
    picky(k,input_44)
    picky(k,input_45)
    picky(k,input_46)
    picky(k,input_47)
    picky(k,input_48)
    picky(k,input_49)
    picky(k,input_50)

# %%
picky_test(10,'Geom_c:10_p:0.3_s:1000.csv')
# Out:
# [0.3456334563345633, 0.26]
# [0.345475910693302, 0.13]
# [0.3282636248415716, 0.2]
# [0.34292565947242204, 0.2]
# [0.33875, 0.15]
# [0.34285714285714286, 0.12]
# [0.33623910336239105, 0.16]
# [0.3602941176470588, 0.18]
# [0.34903381642512077, 0.16]
# [0.3317013463892289, 0.21]
# [0.370595382746051, 0.13]
# [0.337468982630273, 0.18]
# [0.3652173913043478, 0.08]
# [0.35767326732673266, 0.15]
# [0.303970223325062, 0.36]
# [0.35, 0.21]
# [0.3297232250300842, 0.23]
# [0.3589420654911839, 0.14]
# [0.3308641975308642, 0.17]
# [0.3422391857506361, 0.23]
# [0.3480392156862745, 0.18]
# [0.35037406483790523, 0.16]
# [0.32802937576499386, 0.25]
# [0.3374384236453202, 0.18]
# [0.3559748427672956, 0.14]
# [0.3313032886723508, 0.22]
# [0.3818849449204406, 0.11]
# [0.3586550435865504, 0.18]
# [0.3822784810126582, 0.09]
# [0.35294117647058826, 0.14]
# [0.322180916976456, 0.25]
# [0.3888888888888889, 0.06]
# [0.32112332112332115, 0.22]
# [0.3565217391304348, 0.15]
# [0.3484276729559748, 0.18]
# ...

# %%
picky_test(20,'Geom_c:10_p:0.3_s:1000.csv')
# Out:
# [0.1008610086100861, 1.2]
# [0.15041128084606345, 0.72]
# [0.12927756653992395, 0.92]
# [0.14388489208633093, 0.88]
# [0.12625, 0.9]
# [0.15595238095238095, 0.6]
# [0.14694894146948942, 0.68]
# [0.15808823529411764, 0.58]
# [0.12560386473429952, 0.96]
# [0.13953488372093023, 0.76]
# [0.1433778857837181, 0.7]
# [0.1674937965260546, 0.52]
# [0.12298136645962733, 0.92]
# [0.14727722772277227, 0.8]
# [0.13895781637717122, 0.84]
# [0.14102564102564102, 0.94]
# [0.1588447653429603, 0.54]
# [0.15113350125944586, 0.62]
# [0.1506172839506173, 0.7]
# [0.138676844783715, 0.82]
# [0.15808823529411764, 0.56]
# [0.12718204488778054, 0.86]
# [0.12362301101591187, 0.88]
# [0.12561576354679804, 1.1]
# [0.11320754716981132, 1.02]
# [0.1425091352009744, 0.7]
# [0.14320685434516525, 0.76]
# [0.14570361145703611, 0.58]
# [0.15443037974683543, 0.54]
# [0.12622549019607843, 0.9]
# [0.1288723667905824, 1.08]
# [0.1308641975308642, 0.8]
# [0.14163614163614163, 0.72]
# [0.11180124223602485, 1.04]
# ...

# %%
picky_test(50,'Geom_c:10_p:0.3_s:1000.csv')
# Out:
# [0.028290282902829027, 2.0]
# [0.06345475910693302, 1.2]
# [0.032953105196451206, 1.35]
# [0.05155875299760192, 0.95]
# [0.0425, 1.4]
# [0.04404761904761905, 1.3]
# [0.039850560398505604, 1.2]
# [0.04534313725490196, 1.15]
# [0.04710144927536232, 1.2]
# [0.03671970624235006, 1.55]
# [0.054678007290400975, 1.05]
# [0.038461538461538464, 1.6]
# [0.037267080745341616, 1.35]
# [0.04455445544554455, 1.5]
# [0.038461538461538464, 1.35]
# [0.038461538461538464, 1.35]
# [0.061371841155234655, 0.65]
# [0.06297229219143577, 0.95]
# [0.04567901234567901, 1.3]
# [0.062340966921119595, 0.75]
# [0.058823529411764705, 0.65]
# [0.05112219451371571, 1.25]
# [0.03916768665850673, 1.65]
# [0.03940886699507389, 1.85]
# [0.03773584905660377, 1.3]
# [0.04628501827040195, 1.3]
# [0.0416156670746634, 1.2]
# [0.0361145703611457, 1.7]
# [0.04050632911392405, 1.5]
# [0.0428921568627451, 1.2]
# [0.03841387856257745, 1.4]
# [0.05555555555555555, 1.05]
# [0.05616605616605617, 1.05]
# [0.04720496894409938, 1.05]
# ...

# %%
picky_test(10,'Geom_c:20_p:0.3_s:1000.csv')
# Out:
# [0.6698564593301436, 0.05]
# [0.49463647199046484, 0.0]
# [0.522867737948084, 0.07]
# [0.537621359223301, 0.0]
# [0.4518147684605757, 0.16]
# [0.414004914004914, 0.12]
# [0.5326876513317191, 0.13]
# [0.5867469879518072, 0.0]
# [0.4338942307692308, 0.03]
# [0.5758323057953144, 0.03]
# [0.46707317073170734, 0.06]
# [0.4567901234567901, 0.03]
# [0.45554202192448234, 0.05]
# [0.38287752675386444, 0.14]
# [0.5222088835534213, 0.05]
# [0.6855036855036855, 0.0]
# [0.6043956043956044, 0.03]
# [0.526378896882494, 0.01]
# [0.3877038895859473, 0.16]
# [0.5491905354919053, 0.07]
# [0.49443757725587145, 0.14]
# [0.4797047970479705, 0.03]
# [0.4189675870348139, 0.15]
# [0.4962962962962963, 0.0]
# [0.5471923536439666, 0.06]
# [0.4201474201474201, 0.15]
# [0.4190012180267966, 0.12]
# [0.486810551558753, 0.1]
# [0.4577114427860697, 0.08]
# [0.5145985401459854, 0.06]
# [0.6732429099876696, 0.01]
# [0.43050430504305043, 0.08]
# [0.7079856972586412, 0.02]
# [0.453125, 0.04]
# [0.6152927120669056, 0.0]
# ...

# %%
picky_test(20,'Geom_c:20_p:0.3_s:1000.csv')
# Out:
# [0.1423444976076555, 1.1]
# [0.13706793802145412, 1.16]
# [0.17552533992583436, 0.86]
# [0.14199029126213591, 1.04]
# [0.13141426783479349, 1.24]
# [0.15233415233415235, 0.98]
# [0.16343825665859565, 0.96]
# [0.1650602409638554, 0.9]
# [0.1346153846153846, 1.32]
# [0.1381011097410604, 1.18]
# [0.13902439024390245, 1.14]
# [0.13209876543209875, 0.96]
# [0.16930572472594396, 0.88]
# [0.15576694411414982, 0.84]
# [0.12484993997599039, 1.34]
# [0.14864864864864866, 1.0]
# [0.14285714285714285, 1.08]
# [0.1223021582733813, 1.34]
# [0.15809284818067754, 0.74]
# [0.136986301369863, 1.06]
# [0.15451174289245984, 1.12]
# [0.13776137761377613, 0.98]
# [0.15126050420168066, 0.94]
# [0.17160493827160495, 0.92]
# [0.12066905615292713, 1.32]
# [0.14127764127764128, 1.04]
# [0.14494518879415347, 1.12]
# [0.1486810551558753, 0.98]
# [0.1927860696517413, 0.62]
# [0.15085158150851583, 0.8]
# [0.1442663378545006, 1.14]
# [0.13407134071340712, 1.2]
# [0.12514898688915377, 1.44]
# ...

# %%
picky_test(50,'Geom_c:20_p:0.3_s:1000.csv')
# Out:
# [0.03708133971291866, 2.05]
# [0.026221692491060787, 2.05]
# [0.049443757725587144, 1.65]
# [0.032766990291262135, 1.95]
# [0.030037546933667083, 2.1]
# [0.0343980343980344, 1.7]
# [0.029055690072639227, 1.9]
# [0.03253012048192771, 1.7]
# [0.042067307692307696, 1.8]
# [0.025893958076448828, 1.95]
# [0.03048780487804878, 2.35]
# [0.04938271604938271, 1.75]
# [0.04141291108404385, 2.05]
# [0.04637336504161712, 1.65]
# [0.03841536614645858, 1.95]
# [0.033169533169533166, 2.05]
# [0.05372405372405373, 1.3]
# [0.0407673860911271, 1.8]
# [0.04015056461731493, 1.7]
# [0.031133250311332503, 2.0]
# [0.02595797280593325, 1.8]
# [0.03936039360393604, 1.75]
# [0.030012004801920768, 2.25]
# [0.030864197530864196, 2.05]
# [0.03106332138590203, 2.7]
# [0.029484029484029485, 2.15]
# [0.028014616321559074, 2.5]
# [0.06235011990407674, 1.2]
# [0.03482587064676617, 1.95]
# [0.04257907542579075, 1.65]
# [0.04192355117139334, 1.95]
# [0.03690036900369004, 2.0]
# [0.03814064362336114, 2.05]
# ...

# %%
picky_test(10,'Geom_c:50_p:0.3_s:1000.csv')
# Out:
# [0.5066991473812423, 0.0]
# [0.4108241082410824, 0.17]
# [0.6287787182587666, 0.0]
# [0.5214797136038186, 0.01]
# [0.4916467780429594, 0.1]
# [0.4929078014184397, 0.09]
# [0.5495716034271726, 0.07]
# [0.6, 0.0]
# [0.549645390070922, 0.01]
# [0.5190184049079755, 0.06]
# [0.553012048192771, 0.04]
# [0.4956949569495695, 0.04]
# [0.40572792362768495, 0.1]
# [0.45161290322580644, 0.2]
# [0.41912632821723733, 0.13]
# [0.5790784557907845, 0.02]
# [0.5447852760736196, 0.02]
# [0.48383233532934133, 0.03]
# [0.5030978934324659, 0.05]
# [0.46200980392156865, 0.08]
# [0.5586124401913876, 0.04]
# [0.5150784077201448, 0.04]
# [0.5056039850560399, 0.04]
# [0.6699029126213593, 0.06]
# [0.3647342995169082, 0.19]
# [0.6447688564476886, 0.04]
# [0.7254437869822485, 0.0]
# [0.44923857868020306, 0.17]
# [0.8527315914489311, 0.0]
# [0.4550898203592814, 0.03]
# [0.5441527446300716, 0.04]
# [0.5826193390452876, 0.0]
# [0.46943765281173594, 0.05]
# [0.7399527186761229, 0.0]
# [0.44103194103194104, 0.03]
# ...

# %%
picky_test(20,'Geom_c:50_p:0.3_s:1000.csv')
# Out:
# [0.1753958587088916, 0.66]
# [0.15498154981549817, 0.92]
# [0.14389359129383314, 1.12]
# [0.16706443914081145, 0.98]
# [0.18615751789976134, 0.66]
# [0.1288416075650118, 1.26]
# [0.15299877600979192, 0.7]
# [0.1382716049382716, 0.98]
# [0.13829787234042554, 1.0]
# [0.1460122699386503, 1.1]
# [0.14337349397590363, 1.12]
# [0.14391143911439114, 1.14]
# [0.1658711217183771, 0.84]
# [0.15651135005973715, 1.0]
# [0.12160566706021252, 1.34]
# [0.10460772104607721, 1.34]
# [0.1423312883435583, 1.02]
# [0.15449101796407186, 0.88]
# [0.15613382899628253, 1.0]
# [0.1568627450980392, 0.92]
# [0.145933014354067, 1.14]
# [0.13872135102533173, 1.42]
# [0.1569115815691158, 0.84]
# [0.11771844660194175, 1.22]
# [0.10386473429951691, 1.66]
# [0.1386861313868613, 1.28]
# [0.13846153846153847, 1.16]
# [0.12563451776649745, 1.28]
# [0.167458432304038, 0.98]
# [0.14011976047904193, 1.04]
# [0.13842482100238662, 1.0]
# [0.12851897184822522, 1.14]
# [0.1198044009779951, 1.22]
# [0.14893617021276595, 1.32]
# ...

# %%
picky_test(50,'Geom_c:50_p:0.3_s:1000.csv')
# Out:
# [0.04628501827040195, 1.4]
# [0.03567035670356704, 1.75]
# [0.044740024183796856, 1.75]
# [0.04295942720763723, 1.75]
# [0.03341288782816229, 2.15]
# [0.03546099290780142, 1.95]
# [0.02447980416156671, 2.35]
# [0.03209876543209877, 1.8]
# [0.031914893617021274, 2.5]
# [0.04171779141104295, 2.15]
# [0.03734939759036145, 1.8]
# [0.03198031980319803, 2.25]
# [0.0441527446300716, 1.8]
# [0.037037037037037035, 1.85]
# [0.043683589138134596, 1.8]
# [0.0361145703611457, 1.9]
# [0.04785276073619632, 1.55]
# [0.026347305389221556, 2.1]
# [0.05328376703841388, 1.75]
# [0.04044117647058824, 1.8]
# [0.05382775119617225, 1.8]
# [0.038600723763570564, 2.05]
# [0.026151930261519303, 1.9]
# [0.03519417475728155, 1.85]
# [0.033816425120772944, 1.65]
# [0.046228710462287104, 1.6]
# [0.0378698224852071, 2.25]
# [0.03934010152284264, 1.5]
# [0.0498812351543943, 1.95]
# [0.031137724550898204, 1.9]
# [0.028639618138424822, 2.3]
# [0.04773561811505508, 1.5]
# [0.04156479217603912, 1.7]
# ...

# %%
picky_test(50,'Geom_c:50_p:0.3_s:5000.csv')
# Out:
# [0.0241196333815726, 2.13]
# [0.026296387318751537, 2.05]
# [0.022655298416565165, 2.2]
# [0.021062943913788882, 2.2]
# [0.023687423687423687, 2.3]
# [0.0267944936086529, 2.16]
# [0.03293775732622911, 1.95]
# [0.020863309352517987, 2.59]
# [0.022010271460014674, 2.39]
# [0.02761485826001955, 2.09]
# [0.021813725490196077, 2.19]
# [0.02216867469879518, 2.11]
# [0.02178649237472767, 2.46]
# [0.017813567593948268, 2.98]
# [0.022798932815910746, 2.17]
# [0.023097495745198152, 2.36]
# [0.027323737496950475, 2.42]
# [0.025374577090381826, 2.38]
# [0.020481927710843374, 2.25]
# [0.024897268552090887, 2.09]
# [0.02251270878721859, 2.36]
# [0.01617966674716252, 2.27]
# [0.03702807357212004, 2.02]
# [0.030053320407174018, 2.18]
# [0.01792201501574231, 2.31]
# [0.01682287911559721, 2.3]
# [0.025126842232423292, 2.32]
# [0.024049079754601226, 2.35]
# [0.024969400244798042, 2.17]
# [0.016164584864070537, 2.19]
# [0.020187454938716654, 2.38]
# [0.01521371649360058, 2.87]
# ...

# %%
picky_test(100,'Geom_c:50_p:0.3_s:5000.csv')
# Out:
# [0.009406657018813314, 2.28]
# [0.00860162202015237, 2.36]
# [0.0097442143727162, 2.18]
# [0.008327210384521186, 2.24]
# [0.009523809523809525, 2.7]
# [0.009341199606686333, 2.44]
# [0.014289174134172923, 2.12]
# [0.009592326139088728, 2.36]
# [0.011494252873563218, 2.18]
# [0.011485826001955034, 2.18]
# [0.009558823529411765, 2.12]
# [0.009156626506024097, 2.26]
# [0.006778019849915275, 2.18]
# [0.010980966325036604, 2.04]
# [0.008974048023284017, 2.1]
# [0.014101628981278872, 2.06]
# [0.012198097096852892, 2.18]
# [0.011841469308844853, 2.48]
# [0.009397590361445784, 2.26]
# [0.009427121102248005, 2.44]
# [0.010167029774872912, 2.24]
# [0.010142477662400387, 2.18]
# [0.008228460793804453, 2.3]
# [0.011148812409112942, 2.14]
# [0.007992249939452653, 2.38]
# [0.008171112713290074, 2.56]
# [0.0147378593863252, 2.12]
# [0.011288343558282208, 2.32]
# [0.008567931456548347, 2.18]
# [0.011021307861866276, 2.04]
# [0.008411439557798606, 2.34]
# [0.0070031393383240765, 2.18]
# ...

# %%
picky_test(250,'Geom_c:50_p:0.3_s:5000.csv')
# Out:
# [0.006753497346840328, 2.0]
# [0.007618579503563529, 1.8]
# [0.009013398294762484, 1.7]
# [0.007102620622091599, 1.9]
# [0.00757020757020757, 1.9]
# [0.005653883972468043, 2.0]
# [0.007507871155243401, 1.9]
# [0.00671462829736211, 2.05]
# [0.010516018586451455, 1.6]
# [0.008064516129032258, 2.25]
# [0.009068627450980393, 1.9]
# [0.006746987951807229, 2.4]
# [0.007988380537400145, 1.95]
# [0.00634455832113226, 2.2]
# [0.007033713315546932, 2.05]
# [0.007780209093119377, 2.0]
# [0.008050744083922909, 2.15]
# [0.007491541807636539, 1.85]
# [0.006746987951807229, 1.95]
# [0.007009910563210055, 1.8]
# [0.006535947712418301, 2.3]
# [0.0070031393383240765, 2.5]
# [0.007502420135527589, 2.0]
# [0.007755695588948134, 1.85]
# [0.00581254541051102, 2.25]
# [0.0091324200913242, 2.0]
# [0.008214544575984537, 1.9]
# [0.007361963190184049, 2.2]
# [0.006609547123623011, 1.8]
# [0.0073475385745775165, 1.95]
# [0.00600817111271329, 2.0]
# [0.006037189084762135, 2.05]
# [0.006236507555768769, 2.5]
# ...

# %%
picky_test(50,'Geom_c:100_p:0.3_s:5000.csv')
# Out:
# [0.025597269624573378, 2.32]
# [0.029102470041574957, 2.36]
# [0.020334059549745823, 2.4]
# [0.023367863165502288, 2.51]
# [0.025220080894599095, 2.15]
# [0.02183825293976482, 2.31]
# [0.022578295702840496, 2.33]
# [0.02520185955468559, 2.12]
# [0.020192307692307693, 2.31]
# [0.0185586888406845, 2.41]
# [0.020292006928977976, 2.19]
# [0.018477457501847747, 2.45]
# [0.022254475084663765, 2.46]
# [0.012103606874848705, 2.38]
# [0.022238514173998046, 2.12]
# [0.028304208712773813, 2.49]
# [0.020289855072463767, 2.21]
# [0.020318237454100368, 2.48]
# [0.02914960250542038, 2.12]
# [0.023503216229589313, 2.32]
# [0.02057115198451113, 2.18]
# [0.023330058939096267, 2.42]
# [0.025138989605994682, 2.25]
# [0.02058319039451115, 2.55]
# [0.01814662472780063, 2.22]
# [0.024679409629808857, 2.25]
# [0.021728515625, 2.31]
# [0.02061105722599418, 2.59]
# [0.018070818070818073, 2.38]
# [0.021812893843916627, 2.31]
# [0.028175856205975226, 2.38]
# [0.017391304347826087, 2.76]
# ...

# %%
picky_test(100,'Geom_c:100_p:0.3_s:5000.csv')
# Out:
# [0.011945392491467578, 2.1]
# [0.010760577158229395, 2.4]
# [0.009198741224885015, 2.22]
# [0.008672609009877139, 2.22]
# [0.011896264572924102, 2.0]
# [0.014398848092152628, 2.06]
# [0.008011653313911144, 2.22]
# [0.011255199412772204, 2.0]
# [0.013221153846153846, 2.16]
# [0.007712701855868884, 2.12]
# [0.012620638455827766, 2.3]
# [0.012564671101256468, 2.16]
# [0.00991775520077407, 2.16]
# [0.007020091987412249, 2.56]
# [0.010997067448680353, 2.2]
# [0.007383706620723603, 2.54]
# [0.009178743961352657, 2.34]
# [0.010281517747858017, 1.98]
# [0.011804384485666104, 2.22]
# [0.008906481939633844, 2.3]
# [0.011616650532429816, 2.28]
# [0.009577603143418467, 2.34]
# [0.007493352671017646, 2.36]
# [0.0117618230825778, 2.26]
# [0.007500604887490926, 2.24]
# [0.009194289862085652, 2.4]
# [0.00732421875, 2.3]
# [0.007759456838021339, 2.32]
# [0.012454212454212455, 2.56]
# [0.008482792050412021, 2.48]
# [0.0111731843575419, 2.44]
# [0.008695652173913044, 2.38]
# ...

# %%
picky_test(250,'Geom_c:100_p:0.3_s:5000.csv')
# Out:
# [0.007313505607020965, 2.45]
# [0.007825874296894107, 2.3]
# [0.006778019849915275, 1.9]
# [0.006986268369067694, 2.1]
# [0.007851534618129907, 2.05]
# [0.01079913606911447, 1.45]
# [0.006312211701869385, 1.95]
# [0.008074382187423538, 1.95]
# [0.0069711538461538465, 1.95]
# [0.0069896360568811764, 2.0]
# [0.008413758970551844, 2.2]
# [0.007637349100763735, 1.9]
# [0.008708272859216255, 1.85]
# [0.007746308399903171, 2.0]
# [0.00635386119257087, 1.95]
# [0.006399212404627123, 2.3]
# [0.006521739130434782, 2.0]
# [0.006609547123623011, 2.3]
# [0.006263550951577933, 2.0]
# [0.008659079663532904, 1.8]
# [0.006534365924491772, 2.2]
# [0.007612966601178782, 2.0]
# [0.00676818950930626, 2.2]
# [0.007596177407498162, 2.1]
# [0.0077425598838616015, 1.95]
# [0.007984514880232278, 1.9]
# [0.0078125, 1.9]
# [0.006547041707080504, 2.25]
# [0.006593406593406593, 1.95]
# [0.007270964614638876, 1.85]
# [0.007043964051493806, 2.4]
# [0.005314009661835749, 2.25]
# [0.006367866764633847, 2.2]
# ...

# %%
picky_test(50,'Geom_c:250_p:0.3_s:5000.csv')
# Out:
# [0.03240628778718259, 2.0]
# [0.0306420233463035, 2.2]
# [0.01814662472780063, 2.36]
# [0.025493025493025494, 2.28]
# [0.027427184466019418, 2.22]
# [0.029167654730851315, 2.13]
# [0.022616731517509727, 2.03]
# [0.017094017094017096, 2.68]
# [0.01818181818181818, 2.57]
# [0.026949678034819936, 2.11]
# [0.025728155339805825, 2.18]
# [0.025696969696969697, 2.04]
# [0.02421129860601614, 2.25]
# [0.018545632015617375, 2.39]
# [0.02286401925391095, 2.47]
# [0.025452765540871267, 2.12]
# [0.026572403705509506, 2.31]
# [0.017446086745820207, 2.32]
# [0.017896543270409414, 2.38]
# [0.02381530984204131, 2.24]
# [0.021760154738878143, 2.44]
# [0.023408924652523776, 2.24]
# [0.02233009708737864, 2.33]
# [0.023826890347678095, 2.29]
# [0.02424830261881668, 2.29]
# [0.026559454191033137, 2.25]
# [0.02352085354025218, 2.36]
# [0.018621523579201934, 2.48]
# [0.02035870092098885, 2.43]
# [0.016050583657587547, 2.52]
# [0.02433682161109759, 2.17]
# [0.025341130604288498, 2.27]
# ...

# %%
picky_test(100,'Geom_c:250_p:0.3_s:5000.csv')
# Out:
# [0.012333736396614269, 2.12]
# [0.00924124513618677, 2.6]
# [0.012823614807645777, 2.18]
# [0.007696007696007696, 2.3]
# [0.01383495145631068, 2.02]
# [0.008536874555371117, 2.3]
# [0.008511673151750972, 2.4]
# [0.008791208791208791, 2.38]
# [0.01309090909090909, 2.06]
# [0.009301216312902457, 2.42]
# [0.00849514563106796, 2.16]
# [0.009696969696969697, 2.38]
# [0.008559550012227928, 2.3]
# [0.012933138116154222, 2.0]
# [0.00914560770156438, 2.58]
# [0.008565834557023984, 2.32]
# [0.011701608971233545, 2.12]
# [0.009449963653985946, 2.34]
# [0.01201274822260358, 2.08]
# [0.010935601458080195, 2.34]
# [0.009671179883945842, 2.38]
# [0.009266032674957328, 2.36]
# [0.009708737864077669, 2.14]
# [0.00899586676391928, 2.1]
# [0.012366634335596509, 2.08]
# [0.009502923976608187, 2.4]
# [0.008244422890397672, 2.14]
# [0.009189842805320435, 2.24]
# [0.011391177896267571, 2.28]
# [0.00899805447470817, 2.1]
# [0.006327573618885374, 2.26]
# [0.007797270955165692, 2.3]
# ...

# %%
picky_test(250,'Geom_c:250_p:0.3_s:5000.csv')
# Out:
# [0.007738814993954051, 2.6]
# [0.006566147859922179, 2.0]
# [0.008468424872973626, 2.3]
# [0.007215007215007215, 2.25]
# [0.006553398058252427, 2.05]
# [0.007114062129475931, 1.95]
# [0.00632295719844358, 2.15]
# [0.006349206349206349, 2.35]
# [0.008727272727272728, 1.85]
# [0.008108752683043167, 2.35]
# [0.006067961165048544, 1.9]
# [0.0075151515151515155, 1.95]
# [0.008070432868672046, 2.1]
# [0.006832601268911664, 2.1]
# [0.007460890493381468, 2.4]
# [0.006852667645619187, 2.15]
# [0.007313505607020965, 2.25]
# [0.006299975769323964, 2.55]
# [0.006619269428781564, 2.2]
# [0.006804374240583232, 2.25]
# [0.006528046421663443, 2.1]
# [0.008046817849305048, 2.15]
# [0.006067961165048544, 2.55]
# [0.006807682956479455, 1.95]
# [0.007032007759456838, 2.25]
# [0.007309941520467836, 1.95]
# [0.00606207565470417, 1.95]
# [0.0065296251511487305, 1.95]
# [0.007998061076102764, 2.7]
# [0.0070525291828793775, 1.8]
# [0.009247992212217084, 1.6]
# [0.008528265107212475, 1.8]
# ...

# %%
picky_test(100,'Geom_c:100_p:0.3_s:10000.csv')
# Out:
# [0.009072214830047175, 2.26]
# [0.006374022850270595, 2.37]
# [0.010421715947649055, 2.25]
# [0.011331789935420982, 2.31]
# [0.01022022143813116, 2.18]
# [0.006232023010546501, 2.42]
# [0.007414610429074997, 2.34]
# [0.006356191174673023, 2.6]
# [0.00630379439932113, 2.6]
# [0.007875923906458257, 2.39]
# [0.006294637453092846, 2.71]
# [0.005574406204556471, 2.42]
# [0.007139399806389158, 2.33]
# [0.009040928527794747, 2.18]
# [0.007425441265976871, 2.26]
# [0.006178822389144657, 2.16]
# [0.008402338041889917, 2.2]
# [0.008350478034612127, 2.39]
# [0.004879834085641088, 2.31]
# [0.0089143973623153, 2.22]
# [0.005943716642406598, 2.27]
# [0.006055468087683178, 2.22]
# [0.006532784902008227, 2.62]
# [0.008154819863680622, 2.25]
# [0.0069351502615890015, 2.44]
# [0.007458124465093532, 2.21]
# [0.006441419543023821, 2.37]
# [0.009616555082166769, 2.25]
# [0.005111976630963973, 2.43]
# [0.007205666829506595, 2.39]
# [0.006677999028654687, 2.35]
# [0.008730447435431065, 2.39]
# ...

# %%
picky_test(200,'Geom_c:100_p:0.3_s:10000.csv')
# Out:
# [0.004354663118422644, 2.26]
# [0.004690318701142514, 2.48]
# [0.003999030538051382, 2.26]
# [0.005970512976727184, 2.84]
# [0.00511011071906558, 2.66]
# [0.005153403643336529, 2.38]
# [0.004375835663060654, 2.2]
# [0.0044004400440044, 2.42]
# [0.0038792580918899262, 2.56]
# [0.004846722403974313, 2.2]
# [0.006052536012589275, 2.3]
# [0.0037566650508967523, 2.14]
# [0.004719264278799613, 2.36]
# [0.005253512522907758, 2.28]
# [0.004990870359099208, 2.88]
# [0.00484613520717228, 2.22]
# [0.00438382854359474, 2.34]
# [0.004598813990076243, 2.3]
# [0.004879834085641088, 2.34]
# [0.00512883135914031, 2.22]
# [0.006307617661329452, 2.18]
# [0.005328811917161197, 2.1]
# [0.0062908299056375514, 2.04]
# [0.005233690360272639, 2.24]
# [0.005718457233240054, 2.34]
# [0.003545665729306761, 2.38]
# [0.004982984929508993, 2.14]
# [0.004017041996348144, 2.18]
# [0.0046251217137293086, 2.32]
# [0.005740107474352711, 2.24]
# [0.004006799417192812, 2.24]
# [0.004122711288953559, 2.74]
# ...

# %%
picky_test(500,'Geom_c:100_p:0.3_s:10000.csv')
# Out:
# [0.0035079230676182413, 2.35]
# [0.004570054119061936, 2.35]
# [0.003635482307319438, 2.45]
# [0.00438649932984038, 2.4]
# [0.003893417690716632, 2.5]
# [0.003954937679769894, 2.35]
# [0.0036465297192172117, 2.45]
# [0.003667033370003667, 2.5]
# [0.0036368044611468056, 2.55]
# [0.004362050163576881, 2.05]
# [0.003389420167049994, 2.6]
# [0.0033931168201648087, 2.05]
# [0.0035091965150048404, 2.2]
# [0.0036652412950519244, 2.35]
# [0.0038953134510042605, 1.85]
# [0.00363460140537921, 2.25]
# [0.004505601558694593, 2.2]
# [0.0033885997821614428, 2.45]
# [0.0028059045992436258, 2.05]
# [0.0036634509708145073, 1.95]
# [0.003517709849587579, 1.95]
# [0.0042388276613782245, 1.85]
# [0.004355189934672151, 1.8]
# [0.0038948393378773127, 2.15]
# [0.004136756296386422, 2.05]
# [0.003545665729306761, 1.95]
# [0.003767622751579971, 2.0]
# [0.0037735849056603774, 2.1]
# [0.004138266796494644, 2.1]
# [0.0029311187103077674, 2.25]
# [0.00473530840213696, 1.65]
# [0.0043652237177155325, 2.25]
# ...

# %%
picky_test(100,'Geom_c:200_p:0.3_s:10000.csv')
# Out:
# [0.008356545961002786, 2.43]
# [0.011506782945736434, 2.31]
# [0.006055468087683178, 2.39]
# [0.008098634110963374, 2.5]
# [0.008476628723661903, 2.3]
# [0.0062255859375, 2.27]
# [0.010397775359690485, 2.44]
# [0.0064943021688518565, 2.29]
# [0.008524111056989771, 2.29]
# [0.00930963607786241, 2.34]
# [0.0056022408963585435, 2.36]
# [0.007810593116914816, 2.48]
# [0.008478682170542635, 2.6]
# [0.009387954157522556, 2.19]
# [0.005445304937076476, 2.36]
# [0.00749063670411985, 2.21]
# [0.005731008413608097, 2.39]
# [0.007855934251873338, 2.66]
# [0.006435162700339971, 2.22]
# [0.013782168557141115, 1.99]
# [0.004626811153050043, 2.36]
# [0.009027443428021184, 2.36]
# [0.0061915746024037875, 2.37]
# [0.006926722566532993, 2.31]
# [0.005587949465500486, 2.43]
# [0.010852335081087672, 2.24]
# [0.007588739290085679, 2.3]
# [0.008736803785948308, 2.38]
# [0.005369782767878936, 2.38]
# [0.01000243961941937, 2.17]
# [0.006172839506172839, 2.52]
# [0.006940216729575064, 2.45]
# ...

# %%
picky_test(200,'Geom_c:200_p:0.3_s:10000.csv')
# Out:
# [0.00544992127891486, 2.08]
# [0.004723837209302325, 2.48]
# [0.00375439021436357, 2.22]
# [0.006889882751118095, 2.26]
# [0.005933640106563332, 2.08]
# [0.00390625, 2.96]
# [0.0060452182323781885, 2.06]
# [0.0053914961401789, 2.2]
# [0.004870920603994155, 2.24]
# [0.00544069640914037, 2.24]
# [0.004384362440628425, 2.42]
# [0.003539175006102026, 2.38]
# [0.0042393410852713176, 2.32]
# [0.003535722994391612, 2.2]
# [0.0064133591481122946, 2.44]
# [0.0049534855624018366, 2.48]
# [0.004267772222899646, 2.32]
# [0.0048344210780759, 2.54]
# [0.006313744536182613, 2.22]
# [0.006464202951579461, 2.4]
# [0.004383294776573725, 2.2]
# [0.005777563793933558, 2.14]
# [0.00400631297802598, 3.04]
# [0.005225422287033661, 2.1]
# [0.00826044703595724, 1.94]
# [0.005974881112059505, 2.02]
# [0.004039167686658507, 2.32]
# [0.004489746390001214, 2.4]
# [0.004515499145716377, 2.28]
# [0.006464991461332032, 1.94]
# [0.004841442749939482, 2.1]
# [0.00499208571776452, 2.34]
# [0.005961070559610706, 2.18]
# ...

# %%
picky_test(500,'Geom_c:200_p:0.3_s:10000.csv')
# Out:
# [0.004117718299624561, 2.1]
# [0.003633720930232558, 2.15]
# [0.0031488434055952524, 1.95]
# [0.0045932551674120635, 2.2]
# [0.003875030273674013, 2.25]
# [0.003662109375, 1.9]
# [0.0037480353040744772, 2.2]
# [0.004533758117877711, 1.7]
# [0.004627374573794447, 1.8]
# [0.003868939668722041, 1.85]
# [0.00401899890390939, 2.0]
# [0.003417134488650232, 1.85]
# [0.0037548449612403102, 2.4]
# [0.0031699585466959277, 2.0]
# [0.005203291384317522, 1.9]
# [0.00422858523619669, 2.4]
# [0.0037800268259968297, 1.95]
# [0.004230118443316413, 2.15]
# [0.004249635745507528, 2.45]
# [0.0034150506159287717, 2.4]
# [0.0035309874589066117, 2.05]
# [0.0039720751083293215, 2.25]
# [0.003399295860143256, 2.1]
# [0.0035241220075343297, 2.05]
# [0.004373177842565598, 3.0]
# [0.004877453969028167, 1.75]
# [0.003182374541003672, 2.4]
# [0.005339157869190632, 1.8]
# [0.004393458628264584, 1.85]
# [0.003781410100024396, 2.0]
# [0.0037521181312030983, 2.25]
# [0.0035309874589066117, 2.0]
# ...

# %%
picky_test(100,'Geom_c:500_p:0.3_s:10000.csv')
# Out:
# [0.00851270825732701, 2.22]
# [0.009260387474107469, 2.24]
# [0.006354637663448613, 2.36]
# [0.006555784873133423, 2.21]
# [0.005304400241109102, 2.34]
# [0.005214649527043415, 2.55]
# [0.007129047849202513, 2.3]
# [0.007174996959747051, 2.37]
# [0.009350333940497875, 2.23]
# [0.006570142353084317, 2.17]
# [0.004711852120333454, 2.3]
# [0.007320644216691069, 2.26]
# [0.005493834696618239, 2.43]
# [0.00872198667474258, 2.3]
# [0.009950248756218905, 2.17]
# [0.007874015748031496, 2.33]
# [0.006520164211543105, 2.3]
# [0.010508515521198213, 2.3]
# [0.008387018354199586, 2.29]
# [0.00548780487804878, 2.59]
# [0.007227174174897615, 2.56]
# [0.007734138972809668, 2.27]
# [0.00921435499515034, 2.31]
# [0.0044772507260406585, 2.2]
# [0.0069157971366173255, 2.41]
# [0.006185567010309278, 2.77]
# [0.0072089390844647366, 2.34]
# [0.005349544072948328, 2.34]
# [0.007802023649884189, 2.31]
# [0.007875923906458257, 2.2]
# [0.006132018756763256, 2.45]
# [0.005793885601577909, 2.21]
# ...

# %%
picky_test(200,'Geom_c:500_p:0.3_s:10000.csv')
# Out:
# [0.003405083302930804, 2.34]
# [0.004264652126233703, 2.32]
# [0.00501038738848833, 2.48]
# [0.003520699283719801, 2.46]
# [0.004701627486437613, 2.32]
# [0.003638127577007034, 2.32]
# [0.006162397293378444, 2.2]
# [0.005472455308281649, 2.14]
# [0.0035215543412264725, 2.36]
# [0.004623433507726001, 2.38]
# [0.004107768515162498, 2.18]
# [0.004148365056124939, 2.34]
# [0.005249664265657429, 2.54]
# [0.004239854633555421, 2.26]
# [0.005581846863244752, 2.3]
# [0.003997577225923683, 2.82]
# [0.004829751267809708, 2.14]
# [0.0039859886459717355, 2.38]
# [0.0037680807098577854, 2.36]
# [0.0037804878048780487, 2.46]
# [0.0036135870874488074, 2.4]
# [0.006283987915407855, 2.18]
# [0.004485935984481086, 2.92]
# [0.003872216844143272, 2.28]
# [0.00473186119873817, 2.26]
# [0.0038811400848999394, 2.4]
# [0.003844767511714526, 2.5]
# [0.004498480243161095, 2.24]
# [0.0056077044983542605, 2.2]
# [0.006543075245365322, 2.36]
# [0.006132018756763256, 2.2]
# [0.005054240631163708, 2.1]
# ...

# %%
picky_test(500,'Geom_c:500_p:0.3_s:10000.csv')
# Out:
# [0.003526693420892618, 1.95]
# [0.004020957719020349, 2.45]
# [0.003788341683978981, 1.95]
# [0.004613330095908704, 2.0]
# [0.0034960819770946355, 2.25]
# [0.003395585738539898, 2.0]
# [0.0035041082648622525, 1.85]
# [0.003405083302930804, 2.0]
# [0.0037644201578627807, 1.95]
# [0.003163401873707264, 1.95]
# [0.0038661350730941164, 2.25]
# [0.0035383113714006834, 2.0]
# [0.004272982541814186, 2.1]
# [0.0046032707450030285, 1.65]
# [0.004975124378109453, 1.6]
# [0.0038764385221078134, 1.85]
# [0.003622313450857281, 2.2]
# [0.004348351250150984, 1.8]
# [0.003038774766014343, 2.05]
# [0.004024390243902439, 2.15]
# [0.0037340399903637678, 2.25]
# [0.0037462235649546828, 2.15]
# [0.00533462657613967, 1.5]
# [0.004235237173281703, 1.85]
# [0.004125212327105072, 1.65]
# [0.004972710733778047, 1.7]
# [0.00336417157275021, 2.1]
# [0.003768996960486322, 2.5]
# [0.004388638303059856, 2.05]
# [0.003756209863080092, 2.05]
# [0.003366598533124925, 2.35]
# [0.0040680473372781065, 1.8]
# ...
