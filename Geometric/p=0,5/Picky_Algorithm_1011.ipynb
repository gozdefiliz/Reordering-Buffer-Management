# %%
#all necessary side algorithms

#finds the number of color changes in a given list
def nb_of_change(x):
    count=0
    i=0
    while i<(len(x)-1):
        if x[i]!=x[i+1]:
            count=count+1
            i=i+1
        else:
            i=i+1
    return count

#adds k items to the buffer from the input
def add(k, data,buffer):
    while k>0:
        buffer.append(data.pop(0))
        k=k-1
        
#finds and lists the unique items in a given list
def unique(list1): 
    unique_list = [] 
    for x in list1: 
        if x not in unique_list: 
            unique_list.append(x)
    return unique_list

#finds the most freq color in buffer
def most_freq(List): 
    return max(set(List), key = List.count)

#evicts c_act, appends output, removes from buffer, fills buffer till there is no c_act in buffer 
def evict(c_act, data, buffer,output_,k):
    while (c_act in buffer)==True:
        count=0
        buffer.remove(c_act)
        count=count+1
        for i in range(0,count):
            output_.append(c_act)
        while len(buffer)<k and len(data)!=0:
            add(k-len(buffer), data,buffer)
    return output_

#finds the second most frequent color in a given list
def second_most_freq(List): 
    from collections import Counter 
    occurence_count = Counter(List) 
    if len(occurence_count)>=2:
        return occurence_count.most_common(2)[1][0]
    else:
        return -1
    
#finds the occurence of a given color in a given list      
def occurence(List, x): 
    count=0
    for i in range (0, len(List)):
        if List[i]==x:
            count=count+1
    return count


#finds the least freq color in buffer
def least_freq(List): 
    return min(set(List), key = List.count)

# %%
def picky(k,input_):
    import numpy as np
    import math
    buffer=input_[0:0]
    output_=input_[0:0]
    data=input_[:]
    nb_of_delays=0
    c_act=-1
    result=[0]*2
    

    while len(data)!=0:
        ex=0
        while len(buffer)<k and len(data)!=0:

            add(min((k-len(buffer)), len(data)), data, buffer)
            

            if (c_act!=-1 and (c_act in buffer)==True):
                while (c_act in buffer)==True:
                    buffer.remove(c_act)
                    output_.append(c_act)

                    add(min(1,len(data)), data, buffer)
            else:
                continue
            if len(buffer)==0:
                break
                
            #nb of colors in the buffer is sigma
            sigma=len(unique(buffer))
            #most frequent color in the buffer
            o_1=most_freq(buffer)
            size_of_o1=occurence(buffer,o_1)
        

            while (size_of_o1 >= 2 * (math.ceil(len(buffer)/sigma))) and ex<len(data):

                delayed=least_freq(buffer)
                while (delayed in buffer)==True:
                    nb_of_delays=nb_of_delays+1
                    ex=ex+1
                    buffer.remove(delayed)
                    data.append(delayed)
                if len(buffer)==0:
                    break
                    
                    

        if len(buffer)!=0:
            c_act=most_freq(buffer)
            while(c_act in buffer)==True:
                buffer.remove(c_act)
                output_.append(c_act)
            

    while len(buffer)!=0:
        c_act=most_freq(buffer)
        while (c_act in buffer)==True:
            buffer.remove(c_act)
            output_.append(c_act)
            
    result[0]=float(nb_of_change(output_)/nb_of_change(input_))
    result[1]=float(nb_of_delays/len(input_))
    print(result)

# %%
#reads data from given text and makes test of delay alg.
def picky_test(k,text):
    import pandas as pd
    data=pd.read_csv(text, header=None)

    input_1=(data.iloc[0]).tolist()
    input_2=(data.iloc[1]).tolist()
    input_3=(data.iloc[2]).tolist()
    input_4=(data.iloc[3]).tolist()
    input_5=(data.iloc[4]).tolist()
    input_6=(data.iloc[5]).tolist()
    input_7=(data.iloc[6]).tolist()
    input_8=(data.iloc[7]).tolist()
    input_9=(data.iloc[8]).tolist()
    input_10=(data.iloc[9]).tolist()

    input_11=(data.iloc[10]).tolist()
    input_12=(data.iloc[11]).tolist()
    input_13=(data.iloc[12]).tolist()
    input_14=(data.iloc[13]).tolist()
    input_15=(data.iloc[14]).tolist()
    input_16=(data.iloc[15]).tolist()
    input_17=(data.iloc[16]).tolist()
    input_18=(data.iloc[17]).tolist()
    input_19=(data.iloc[18]).tolist()
    input_20=(data.iloc[19]).tolist()

    input_21=(data.iloc[20]).tolist()
    input_22=(data.iloc[21]).tolist()
    input_23=(data.iloc[22]).tolist()
    input_24=(data.iloc[23]).tolist()
    input_25=(data.iloc[24]).tolist()
    input_26=(data.iloc[25]).tolist()
    input_27=(data.iloc[26]).tolist()
    input_28=(data.iloc[27]).tolist()
    input_29=(data.iloc[28]).tolist()
    input_30=(data.iloc[29]).tolist()

    input_31=(data.iloc[30]).tolist()
    input_32=(data.iloc[31]).tolist()
    input_33=(data.iloc[32]).tolist()
    input_34=(data.iloc[33]).tolist()
    input_35=(data.iloc[34]).tolist()
    input_36=(data.iloc[35]).tolist()
    input_37=(data.iloc[36]).tolist()
    input_38=(data.iloc[37]).tolist()
    input_39=(data.iloc[38]).tolist()
    input_40=(data.iloc[39]).tolist()

    input_41=(data.iloc[40]).tolist()
    input_42=(data.iloc[41]).tolist()
    input_43=(data.iloc[42]).tolist()
    input_44=(data.iloc[43]).tolist()
    input_45=(data.iloc[44]).tolist()
    input_46=(data.iloc[45]).tolist()
    input_47=(data.iloc[46]).tolist()
    input_48=(data.iloc[47]).tolist()
    input_49=(data.iloc[48]).tolist()
    input_50=(data.iloc[49]).tolist()

    picky(k,input_1)
    picky(k,input_2)
    picky(k,input_3)
    picky(k,input_4)
    picky(k,input_5)
    picky(k,input_6)
    picky(k,input_7)
    picky(k,input_8)
    picky(k,input_9)
    picky(k,input_10)

    picky(k,input_11)
    picky(k,input_12)
    picky(k,input_13)
    picky(k,input_14)
    picky(k,input_15)
    picky(k,input_16)
    picky(k,input_17)
    picky(k,input_18)
    picky(k,input_19)
    picky(k,input_20)

    picky(k,input_21)
    picky(k,input_22)
    picky(k,input_23)
    picky(k,input_24)
    picky(k,input_25)
    picky(k,input_26)
    picky(k,input_27)
    picky(k,input_28)
    picky(k,input_29)
    picky(k,input_30)

    picky(k,input_31)
    picky(k,input_32)
    picky(k,input_33)
    picky(k,input_34)
    picky(k,input_35)
    picky(k,input_36)
    picky(k,input_37)
    picky(k,input_38)
    picky(k,input_39)
    picky(k,input_40)

    picky(k,input_41)
    picky(k,input_42)
    picky(k,input_43)
    picky(k,input_44)
    picky(k,input_45)
    picky(k,input_46)
    picky(k,input_47)
    picky(k,input_48)
    picky(k,input_49)
    picky(k,input_50)

# %%
picky_test(10,'Geom_c:10_p:0.5_s:1000.csv')
# Out:
# [0.21375186846038863, 0.24]
# [0.2252663622526636, 0.2]
# [0.2042360060514372, 0.2]
# [0.23170731707317074, 0.19]
# [0.20634920634920634, 0.2]
# [0.20996978851963746, 0.23]
# [0.23823529411764705, 0.17]
# [0.20648967551622419, 0.3]
# [0.20916030534351146, 0.23]
# [0.23407407407407407, 0.16]
# [0.20552147239263804, 0.22]
# [0.19480519480519481, 0.37]
# [0.2267884322678843, 0.19]
# [0.2220496894409938, 0.18]
# [0.2050520059435364, 0.26]
# [0.21792890262751158, 0.12]
# [0.19469026548672566, 0.22]
# [0.2526636225266362, 0.19]
# [0.21116138763197587, 0.3]
# [0.22556390977443608, 0.22]
# [0.24659606656580937, 0.16]
# [0.20512820512820512, 0.3]
# [0.17496229260935142, 0.37]
# [0.22807017543859648, 0.26]
# [0.2566510172143975, 0.16]
# [0.1937869822485207, 0.28]
# [0.2161764705882353, 0.26]
# [0.2084592145015106, 0.29]
# [0.24537037037037038, 0.21]
# [0.21242774566473988, 0.19]
# [0.21851289833080426, 0.32]
# [0.24925373134328357, 0.18]
# [0.22306525037936267, 0.27]
# ...

# %%
picky_test(20,'Geom_c:10_p:0.5_s:1000.csv')
# Out:
# [0.08520179372197309, 0.76]
# [0.0593607305936073, 0.86]
# [0.04387291981845688, 0.84]
# [0.07164634146341463, 0.82]
# [0.09047619047619047, 0.44]
# [0.04682779456193353, 1.0]
# [0.057352941176470586, 0.82]
# [0.06047197640117994, 1.0]
# [0.06564885496183206, 0.86]
# [0.047407407407407405, 0.82]
# [0.03834355828220859, 0.7]
# [0.046176046176046176, 0.94]
# [0.0639269406392694, 0.86]
# [0.07763975155279502, 0.58]
# [0.0638930163447251, 0.88]
# [0.05564142194744977, 0.86]
# [0.05457227138643068, 0.82]
# [0.0517503805175038, 0.94]
# [0.05731523378582202, 0.9]
# [0.08270676691729323, 0.6]
# [0.0832072617246596, 0.64]
# [0.08144796380090498, 0.7]
# [0.06485671191553545, 0.82]
# [0.07748538011695906, 0.66]
# [0.057902973395931145, 0.7]
# [0.07396449704142012, 0.62]
# [0.06323529411764706, 0.88]
# [0.06797583081570997, 0.82]
# [0.08333333333333333, 0.78]
# [0.06502890173410404, 0.78]
# [0.06069802731411229, 0.82]
# [0.06567164179104477, 0.76]
# [0.0622154779969651, 0.94]
# ...

# %%
picky_test(50,'Geom_c:10_p:0.5_s:1000.csv')
# Out:
# [0.02242152466367713, 1.1]
# [0.0213089802130898, 0.65]
# [0.01361573373676248, 0.9]
# [0.018292682926829267, 1.0]
# [0.012698412698412698, 0.85]
# [0.015105740181268883, 0.85]
# [0.020588235294117647, 0.85]
# [0.016224188790560472, 1.7]
# [0.015267175572519083, 0.75]
# [0.02074074074074074, 0.8]
# [0.018404907975460124, 0.7]
# [0.01443001443001443, 0.95]
# [0.015220700152207, 0.8]
# [0.017080745341614908, 0.9]
# [0.01188707280832095, 1.05]
# [0.01854714064914992, 0.95]
# [0.01327433628318584, 0.95]
# [0.0243531202435312, 0.7]
# [0.012066365007541479, 0.85]
# [0.022556390977443608, 0.7]
# [0.01664145234493192, 1.0]
# [0.01809954751131222, 1.25]
# [0.013574660633484163, 0.85]
# [0.019005847953216373, 1.0]
# [0.014084507042253521, 0.75]
# [0.022189349112426034, 0.95]
# [0.01764705882352941, 1.0]
# [0.013595166163141994, 0.8]
# [0.020061728395061727, 0.75]
# [0.02023121387283237, 0.8]
# [0.01669195751138088, 0.8]
# [0.013432835820895522, 1.1]
# [0.015174506828528073, 0.9]
# ...

# %%
picky_test(10,'Geom_c:20_p:0.5_s:1000.csv')
# Out:
# [0.24925816023738873, 0.38]
# [0.2237442922374429, 0.22]
# [0.2096317280453258, 0.21]
# [0.21428571428571427, 0.26]
# [0.2321699544764795, 0.24]
# [0.22287390029325513, 0.21]
# [0.2225609756097561, 0.22]
# [0.2303206997084548, 0.25]
# [0.22018348623853212, 0.26]
# [0.2578125, 0.14]
# [0.18584070796460178, 0.31]
# [0.19879518072289157, 0.31]
# [0.22518518518518518, 0.26]
# [0.3020527859237537, 0.15]
# [0.22005988023952097, 0.19]
# [0.21758569299552907, 0.23]
# [0.21823617339312407, 0.31]
# [0.20489296636085627, 0.29]
# [0.1887366818873668, 0.34]
# [0.20943952802359883, 0.3]
# [0.2353823088455772, 0.24]
# [0.19424460431654678, 0.26]
# [0.22008862629246675, 0.25]
# [0.21751824817518248, 0.19]
# [0.2146118721461187, 0.23]
# [0.2257100149476831, 0.21]
# [0.23900293255131966, 0.23]
# [0.22108345534407028, 0.24]
# [0.20839363241678727, 0.21]
# [0.2187028657616893, 0.22]
# [0.22786647314949202, 0.25]
# [0.18950437317784258, 0.33]
# [0.21203007518796993, 0.25]
# [0.21279761904761904, 0.25]
# ...

# %%
picky_test(20,'Geom_c:20_p:0.5_s:1000.csv')
# Out:
# [0.06379821958456973, 0.92]
# [0.0669710806697108, 0.82]
# [0.05099150141643059, 0.98]
# [0.05167173252279635, 1.1]
# [0.05918057663125948, 1.0]
# [0.06451612903225806, 0.86]
# [0.04878048780487805, 1.02]
# [0.08017492711370262, 0.6]
# [0.07033639143730887, 0.68]
# [0.0734375, 0.64]
# [0.06932153392330384, 0.64]
# [0.07078313253012049, 0.78]
# [0.04148148148148148, 1.14]
# [0.051319648093841645, 0.82]
# [0.07335329341317365, 0.62]
# [0.06259314456035768, 0.72]
# [0.07473841554559044, 0.8]
# [0.0581039755351682, 0.82]
# [0.060882800608828, 0.72]
# [0.04129793510324484, 0.92]
# [0.044977511244377814, 0.96]
# [0.053237410071942444, 0.96]
# [0.060561299852289516, 0.82]
# [0.06423357664233577, 0.86]
# [0.0745814307458143, 0.7]
# [0.07772795216741404, 0.58]
# [0.06158357771260997, 0.94]
# [0.05856515373352855, 0.86]
# [0.08104196816208394, 0.68]
# [0.058823529411764705, 0.78]
# [0.04354136429608128, 1.02]
# [0.056851311953352766, 0.84]
# [0.06466165413533835, 0.94]
# ...

# %%
picky_test(50,'Geom_c:20_p:0.5_s:1000.csv')
# Out:
# [0.02225519287833828, 1.05]
# [0.0167427701674277, 0.9]
# [0.018413597733711047, 0.7]
# [0.0182370820668693, 0.75]
# [0.018209408194233688, 1.3]
# [0.016129032258064516, 0.9]
# [0.01676829268292683, 0.9]
# [0.014577259475218658, 1.05]
# [0.021406727828746176, 1.0]
# [0.015625, 0.75]
# [0.02064896755162242, 0.9]
# [0.015060240963855422, 0.9]
# [0.01925925925925926, 1.35]
# [0.020527859237536656, 0.85]
# [0.014970059880239521, 0.7]
# [0.01788375558867362, 0.9]
# [0.01943198804185351, 1.2]
# [0.01529051987767584, 1.35]
# [0.015220700152207, 0.75]
# [0.016224188790560472, 0.9]
# [0.01649175412293853, 0.8]
# [0.014388489208633094, 0.85]
# [0.01772525849335303, 0.9]
# [0.017518248175182483, 0.85]
# [0.0136986301369863, 0.85]
# [0.02092675635276532, 0.95]
# [0.024926686217008796, 0.8]
# [0.016105417276720352, 0.95]
# [0.015918958031837915, 1.4]
# [0.016591251885369532, 1.2]
# [0.013062409288824383, 1.0]
# [0.011661807580174927, 0.9]
# [0.022556390977443608, 0.85]
# ...

# %%
picky_test(10,'Geom_c:50_p:0.5_s:1000.csv')
# Out:
# [0.20532915360501566, 0.23]
# [0.20414201183431951, 0.38]
# [0.20902255639097744, 0.3]
# [0.2378917378917379, 0.23]
# [0.239880059970015, 0.15]
# [0.2158273381294964, 0.24]
# [0.2254335260115607, 0.24]
# [0.20754716981132076, 0.36]
# [0.21791044776119403, 0.24]
# [0.21263482280431434, 0.21]
# [0.22466960352422907, 0.26]
# [0.2321699544764795, 0.33]
# [0.2378716744913928, 0.27]
# [0.23851851851851852, 0.23]
# [0.22156573116691286, 0.17]
# [0.20458015267175572, 0.18]
# [0.20408163265306123, 0.23]
# [0.20833333333333334, 0.28]
# [0.19629057187017002, 0.29]
# [0.2120253164556962, 0.22]
# [0.2171344165435746, 0.28]
# [0.21139430284857572, 0.21]
# [0.2514705882352941, 0.2]
# [0.2199108469539376, 0.17]
# [0.2081513828238719, 0.27]
# [0.2304147465437788, 0.19]
# [0.2085889570552147, 0.26]
# [0.2049062049062049, 0.3]
# [0.2589147286821705, 0.19]
# [0.19756838905775076, 0.28]
# [0.23726346433770015, 0.19]
# [0.20212765957446807, 0.34]
# [0.1751497005988024, 0.34]
# [0.2503725782414307, 0.18]
# ...

# %%
picky_test(20,'Geom_c:50_p:0.5_s:1000.csv')
# Out:
# [0.061128526645768025, 0.6]
# [0.0650887573964497, 0.84]
# [0.061654135338345864, 0.86]
# [0.05413105413105413, 0.94]
# [0.0704647676161919, 0.86]
# [0.05467625899280575, 0.8]
# [0.05202312138728324, 0.98]
# [0.062409288824383166, 0.9]
# [0.056716417910447764, 0.9]
# [0.05546995377503852, 0.82]
# [0.06754772393538913, 0.8]
# [0.06676783004552352, 0.72]
# [0.081377151799687, 0.66]
# [0.07555555555555556, 0.7]
# [0.051698670605613, 0.82]
# [0.04885496183206107, 0.8]
# [0.0728862973760933, 0.7]
# [0.07738095238095238, 0.64]
# [0.0973724884080371, 0.58]
# [0.056962025316455694, 0.88]
# [0.050221565731166914, 1.08]
# [0.06446776611694154, 0.78]
# [0.07205882352941176, 0.82]
# [0.0787518573551263, 0.82]
# [0.053857350800582245, 0.76]
# [0.04915514592933948, 0.72]
# [0.05061349693251534, 1.02]
# [0.0735930735930736, 0.64]
# [0.05271317829457364, 0.82]
# [0.07142857142857142, 0.68]
# [0.056768558951965066, 1.02]
# [0.060790273556231005, 0.94]
# [0.07784431137724551, 0.7]
# ...

# %%
picky_test(50,'Geom_c:50_p:0.5_s:1000.csv')
# Out:
# [0.01567398119122257, 0.8]
# [0.01775147928994083, 0.9]
# [0.015037593984962405, 0.9]
# [0.01566951566951567, 1.4]
# [0.025487256371814093, 1.15]
# [0.014388489208633094, 0.9]
# [0.014450867052023121, 0.9]
# [0.018867924528301886, 0.95]
# [0.014925373134328358, 0.95]
# [0.01848998459167951, 1.1]
# [0.014684287812041116, 0.9]
# [0.018209408194233688, 0.85]
# [0.014084507042253521, 0.85]
# [0.02074074074074074, 1.5]
# [0.01772525849335303, 1.1]
# [0.013740458015267175, 0.8]
# [0.01749271137026239, 0.9]
# [0.019345238095238096, 1.05]
# [0.02009273570324575, 1.0]
# [0.01740506329113924, 0.8]
# [0.01772525849335303, 1.15]
# [0.01649175412293853, 0.85]
# [0.01911764705882353, 1.1]
# [0.014858841010401188, 1.3]
# [0.01601164483260553, 0.85]
# [0.018433179723502304, 0.75]
# [0.01687116564417178, 0.8]
# [0.025974025974025976, 0.7]
# [0.017054263565891473, 1.0]
# [0.025835866261398176, 1.1]
# [0.013100436681222707, 1.0]
# [0.015197568389057751, 0.85]
# [0.019461077844311378, 1.3]
# ...

# %%
picky_test(50,'Geom_c:50_p:0.5_s:5000.csv')
# Out:
# [0.0073681108163866785, 1.29]
# [0.0033353547604608852, 1.05]
# [0.007772795216741405, 1.28]
# [0.006134969325153374, 0.96]
# [0.012684989429175475, 1.17]
# [0.00477754553598089, 0.95]
# [0.003942978465271459, 1.15]
# [0.006222222222222222, 1.38]
# [0.007883565797453002, 1.33]
# [0.009264793783622235, 1.19]
# [0.009456985967053081, 1.43]
# [0.006995133819951338, 0.91]
# [0.010814058275758487, 1.29]
# [0.009256494475962974, 0.99]
# [0.004134672179562906, 1.59]
# [0.0059665871121718375, 1.12]
# [0.0059417706476530005, 1.27]
# [0.00985525100092393, 0.97]
# [0.006016847172081829, 1.28]
# [0.008083832335329342, 1.26]
# [0.006988757216651474, 1.02]
# [0.007532389273877674, 1.37]
# [0.006238859180035651, 1.47]
# [0.004469606674612634, 0.95]
# [0.009757539917208752, 1.12]
# [0.00481637567730283, 1.08]
# [0.00724200362100181, 1.31]
# [0.005669949268874963, 1.0]
# [0.006880047861202512, 0.94]
# [0.005714285714285714, 1.03]
# [0.00938824954572986, 0.88]
# [0.007312079555425563, 1.14]
# ...

# %%
picky_test(100,'Geom_c:50_p:0.5_s:5000.csv')
# Out:
# [0.0029472443265546712, 1.06]
# [0.0036385688295936932, 1.0]
# [0.003288490284005979, 0.98]
# [0.0036809815950920245, 0.92]
# [0.003926306251887647, 0.92]
# [0.003881755747984473, 0.88]
# [0.003639672429481347, 0.94]
# [0.003851851851851852, 0.94]
# [0.0036385688295936932, 0.98]
# [0.0038852361028093247, 0.92]
# [0.004270896888346553, 0.88]
# [0.0033454987834549877, 1.04]
# [0.003604686091919495, 0.9]
# [0.004478948939982084, 0.88]
# [0.0035440047253396337, 0.96]
# [0.0038782816229116944, 0.98]
# [0.0035650623885918, 0.96]
# [0.004003695719125347, 0.9]
# [0.003309265944645006, 0.94]
# [0.0038922155688622755, 1.02]
# [0.004557885141294439, 0.9]
# [0.004218137993371497, 0.9]
# [0.0032679738562091504, 0.94]
# [0.003575685339690107, 1.0]
# [0.0035481963335304554, 0.94]
# [0.004515352197471403, 1.0]
# [0.004526252263126132, 0.98]
# [0.0035810205908683975, 0.92]
# [0.004187855219862399, 0.9]
# [0.004210526315789474, 0.9]
# [0.0036341611144760752, 1.04]
# [0.0038022813688212928, 1.1]
# ...

# %%
picky_test(250,'Geom_c:50_p:0.5_s:5000.csv')
# Out:
# [0.0029472443265546712, 0.95]
# [0.003941782898726501, 0.9]
# [0.003587443946188341, 0.85]
# [0.0036809815950920245, 0.8]
# [0.003926306251887647, 0.85]
# [0.0035831591519856674, 0.8]
# [0.003639672429481347, 0.9]
# [0.0035555555555555557, 0.9]
# [0.0036385688295936932, 0.9]
# [0.0035863717872086074, 0.85]
# [0.0036607687614399025, 0.8]
# [0.0033454987834549877, 0.8]
# [0.0039050765995794533, 0.75]
# [0.0035831591519856674, 0.85]
# [0.0032486709982279976, 0.9]
# [0.0032816229116945108, 0.9]
# [0.0038621509209744503, 0.85]
# [0.0036957191253464737, 0.8]
# [0.0030084235860409147, 0.9]
# [0.003592814371257485, 0.9]
# [0.0036463081130355514, 0.85]
# [0.004218137993371497, 0.9]
# [0.0032679738562091504, 0.9]
# [0.003575685339690107, 0.9]
# [0.003252513305736251, 0.9]
# [0.0039133052378085495, 0.8]
# [0.003922751961375981, 0.85]
# [0.003879438973440764, 0.95]
# [0.004187855219862399, 0.9]
# [0.003909774436090226, 0.85]
# [0.0036341611144760752, 0.8]
# [0.0035097981866042704, 0.95]
# ...

# %%
picky_test(50,'Geom_c:100_p:0.5_s:5000.csv')
# Out:
# [0.007416563658838072, 1.48]
# [0.00894187779433681, 1.42]
# [0.005755831566192063, 0.9]
# [0.00909090909090909, 1.2]
# [0.006810778797749482, 1.23]
# [0.006713457430576747, 1.07]
# [0.00853398354160317, 1.16]
# [0.004236006051437216, 0.98]
# [0.004807692307692308, 1.05]
# [0.008030933967876264, 1.19]
# [0.007890743550834597, 1.03]
# [0.0053843852826802275, 1.03]
# [0.003357753357753358, 0.98]
# [0.006153846153846154, 1.08]
# [0.006906906906906907, 0.93]
# [0.007791429427629608, 1.26]
# [0.005993407252022775, 0.97]
# [0.0056564453706460256, 1.58]
# [0.005535055350553505, 0.93]
# [0.01105797967722654, 1.08]
# [0.013185495954450104, 1.15]
# [0.004486987735566856, 1.39]
# [0.008130081300813009, 1.03]
# [0.008147254073627036, 1.55]
# [0.005387608500448967, 1.21]
# [0.013349154553544943, 1.14]
# [0.0075826508947528055, 1.09]
# [0.0068533969010727055, 1.36]
# [0.007226738934056007, 1.07]
# [0.010513296227581941, 1.09]
# [0.006251860672819291, 0.99]
# [0.006002400960384154, 1.18]
# ...

# %%
picky_test(100,'Geom_c:100_p:0.5_s:5000.csv')
# Out:
# [0.003708281829419036, 0.92]
# [0.0035767511177347243, 0.92]
# [0.003332323538321721, 0.88]
# [0.004242424242424243, 1.0]
# [0.002961208172934557, 0.94]
# [0.0042722001830942935, 0.9]
# [0.00365742151782993, 1.0]
# [0.003933434190620273, 0.94]
# [0.0030048076923076925, 0.88]
# [0.003569303985722784, 0.94]
# [0.0036418816388467377, 0.9]
# [0.0035895901884534847, 0.98]
# [0.003357753357753358, 0.88]
# [0.003384615384615385, 0.94]
# [0.003903903903903904, 0.9]
# [0.003596044351213665, 0.94]
# [0.003596044351213665, 1.0]
# [0.004167907115212861, 0.94]
# [0.0036900369003690036, 0.88]
# [0.0035863717872086074, 1.1]
# [0.003895714713814804, 0.94]
# [0.0035895901884534847, 0.92]
# [0.00331225534477567, 0.94]
# [0.003922751961375981, 0.88]
# [0.004489673750374139, 0.98]
# [0.003263126668644319, 0.94]
# [0.003639672429481347, 1.04]
# [0.004171632896305125, 0.92]
# [0.004817825956037338, 1.06]
# [0.0037105751391465678, 1.04]
# [0.003572491813039595, 0.92]
# [0.004201680672268907, 0.92]
# ...

# %%
picky_test(250,'Geom_c:100_p:0.5_s:5000.csv')
# Out:
# [0.003399258343634116, 0.8]
# [0.003278688524590164, 0.85]
# [0.003938200545289306, 0.85]
# [0.0048484848484848485, 0.7]
# [0.002961208172934557, 0.85]
# [0.0045773573390296, 0.75]
# [0.003962206644315757, 0.85]
# [0.003630862329803328, 0.75]
# [0.0033052884615384615, 0.75]
# [0.003569303985722784, 0.9]
# [0.0036418816388467377, 0.8]
# [0.003888722704157942, 0.85]
# [0.003663003663003663, 0.8]
# [0.003384615384615385, 0.9]
# [0.0036036036036036037, 0.75]
# [0.003296373988612526, 0.9]
# [0.003895714713814804, 0.9]
# [0.004167907115212861, 0.9]
# [0.004305043050430504, 0.85]
# [0.0038852361028093247, 0.8]
# [0.004195385076415942, 0.85]
# [0.003888722704157942, 0.85]
# [0.00331225534477567, 0.8]
# [0.003621001810500905, 0.8]
# [0.0038910505836575876, 0.9]
# [0.003263126668644319, 0.9]
# [0.003942978465271459, 0.75]
# [0.0038736591179976162, 0.9]
# [0.004516711833785004, 0.95]
# [0.003401360544217687, 0.8]
# [0.003274784161952962, 0.9]
# [0.003601440576230492, 0.85]
# ...

# %%
picky_test(50,'Geom_c:250_p:0.5_s:5000.csv')
# Out:
# [0.005499541704857928, 1.02]
# [0.006904833383368358, 1.05]
# [0.007777445408315884, 1.09]
# [0.008564678086237449, 1.21]
# [0.0053207212533254505, 1.11]
# [0.004839685420447671, 1.61]
# [0.0074917590650284685, 1.34]
# [0.011515151515151515, 1.2]
# [0.01259888661002051, 0.93]
# [0.007100591715976331, 1.17]
# [0.0035885167464114833, 1.25]
# [0.005702280912364946, 1.05]
# [0.006334841628959276, 1.17]
# [0.0054446460980036296, 1.05]
# [0.0057506053268765135, 1.0]
# [0.004881025015253203, 1.01]
# [0.006400487656202377, 0.96]
# [0.0069381598793363496, 1.18]
# [0.0053683268714583956, 1.18]
# [0.007514277126540427, 1.12]
# [0.007471607890017932, 1.02]
# [0.004206730769230769, 0.94]
# [0.012257100149476832, 1.12]
# [0.0045871559633027525, 0.96]
# [0.005086774386594853, 1.52]
# [0.009491733006736069, 0.94]
# [0.008083832335329342, 1.41]
# [0.009066183136899365, 1.11]
# [0.005031074282332051, 0.96]
# [0.004822182037371911, 1.09]
# [0.008734939759036145, 1.44]
# [0.006717557251908397, 1.26]
# ...

# %%
picky_test(100,'Geom_c:250_p:0.5_s:5000.csv')
# Out:
# [0.003971891231286282, 1.0]
# [0.003602521765235665, 1.0]
# [0.0035895901884534847, 1.0]
# [0.0035440047253396337, 0.9]
# [0.0035471475022169673, 0.94]
# [0.003629764065335753, 0.94]
# [0.003895714713814804, 0.96]
# [0.0036363636363636364, 1.12]
# [0.0032229709932610606, 1.1]
# [0.003254437869822485, 0.94]
# [0.004485645933014354, 1.28]
# [0.003601440576230492, 0.92]
# [0.00392156862745098, 1.0]
# [0.003327283726557774, 0.98]
# [0.004539951573849879, 1.1]
# [0.003355704697986577, 0.9]
# [0.004266991770801585, 0.94]
# [0.004223227752639517, 0.92]
# [0.003578884580972264, 0.96]
# [0.003005710850616171, 0.88]
# [0.005977286312014346, 0.96]
# [0.004507211538461538, 0.96]
# [0.004484304932735426, 1.26]
# [0.003975535168195718, 0.92]
# [0.003590664272890485, 0.94]
# [0.003061849357011635, 0.86]
# [0.0032934131736526945, 0.94]
# [0.003928679359323058, 0.96]
# [0.004143237644273453, 0.9]
# [0.003616636528028933, 1.0]
# [0.004518072289156626, 0.92]
# [0.00366412213740458, 1.02]
# ...

# %%
picky_test(250,'Geom_c:250_p:0.5_s:5000.csv')
# Out:
# [0.004277421326000611, 0.75]
# [0.003902731912338637, 0.9]
# [0.002991325157044571, 0.9]
# [0.0032486709982279976, 0.85]
# [0.0035471475022169673, 0.9]
# [0.003932244404113733, 0.9]
# [0.003895714713814804, 0.85]
# [0.0030303030303030303, 0.9]
# [0.0032229709932610606, 0.9]
# [0.0035502958579881655, 0.8]
# [0.00388755980861244, 0.9]
# [0.0033013205282112846, 0.9]
# [0.0036199095022624436, 0.85]
# [0.003327283726557774, 0.75]
# [0.003934624697336562, 0.85]
# [0.003355704697986577, 0.8]
# [0.004266991770801585, 0.75]
# [0.004223227752639517, 0.8]
# [0.003578884580972264, 0.9]
# [0.003005710850616171, 0.8]
# [0.0041841004184100415, 0.9]
# [0.003605769230769231, 0.85]
# [0.003587443946188341, 0.9]
# [0.004281345565749235, 0.9]
# [0.0038898862956313583, 0.85]
# [0.003674219228413962, 0.8]
# [0.0032934131736526945, 0.85]
# [0.003324267150196434, 0.8]
# [0.004143237644273453, 0.85]
# [0.0039180229053646775, 0.85]
# [0.00391566265060241, 0.8]
# [0.00366412213740458, 0.85]
# ...

# %%
picky_test(100,'Geom_c:100_p:0.5_s:10000.csv')
# Out:
# [0.0019540057117090033, 0.96]
# [0.0017720023626698169, 0.98]
# [0.0022318107424490405, 0.97]
# [0.0018110473890733474, 0.94]
# [0.00194377990430622, 1.04]
# [0.001834581868215869, 0.96]
# [0.002283452580301416, 1.13]
# [0.00223081499107674, 1.03]
# [0.0024143654745737136, 0.97]
# [0.002657218777679362, 0.94]
# [0.0022648346670693037, 0.99]
# [0.001968503937007874, 0.96]
# [0.00210178651854076, 0.97]
# [0.0016504126031507878, 0.93]
# [0.002389843166542196, 1.14]
# [0.0021039975954313195, 0.95]
# [0.0017889087656529517, 1.03]
# [0.002229820127843021, 1.09]
# [0.00194377990430622, 0.99]
# [0.0022471910112359553, 0.98]
# [0.0018058690744920992, 0.96]
# [0.0016571256402530884, 1.0]
# [0.0019305019305019305, 0.99]
# [0.0019768856447688566, 0.96]
# [0.0022552999548940008, 1.06]
# [0.002245508982035928, 1.09]
# [0.0017804154302670622, 0.96]
# [0.0019405881474846992, 1.1]
# [0.0019368295589988081, 1.07]
# [0.0025652633167345708, 1.7]
# [0.0020948675744426157, 1.1]
# ...

# %%
picky_test(200,'Geom_c:100_p:0.5_s:10000.csv')
# Out:
# [0.0021043138433789266, 0.92]
# [0.0017720023626698169, 0.94]
# [0.0022318107424490405, 0.94]
# [0.0018110473890733474, 0.98]
# [0.00194377990430622, 0.92]
# [0.001834581868215869, 1.04]
# [0.001978992236261227, 0.96]
# [0.002082093991671624, 0.94]
# [0.0022634676324128564, 0.94]
# [0.0023619722468261, 0.92]
# [0.0022648346670693037, 1.04]
# [0.0021199273167777106, 0.92]
# [0.002251914127007957, 0.98]
# [0.0016504126031507878, 0.9]
# [0.0020911127707244214, 0.92]
# [0.0018034265103697023, 1.02]
# [0.001937984496124031, 0.92]
# [0.0019325107774639512, 0.94]
# [0.0017942583732057417, 0.96]
# [0.0017977528089887641, 0.98]
# [0.001655379984951091, 1.06]
# [0.0016571256402530884, 0.9]
# [0.001782001782001782, 0.96]
# [0.0019768856447688566, 1.04]
# [0.0022552999548940008, 0.92]
# [0.0019461077844311378, 0.98]
# [0.0019287833827893175, 0.98]
# [0.0017913121361397223, 1.0]
# [0.0020858164481525627, 0.94]
# [0.0019616719480911424, 1.04]
# [0.002244500972617088, 0.9]
# ...

# %%
picky_test(500,'Geom_c:100_p:0.5_s:10000.csv')
# Out:
# [0.0021043138433789266, 0.75]
# [0.0017720023626698169, 0.9]
# [0.0023805981252789763, 0.85]
# [0.0018110473890733474, 0.85]
# [0.00194377990430622, 0.9]
# [0.0019874636905671916, 0.75]
# [0.001978992236261227, 0.75]
# [0.001933372992266508, 0.9]
# [0.0021125697902519996, 0.85]
# [0.0022143489813994687, 0.85]
# [0.0021138456892646836, 0.85]
# [0.0021199273167777106, 0.85]
# [0.0019516589100735625, 0.9]
# [0.001800450112528132, 0.75]
# [0.001941747572815534, 0.9]
# [0.001953712052900511, 0.85]
# [0.001937984496124031, 0.9]
# [0.0019325107774639512, 0.9]
# [0.00194377990430622, 0.95]
# [0.0017977528089887641, 0.85]
# [0.0018058690744920992, 0.85]
# [0.0018077734257306419, 0.75]
# [0.001782001782001782, 0.9]
# [0.0019768856447688566, 0.8]
# [0.0022552999548940008, 0.75]
# [0.0019461077844311378, 0.8]
# [0.0019287833827893175, 0.8]
# [0.0017913121361397223, 0.9]
# [0.0020858164481525627, 0.85]
# [0.0021125697902519996, 0.9]
# [0.002244500972617088, 0.8]
# [0.0019461077844311378, 0.85]
# ...

# %%
picky_test(100,'Geom_c:200_p:0.5_s:10000.csv')
# Out:
# [0.0019750835612275903, 0.96]
# [0.001947857356907402, 1.01]
# [0.002127013065937405, 0.95]
# [0.002228495023027782, 1.0]
# [0.0019741837509491267, 1.02]
# [0.002255978342607911, 0.99]
# [0.0019622641509433963, 0.96]
# [0.0017950635751682873, 0.96]
# [0.0019411676870240407, 0.96]
# [0.002227833061042626, 0.96]
# [0.0025471980821096794, 0.99]
# [0.0019499025048747563, 0.96]
# [0.001935099732063114, 1.1]
# [0.0017947950942267424, 1.04]
# [0.0019596020500452214, 0.98]
# [0.002074381389835531, 0.97]
# [0.001956063797773097, 0.99]
# [0.0018162554866051157, 0.96]
# [0.0016651528913109294, 0.95]
# [0.002112251056125528, 1.1]
# [0.0017854485939592323, 0.96]
# [0.00210115563559958, 0.98]
# [0.001975683890577508, 0.94]
# [0.0019339482296935435, 0.96]
# [0.0019534184823441023, 0.95]
# [0.002253605769230769, 0.96]
# [0.0022245291413317513, 1.05]
# [0.0022576760987357016, 0.95]
# [0.002283452580301416, 0.94]
# [0.0018157058556513845, 0.95]
# [0.0025452912112591706, 1.55]
# ...

# %%
picky_test(200,'Geom_c:200_p:0.5_s:10000.csv')
# Out:
# [0.002127013065937405, 0.9]
# [0.0017980221756068325, 1.0]
# [0.0019750835612275903, 1.04]
# [0.0019313623532907444, 0.96]
# [0.0019741837509491267, 0.92]
# [0.0019551812302601897, 0.96]
# [0.0021132075471698114, 0.9]
# [0.0016454749439042632, 0.94]
# [0.002090488278333582, 0.92]
# [0.002227833061042626, 0.92]
# [0.002097692538207971, 0.9]
# [0.0020998950052497373, 0.94]
# [0.001935099732063114, 0.94]
# [0.0017947950942267424, 0.94]
# [0.0019596020500452214, 1.0]
# [0.002074381389835531, 0.94]
# [0.0021065302437556425, 0.98]
# [0.0019676101104888753, 0.9]
# [0.0016651528913109294, 0.92]
# [0.0018105009052504525, 0.88]
# [0.0020830233596191043, 0.92]
# [0.0022512381809995496, 0.92]
# [0.00182370820668693, 0.92]
# [0.0017851829812555787, 1.0]
# [0.0018031555221637867, 0.92]
# [0.0021033653846153845, 0.92]
# [0.002076227198576301, 0.94]
# [0.0022576760987357016, 1.02]
# [0.0021312224082813214, 0.94]
# [0.0019670146769556664, 0.9]
# [0.0017966761491241205, 0.94]
# ...

# %%
picky_test(500,'Geom_c:200_p:0.5_s:10000.csv')
# Out:
# [0.0018231540565177757, 0.8]
# [0.001947857356907402, 0.9]
# [0.0022789425706472195, 0.75]
# [0.0019313623532907444, 0.9]
# [0.002126044039483675, 0.75]
# [0.00210557978643405, 0.75]
# [0.0021132075471698114, 0.75]
# [0.0017950635751682873, 0.75]
# [0.001791847095714499, 0.9]
# [0.002227833061042626, 0.8]
# [0.001947857356907402, 0.85]
# [0.0019499025048747563, 0.9]
# [0.0017862459065197975, 0.9]
# [0.001944361352078971, 0.85]
# [0.0021103406692794696, 0.85]
# [0.002074381389835531, 0.85]
# [0.0021065302437556425, 0.9]
# [0.0019676101104888753, 0.95]
# [0.0018165304268846503, 0.75]
# [0.0018105009052504525, 0.8]
# [0.0017854485939592323, 0.9]
# [0.00210115563559958, 0.9]
# [0.001975683890577508, 0.75]
# [0.0019339482296935435, 0.9]
# [0.0018031555221637867, 0.85]
# [0.0021033653846153845, 0.8]
# [0.002076227198576301, 0.9]
# [0.0022576760987357016, 0.85]
# [0.002283452580301416, 0.75]
# [0.0019670146769556664, 0.75]
# [0.0017966761491241205, 0.9]
# [0.00163471541090801, 0.9]
# ...

# %%
picky_test(100,'Geom_c:500_p:0.5_s:10000.csv')
# Out:
# [0.0032075759890025967, 0.93]
# [0.0019604886140853566, 0.97]
# [0.0019808014627456954, 0.95]
# [0.001976284584980237, 0.94]
# [0.0020864381520119225, 1.04]
# [0.0021205695243865495, 1.07]
# [0.0019449431478156792, 0.99]
# [0.0017851829812555787, 0.98]
# [0.0016598762637694282, 0.95]
# [0.00223081499107674, 1.03]
# [0.002389843166542196, 0.96]
# [0.0025395876904690767, 0.94]
# [0.001929642274009203, 0.96]
# [0.001912608503751655, 1.04]
# [0.0015114873035066505, 0.93]
# [0.0019408778739922366, 0.98]
# [0.0021183234982599486, 0.94]
# [0.0017969451931716084, 1.0]
# [0.002273760800363802, 0.93]
# [0.001942908384396951, 0.94]
# [0.0017878426698450535, 1.0]
# [0.0020901761719916393, 1.33]
# [0.0019566526189042747, 1.02]
# [0.00224517287831163, 0.95]
# [0.002076227198576301, 1.01]
# [0.0019446522064323112, 1.08]
# [0.0019405881474846992, 0.99]
# [0.0019528316058284513, 0.97]
# [0.001794526693584567, 0.95]
# [0.0022651766837813348, 1.08]
# [0.002360230122436938, 1.28]
# ...

# %%
picky_test(200,'Geom_c:500_p:0.5_s:10000.csv')
# Out:
# [0.0019856422789063695, 0.92]
# [0.0019604886140853566, 0.94]
# [0.0019808014627456954, 0.92]
# [0.001976284584980237, 0.96]
# [0.0019374068554396423, 0.92]
# [0.001969100272644653, 1.06]
# [0.0017953321364452424, 0.94]
# [0.0020827134781315083, 0.98]
# [0.0018107741059302852, 0.9]
# [0.00223081499107674, 0.92]
# [0.001941747572815534, 0.94]
# [0.00224081266806095, 0.88]
# [0.001781208252931572, 0.96]
# [0.001912608503751655, 0.96]
# [0.0016626360338573155, 0.88]
# [0.0019408778739922366, 1.02]
# [0.0019670146769556664, 0.94]
# [0.0017969451931716084, 0.96]
# [0.0018190086402910413, 0.92]
# [0.002092362875504409, 0.88]
# [0.0019368295589988081, 0.92]
# [0.0019408778739922366, 0.9]
# [0.002107164358819988, 0.9]
# [0.002095494686424188, 1.0]
# [0.0019279252558208513, 0.96]
# [0.0020942408376963353, 1.04]
# [0.0019405881474846992, 0.92]
# [0.0018026137899954935, 0.94]
# [0.001794526693584567, 0.92]
# [0.0021141649048625794, 1.06]
# [0.0017701725918277031, 0.96]
# ...

# %%
picky_test(500,'Geom_c:500_p:0.5_s:10000.csv')
# Out:
# [0.0019856422789063695, 0.8]
# [0.0019604886140853566, 0.9]
# [0.002133170806033826, 0.75]
# [0.001976284584980237, 0.8]
# [0.0017883755588673621, 0.9]
# [0.001969100272644653, 0.95]
# [0.0017953321364452424, 0.85]
# [0.0016364177328176137, 0.9]
# [0.0018107741059302852, 0.75]
# [0.002082093991671624, 0.9]
# [0.0017923823749066467, 0.85]
# [0.002091425156856887, 0.85]
# [0.001781208252931572, 0.9]
# [0.0020597322348094747, 0.85]
# [0.0015114873035066505, 0.8]
# [0.0017915795759928337, 0.9]
# [0.0021183234982599486, 0.75]
# [0.0017969451931716084, 0.9]
# [0.0019705926936486283, 0.75]
# [0.001942908384396951, 0.75]
# [0.0017878426698450535, 0.9]
# [0.0017915795759928337, 0.85]
# [0.001806140878988561, 0.85]
# [0.001945816494536746, 0.9]
# [0.0019279252558208513, 0.9]
# [0.0019446522064323112, 0.95]
# [0.0019405881474846992, 0.9]
# [0.0019528316058284513, 0.85]
# [0.001794526693584567, 0.8]
# [0.0021141649048625794, 0.9]
# [0.0017701725918277031, 0.9]
# [0.0019484412470023981, 0.85]
# ...
