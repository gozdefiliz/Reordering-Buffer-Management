# %%
#truncated n_binom, to have color size of 5 max_value needs to be 4
def truncated_Nbinom(n, p, max_value, size):
    import scipy.stats as sct
    temp_size = size
    while True:
        temp_size *= 2
        temp = sct.nbinom.rvs(n, p, size=temp_size)
        truncated = temp[temp <= max_value]
        if len(truncated) >= size:
            return truncated[:size]

# %%
#creates inputs according to the written algorithm inside
#to have color size of 5 max_value needs to be 4, n=max_value
def inputs(n, p, size, text):
    import scipy.stats as sct
    import numpy as np
    import csv
    max_value=n
    
    input_1= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_1)
    
    input_2= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_2)
    
    input_3= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_3)
    
    input_4= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_4)
    
    input_5= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_5)
    
    input_6= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_6)
    
    input_7= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_7)
    
    input_8= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_8)
    
    input_9= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_9)
    
    input_10= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_10)

    input_11= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_11)
    
    input_12= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_12)
    
    input_13= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_13)
    
    input_14= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_14)
    
    input_15= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_15)
    
    input_16= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_16)
    
    input_17= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_17)
    
    input_18= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_18)
    
    input_19= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_19)
    
    input_20= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_20)

    input_21= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_21)
    
    input_22= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_22)
    
    input_23= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_23)
    
    input_24= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_24)
    
    input_25= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_25)
    
    input_26= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_26)
    
    input_27= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_27)
    
    input_28= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_28)
    
    input_29= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_29)
    
    input_30= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_30)
    
    input_31= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_31)
    
    input_32= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_32)
    
    input_33= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_33)
    
    input_34= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_34)
    
    input_35= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_35)
    
    input_36= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_36)
    
    input_37= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_37)
    
    input_38= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_38)
    
    input_39= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_39)
    
    input_40= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_40)
    
    input_41= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_41)
    
    input_42= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_42)
    
    input_43= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_43)
    
    input_44= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_44)
    
    input_45= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_45)
    
    input_46= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_46)
    
    input_47= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_47)
    
    input_48= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_48)
    
    input_49= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_49)
    
    input_50= truncated_Nbinom(n, p, max_value, size).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_50)

# %%
#creates inputs according to the written algorithm inside
#to have color size of 5 max_value needs to be 4, n=max_value
#inputs(n, p, size, text)
inputs(4, 0.3, 100, 'NBinom_c:5_p:0.3_s:100.csv')

# %%
#n=color-1, p=probability, size
inputs(9, 0.3, 100, 'NBinom_c:10_p:0.3_s:100.csv')

# %%
#n=color-1, p=probability, size
inputs(19, 0.3, 100, 'NBinom_c:20_p:0.3_s:100.csv')

# %%
#n=color-1, p=probability, size
inputs(49, 0.3, 100, 'NBinom_c:50_p:0.3_s:100.csv')

# %%
#n=color-1, p=probability, size
inputs(4, 0.3, 1000, 'NBinom_c:5_p:0.3_s:1000.csv')

# %%
#n=color-1, p=probability, size
inputs(9, 0.3, 1000, 'NBinom_c:10_p:0.3_s:1000.csv')

# %%
#n=color-1, p=probability, size
inputs(19, 0.3, 1000, 'NBinom_c:20_p:0.3_s:1000.csv')

# %%
#n=color-1, p=probability, size
inputs(49, 0.3, 1000, 'NBinom_c:50_p:0.3_s:1000.csv')

# %%
#n=color-1, p=probability, size
inputs(4, 0.3, 5000, 'NBinom_c:5_p:0.3_s:5000.csv')

# %%
#n=color-1, p=probability, size
inputs(9, 0.3, 5000, 'NBinom_c:10_p:0.3_s:5000.csv')

# %%
#n=color-1, p=probability, size
inputs(19, 0.3, 5000, 'NBinom_c:20_p:0.3_s:5000.csv')

# %%
#n=color-1, p=probability, size
inputs(49, 0.3, 5000, 'NBinom_c:50_p:0.3_s:5000.csv')

# %%
#n=color-1, p=probability, size
inputs(4, 0.3, 10000, 'NBinom_c:5_p:0.3_s:10000.csv')

# %%
#n=color-1, p=probability, size
inputs(9, 0.3, 10000, 'NBinom_c:10_p:0.3_s:10000.csv')

# %%
#n=color-1, p=probability, size
inputs(19, 0.3, 10000, 'NBinom_c:20_p:0.3_s:10000.csv')

# %%
#n=color-1, p=probability, size
inputs(49, 0.3, 10000, 'NBinom_c:50_p:0.3_s:10000.csv')
