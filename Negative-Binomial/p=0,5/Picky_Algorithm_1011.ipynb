# %%
#all necessary side algorithms

#finds the number of color changes in a given list
def nb_of_change(x):
    count=0
    i=0
    while i<(len(x)-1):
        if x[i]!=x[i+1]:
            count=count+1
            i=i+1
        else:
            i=i+1
    return count

#adds k items to the buffer from the input
def add(k, data,buffer):
    while k>0:
        buffer.append(data.pop(0))
        k=k-1
        
#finds and lists the unique items in a given list
def unique(list1): 
    unique_list = [] 
    for x in list1: 
        if x not in unique_list: 
            unique_list.append(x)
    return unique_list

#finds the most freq color in buffer
def most_freq(List): 
    return max(set(List), key = List.count)

#evicts c_act, appends output, removes from buffer, fills buffer till there is no c_act in buffer 
def evict(c_act, data, buffer,output_,k):
    while (c_act in buffer)==True:
        count=0
        buffer.remove(c_act)
        count=count+1
        for i in range(0,count):
            output_.append(c_act)
        while len(buffer)<k and len(data)!=0:
            add(k-len(buffer), data,buffer)
    return output_

#finds the second most frequent color in a given list
def second_most_freq(List): 
    from collections import Counter 
    occurence_count = Counter(List) 
    if len(occurence_count)>=2:
        return occurence_count.most_common(2)[1][0]
    else:
        return -1
    
#finds the occurence of a given color in a given list      
def occurence(List, x): 
    count=0
    for i in range (0, len(List)):
        if List[i]==x:
            count=count+1
    return count


#finds the least freq color in buffer
def least_freq(List): 
    return min(set(List), key = List.count)

# %%
def picky(k,input_):
    import numpy as np
    import math
    buffer=input_[0:0]
    output_=input_[0:0]
    data=input_[:]
    nb_of_delays=0
    c_act=-1
    result=[0]*2
    

    while len(data)!=0:
        ex=0
        while len(buffer)<k and len(data)!=0:

            add(min((k-len(buffer)), len(data)), data, buffer)
            

            if (c_act!=-1 and (c_act in buffer)==True):
                while (c_act in buffer)==True:
                    buffer.remove(c_act)
                    output_.append(c_act)

                    add(min(1,len(data)), data, buffer)
            else:
                continue
            if len(buffer)==0:
                break
                
            #nb of colors in the buffer is sigma
            sigma=len(unique(buffer))
            #most frequent color in the buffer
            o_1=most_freq(buffer)
            size_of_o1=occurence(buffer,o_1)
        

            while (size_of_o1 >= 2 * (math.ceil(len(buffer)/sigma))) and ex<len(data):

                delayed=least_freq(buffer)
                while (delayed in buffer)==True:
                    nb_of_delays=nb_of_delays+1
                    ex=ex+1
                    buffer.remove(delayed)
                    data.append(delayed)
                if len(buffer)==0:
                    break
                    
                    

        if len(buffer)!=0:
            c_act=most_freq(buffer)
            while(c_act in buffer)==True:
                buffer.remove(c_act)
                output_.append(c_act)
            

    while len(buffer)!=0:
        c_act=most_freq(buffer)
        while (c_act in buffer)==True:
            buffer.remove(c_act)
            output_.append(c_act)
            
    result[0]=float(nb_of_change(output_)/nb_of_change(input_))
    result[1]=float(nb_of_delays/len(input_))
    print(result)

# %%
#reads data from given text and makes test of delay alg.
def picky_test(k,text):
    import pandas as pd
    data=pd.read_csv(text, header=None)

    input_1=(data.iloc[0]).tolist()
    input_2=(data.iloc[1]).tolist()
    input_3=(data.iloc[2]).tolist()
    input_4=(data.iloc[3]).tolist()
    input_5=(data.iloc[4]).tolist()
    input_6=(data.iloc[5]).tolist()
    input_7=(data.iloc[6]).tolist()
    input_8=(data.iloc[7]).tolist()
    input_9=(data.iloc[8]).tolist()
    input_10=(data.iloc[9]).tolist()

    input_11=(data.iloc[10]).tolist()
    input_12=(data.iloc[11]).tolist()
    input_13=(data.iloc[12]).tolist()
    input_14=(data.iloc[13]).tolist()
    input_15=(data.iloc[14]).tolist()
    input_16=(data.iloc[15]).tolist()
    input_17=(data.iloc[16]).tolist()
    input_18=(data.iloc[17]).tolist()
    input_19=(data.iloc[18]).tolist()
    input_20=(data.iloc[19]).tolist()

    input_21=(data.iloc[20]).tolist()
    input_22=(data.iloc[21]).tolist()
    input_23=(data.iloc[22]).tolist()
    input_24=(data.iloc[23]).tolist()
    input_25=(data.iloc[24]).tolist()
    input_26=(data.iloc[25]).tolist()
    input_27=(data.iloc[26]).tolist()
    input_28=(data.iloc[27]).tolist()
    input_29=(data.iloc[28]).tolist()
    input_30=(data.iloc[29]).tolist()

    input_31=(data.iloc[30]).tolist()
    input_32=(data.iloc[31]).tolist()
    input_33=(data.iloc[32]).tolist()
    input_34=(data.iloc[33]).tolist()
    input_35=(data.iloc[34]).tolist()
    input_36=(data.iloc[35]).tolist()
    input_37=(data.iloc[36]).tolist()
    input_38=(data.iloc[37]).tolist()
    input_39=(data.iloc[38]).tolist()
    input_40=(data.iloc[39]).tolist()

    input_41=(data.iloc[40]).tolist()
    input_42=(data.iloc[41]).tolist()
    input_43=(data.iloc[42]).tolist()
    input_44=(data.iloc[43]).tolist()
    input_45=(data.iloc[44]).tolist()
    input_46=(data.iloc[45]).tolist()
    input_47=(data.iloc[46]).tolist()
    input_48=(data.iloc[47]).tolist()
    input_49=(data.iloc[48]).tolist()
    input_50=(data.iloc[49]).tolist()

    picky(k,input_1)
    picky(k,input_2)
    picky(k,input_3)
    picky(k,input_4)
    picky(k,input_5)
    picky(k,input_6)
    picky(k,input_7)
    picky(k,input_8)
    picky(k,input_9)
    picky(k,input_10)

    picky(k,input_11)
    picky(k,input_12)
    picky(k,input_13)
    picky(k,input_14)
    picky(k,input_15)
    picky(k,input_16)
    picky(k,input_17)
    picky(k,input_18)
    picky(k,input_19)
    picky(k,input_20)

    picky(k,input_21)
    picky(k,input_22)
    picky(k,input_23)
    picky(k,input_24)
    picky(k,input_25)
    picky(k,input_26)
    picky(k,input_27)
    picky(k,input_28)
    picky(k,input_29)
    picky(k,input_30)

    picky(k,input_31)
    picky(k,input_32)
    picky(k,input_33)
    picky(k,input_34)
    picky(k,input_35)
    picky(k,input_36)
    picky(k,input_37)
    picky(k,input_38)
    picky(k,input_39)
    picky(k,input_40)

    picky(k,input_41)
    picky(k,input_42)
    picky(k,input_43)
    picky(k,input_44)
    picky(k,input_45)
    picky(k,input_46)
    picky(k,input_47)
    picky(k,input_48)
    picky(k,input_49)
    picky(k,input_50)

# %%
picky_test(10,'NBinom_c:10_p:0.5_s:1000.csv')
# Out:
# [0.3213872832369942, 0.16]
# [0.3186558516801854, 0.17]
# [0.31431897555296856, 0.18]
# [0.30539609644087257, 0.22]
# [0.3286384976525822, 0.18]
# [0.3083235638921454, 0.24]
# [0.3294663573085847, 0.19]
# [0.32708089097303633, 0.2]
# [0.31445086705202313, 0.22]
# [0.3384253819036428, 0.14]
# [0.320973348783314, 0.18]
# [0.3019517795637199, 0.23]
# [0.3064516129032258, 0.26]
# [0.3149882903981265, 0.24]
# [0.30186480186480186, 0.35]
# [0.32105868814729577, 0.18]
# [0.3079625292740047, 0.21]
# [0.32784958871915393, 0.2]
# [0.31220657276995306, 0.25]
# [0.3309608540925267, 0.21]
# [0.29965156794425085, 0.27]
# [0.31542857142857145, 0.22]
# [0.3131548311990687, 0.27]
# [0.3395565927654609, 0.14]
# [0.32646048109965636, 0.15]
# [0.32837528604118993, 0.14]
# [0.3256880733944954, 0.15]
# [0.3217993079584775, 0.18]
# [0.31812865497076026, 0.18]
# [0.3356562137049942, 0.16]
# [0.28537735849056606, 0.29]
# [0.29814385150812067, 0.29]
# [0.32027649769585254, 0.19]
# [0.3076036866359447, 0.29]
# ...

# %%
picky_test(20,'NBinom_c:10_p:0.5_s:1000.csv')
# Out:
# [0.16647398843930636, 0.46]
# [0.16801853997682503, 0.42]
# [0.15017462165308498, 0.7]
# [0.15729047072330654, 0.7]
# [0.1807511737089202, 0.3]
# [0.16881594372801875, 0.38]
# [0.17633410672853828, 0.46]
# [0.1735052754982415, 0.46]
# [0.15491329479768787, 0.66]
# [0.16686251468860164, 0.64]
# [0.1657010428736964, 0.54]
# [0.15040183696900114, 0.8]
# [0.15668202764976957, 0.62]
# [0.16276346604215455, 0.56]
# [0.15151515151515152, 0.66]
# [0.1714614499424626, 0.52]
# [0.18501170960187355, 0.32]
# [0.1692126909518214, 0.58]
# [0.176056338028169, 0.36]
# [0.17319098457888493, 0.4]
# [0.16144018583042974, 0.56]
# [0.14742857142857144, 0.74]
# [0.16530849825378346, 0.52]
# [0.1645274212368728, 0.58]
# [0.16953035509736541, 0.34]
# [0.17391304347826086, 0.46]
# [0.1651376146788991, 0.56]
# [0.15455594002306805, 0.72]
# [0.17192982456140352, 0.52]
# [0.17073170731707318, 0.36]
# [0.15212264150943397, 0.76]
# [0.1531322505800464, 0.6]
# [0.16589861751152074, 0.6]
# [0.173963133640553, 0.5]
# ...

# %%
picky_test(50,'NBinom_c:10_p:0.5_s:1000.csv')
# Out:
# [0.07398843930635839, 0.65]
# [0.0660486674391657, 0.9]
# [0.06984866123399301, 0.6]
# [0.06544202066590127, 0.9]
# [0.06103286384976526, 0.95]
# [0.07268464243845252, 0.45]
# [0.07308584686774942, 0.65]
# [0.06799531066822978, 0.9]
# [0.07052023121387284, 0.65]
# [0.0799059929494712, 0.35]
# [0.0660486674391657, 0.75]
# [0.0677382319173364, 0.55]
# [0.08294930875576037, 0.1]
# [0.07259953161592506, 0.6]
# [0.07226107226107226, 0.7]
# [0.07019562715765247, 0.5]
# [0.06557377049180328, 0.8]
# [0.06345475910693302, 1.25]
# [0.0715962441314554, 0.65]
# [0.06524317912218268, 1.1]
# [0.06736353077816493, 0.85]
# [0.07314285714285715, 0.6]
# [0.0640279394644936, 0.9]
# [0.07584597432905485, 0.6]
# [0.06643757159221077, 0.8]
# [0.06979405034324943, 0.6]
# [0.06307339449541284, 0.9]
# [0.0657439446366782, 0.9]
# [0.06549707602339182, 0.85]
# [0.07200929152148665, 0.7]
# [0.0695754716981132, 0.65]
# [0.06496519721577726, 0.7]
# [0.08064516129032258, 0.3]
# [0.0748847926267281, 0.65]
# ...

# %%
picky_test(10,'NBinom_c:20_p:0.5_s:1000.csv')
# Out:
# [0.436241610738255, 0.03]
# [0.43029637760702527, 0.06]
# [0.4397790055248619, 0.06]
# [0.44039735099337746, 0.01]
# [0.43891891891891893, 0.01]
# [0.4511930585683297, 0.02]
# [0.44652701212789414, 0.0]
# [0.43694690265486724, 0.04]
# [0.4272930648769575, 0.05]
# [0.44150110375275936, 0.05]
# [0.4280898876404494, 0.04]
# [0.4485373781148429, 0.02]
# [0.43743199129488575, 0.02]
# [0.4384017758046615, 0.0]
# [0.422271223814774, 0.05]
# [0.4375690607734807, 0.01]
# [0.43435448577680524, 0.01]
# [0.43946188340807174, 0.02]
# [0.42701525054466233, 0.04]
# [0.43942731277533037, 0.03]
# [0.43526785714285715, 0.08]
# [0.42872687704026113, 0.03]
# [0.4265193370165746, 0.04]
# [0.43492769744160176, 0.06]
# [0.43736263736263736, 0.01]
# [0.4487594390507012, 0.02]
# [0.4201117318435754, 0.04]
# [0.41629955947136565, 0.06]
# [0.45364238410596025, 0.0]
# [0.44541484716157204, 0.04]
# [0.4600219058050383, 0.0]
# [0.4172259507829978, 0.05]
# [0.4363233665559247, 0.01]
# [0.4440789473684211, 0.02]
# ...

# %%
picky_test(20,'NBinom_c:20_p:0.5_s:1000.csv')
# Out:
# [0.24049217002237136, 0.64]
# [0.21953896816684962, 0.86]
# [0.2276243093922652, 0.66]
# [0.22075055187637968, 0.68]
# [0.23459459459459459, 0.64]
# [0.22559652928416485, 0.66]
# [0.2227122381477398, 0.74]
# [0.24557522123893805, 0.54]
# [0.2181208053691275, 0.68]
# [0.22626931567328917, 0.68]
# [0.21685393258426966, 0.6]
# [0.2296858071505959, 0.72]
# [0.23612622415669204, 0.54]
# [0.24195338512763595, 0.6]
# [0.2348401323042999, 0.52]
# [0.21878453038674034, 0.68]
# [0.2286652078774617, 0.76]
# [0.22309417040358745, 0.68]
# [0.24074074074074073, 0.54]
# [0.24118942731277532, 0.52]
# [0.20424107142857142, 0.92]
# [0.24591947769314473, 0.42]
# [0.2265193370165746, 0.54]
# [0.2436040044493882, 0.54]
# [0.22417582417582418, 0.82]
# [0.24271844660194175, 0.72]
# [0.23128491620111732, 0.66]
# [0.2444933920704846, 0.52]
# [0.24392935982339956, 0.44]
# [0.22161572052401746, 0.82]
# [0.22343921139101863, 0.86]
# [0.23154362416107382, 0.48]
# [0.23920265780730898, 0.46]
# ...

# %%
picky_test(50,'NBinom_c:20_p:0.5_s:1000.csv')
# Out:
# [0.08165548098434004, 1.8]
# [0.09659714599341383, 1.2]
# [0.08066298342541436, 1.75]
# [0.08498896247240618, 1.55]
# [0.09405405405405405, 1.45]
# [0.0911062906724512, 1.1]
# [0.0926130099228225, 1.35]
# [0.09955752212389381, 1.05]
# [0.08277404921700224, 1.5]
# [0.09271523178807947, 1.35]
# [0.08764044943820225, 1.7]
# [0.09209100758396534, 1.4]
# [0.09031556039173014, 1.05]
# [0.10099889012208657, 1.25]
# [0.09481808158765159, 1.45]
# [0.08397790055248619, 1.9]
# [0.09956236323851203, 1.35]
# [0.08632286995515695, 1.3]
# [0.08278867102396514, 1.7]
# [0.10572687224669604, 0.85]
# [0.07477678571428571, 2.15]
# [0.09466811751904244, 1.4]
# [0.09723756906077348, 1.05]
# [0.11123470522803114, 0.85]
# [0.08241758241758242, 1.8]
# [0.08522114347357065, 1.3]
# [0.08491620111731843, 1.9]
# [0.07709251101321586, 1.8]
# [0.10375275938189846, 0.85]
# [0.09606986899563319, 1.55]
# [0.08981380065717415, 1.45]
# [0.09731543624161074, 1.2]
# [0.09302325581395349, 1.25]
# ...

# %%
picky_test(10,'NBinom_c:50_p:0.5_s:1000.csv')
# Out:
# [0.6857142857142857, 0.0]
# [0.676595744680851, 0.0]
# [0.6567164179104478, 0.0]
# [0.6702470461868958, 0.0]
# [0.7791798107255521, 0.0]
# [0.7396825396825397, 0.0]
# [0.7118463180362861, 0.0]
# [0.6772823779193206, 0.0]
# [0.6863780359028511, 0.0]
# [0.7167199148029819, 0.0]
# [0.7042105263157895, 0.0]
# [0.6913183279742765, 0.0]
# [0.6913183279742765, 0.0]
# [0.6708994708994709, 0.0]
# [0.6656118143459916, 0.0]
# [0.6925498426023085, 0.0]
# [0.6613418530351438, 0.0]
# [0.6399132321041214, 0.0]
# [0.6706135629709364, 0.0]
# [0.6649048625792812, 0.0]
# [0.6801705756929638, 0.0]
# [0.6216505894962486, 0.0]
# [0.6896918172157279, 0.0]
# [0.7035864978902954, 0.0]
# [0.703862660944206, 0.0]
# [0.6461864406779662, 0.0]
# [0.7252396166134185, 0.0]
# [0.6079913606911447, 0.0]
# [0.667375132837407, 0.0]
# [0.6993603411513859, 0.0]
# [0.6409431939978564, 0.0]
# [0.6652631578947369, 0.0]
# [0.667728237791932, 0.0]
# [0.7144362486828241, 0.0]
# [0.6737967914438503, 0.0]
# ...

# %%
picky_test(20,'NBinom_c:50_p:0.5_s:1000.csv')
# Out:
# [0.4042328042328042, 0.12]
# [0.4276595744680851, 0.0]
# [0.40298507462686567, 0.04]
# [0.39742212674543503, 0.16]
# [0.38380651945320715, 0.08]
# [0.39365079365079364, 0.24]
# [0.40981856990394877, 0.12]
# [0.40658174097664546, 0.08]
# [0.42133051742344246, 0.0]
# [0.38977635782747605, 0.16]
# [0.42210526315789476, 0.02]
# [0.3987138263665595, 0.14]
# [0.36763129689174706, 0.44]
# [0.4021164021164021, 0.14]
# [0.39135021097046413, 0.14]
# [0.4218258132214061, 0.0]
# [0.3812566560170394, 0.12]
# [0.4240780911062907, 0.0]
# [0.4251883745963401, 0.06]
# [0.4143763213530655, 0.02]
# [0.42643923240938164, 0.02]
# [0.39978563772775993, 0.22]
# [0.4250797024442083, 0.06]
# [0.4345991561181435, 0.0]
# [0.41416309012875535, 0.12]
# [0.3675847457627119, 0.14]
# [0.41959531416400425, 0.0]
# [0.4038876889848812, 0.2]
# [0.3931987247608927, 0.16]
# [0.41044776119402987, 0.02]
# [0.4180064308681672, 0.06]
# [0.4010526315789474, 0.12]
# [0.3991507430997877, 0.08]
# [0.4035827186512118, 0.04]
# ...

# %%
picky_test(50,'NBinom_c:50_p:0.5_s:1000.csv')
# Out:
# [0.14603174603174604, 1.75]
# [0.15106382978723404, 1.35]
# [0.13539445628997868, 1.45]
# [0.14070891514500536, 1.45]
# [0.12723449001051526, 2.1]
# [0.14285714285714285, 1.55]
# [0.12379935965848453, 2.7]
# [0.1475583864118896, 1.25]
# [0.1457233368532207, 1.4]
# [0.14164004259850904, 1.7]
# [0.14210526315789473, 1.95]
# [0.11468381564844587, 2.55]
# [0.15112540192926044, 1.2]
# [0.14074074074074075, 1.5]
# [0.14345991561181434, 1.5]
# [0.1689401888772298, 0.65]
# [0.14376996805111822, 1.75]
# [0.15075921908893708, 1.45]
# [0.1356297093649085, 1.7]
# [0.13530655391120508, 1.85]
# [0.15671641791044777, 1.5]
# [0.12540192926045016, 2.35]
# [0.1381509032943677, 1.95]
# [0.1308016877637131, 2.4]
# [0.148068669527897, 1.55]
# [0.1451271186440678, 1.65]
# [0.13205537806176784, 1.85]
# [0.13714902807775378, 1.7]
# [0.14240170031880978, 1.9]
# [0.11940298507462686, 2.5]
# [0.15755627009646303, 1.35]
# [0.13789473684210526, 1.5]
# [0.1602972399150743, 0.95]
# [0.16754478398314016, 0.7]
# ...

# %%
picky_test(50,'NBinom_c:50_p:0.5_s:5000.csv')
# Out:
# [0.13884156729131175, 1.55]
# [0.13253012048192772, 1.82]
# [0.1375717627046566, 1.6]
# [0.1198892674616695, 2.47]
# [0.13268744734625104, 1.85]
# [0.13786531130876747, 1.5]
# [0.13755598208573255, 1.66]
# [0.12598091198303288, 2.13]
# [0.13382663847780127, 1.78]
# [0.1340510871859827, 1.81]
# [0.13329095147276965, 1.94]
# [0.1288408561135834, 1.81]
# [0.13131098854476028, 2.0]
# [0.1404625503925313, 1.68]
# [0.13129610115911486, 1.84]
# [0.13012970444397193, 1.97]
# [0.12974348102607589, 1.93]
# [0.13166277341261415, 1.89]
# [0.13663282571912014, 1.91]
# [0.13266609880749575, 2.05]
# [0.1350948220754315, 1.79]
# [0.1299684542586751, 1.81]
# [0.12989778534923338, 1.96]
# [0.13426811132356065, 1.76]
# [0.13405566178032718, 1.77]
# [0.1347337152556758, 1.97]
# [0.12842866255581545, 2.0]
# [0.13582342954159593, 1.89]
# [0.13395506570580754, 1.81]
# [0.12502657877950243, 2.22]
# [0.13623745462310485, 1.62]
# [0.1343915343915344, 1.78]
# [0.12249680443118875, 2.36]
# ...

# %%
picky_test(100,'NBinom_c:50_p:0.5_s:5000.csv')
# Out:
# [0.056218057921635436, 3.24]
# [0.05833861762840837, 2.92]
# [0.0531575590048905, 3.36]
# [0.06090289608177172, 3.02]
# [0.05518112889637742, 3.66]
# [0.058873358746293944, 3.2]
# [0.05886116442738324, 3.1]
# [0.05641569459172852, 3.38]
# [0.06363636363636363, 2.82]
# [0.05425374709731898, 3.56]
# [0.056579783852511126, 3.16]
# [0.05912269548633185, 2.98]
# [0.060882477725922785, 3.06]
# [0.05962232123912582, 3.04]
# [0.05964172813487882, 2.98]
# [0.060386987029555604, 3.04]
# [0.058935764256942975, 2.92]
# [0.0573370142280739, 3.08]
# [0.06535532994923858, 2.48]
# [0.06132879045996593, 2.7]
# [0.0575324952056254, 3.2]
# [0.05741324921135647, 3.16]
# [0.056643952299829645, 3.44]
# [0.05991077119184194, 3.02]
# [0.06479711068621202, 2.52]
# [0.05792488860598345, 3.26]
# [0.05464597065702743, 3.34]
# [0.06557724957555178, 2.42]
# [0.06252649427723611, 2.86]
# [0.06357644056984903, 2.6]
# [0.058936579115951314, 3.16]
# [0.05947089947089947, 2.92]
# [0.06284618662121857, 2.74]
# ...

# %%
picky_test(250,'NBinom_c:50_p:0.5_s:5000.csv')
# Out:
# [0.02385008517887564, 3.75]
# [0.02092580849714648, 4.2]
# [0.022113544546034446, 3.8]
# [0.023211243611584328, 3.6]
# [0.02190395956192081, 3.65]
# [0.021812791190173656, 3.75]
# [0.02473875026658136, 3.35]
# [0.024602332979851538, 3.15]
# [0.021987315010570826, 4.1]
# [0.025754697065653368, 2.95]
# [0.02564102564102564, 2.95]
# [0.026064844246662427, 3.25]
# [0.025243954179041152, 2.9]
# [0.026098026734563972, 2.75]
# [0.026343519494204427, 3.1]
# [0.022113544546034446, 3.95]
# [0.021623913504345983, 3.65]
# [0.023784242939052878, 3.6]
# [0.024746192893401017, 3.35]
# [0.02129471890971039, 3.9]
# [0.024717664606861284, 3.3]
# [0.020609884332281808, 4.5]
# [0.020868824531516183, 4.0]
# [0.025281495644784362, 3.4]
# [0.02188230295304865, 4.15]
# [0.022278803309993635, 3.4]
# [0.02019987242185839, 3.7]
# [0.021222410865874362, 4.0]
# [0.02628232301822806, 2.9]
# [0.020837763129917076, 4.45]
# [0.02626521460602178, 3.2]
# [0.02306878306878307, 3.4]
# [0.022795057520238603, 3.4]
# ...

# %%
picky_test(50,'NBinom_c:100_p:0.5_s:5000.csv')
# Out:
# [0.20425620696849572, 1.3]
# [0.2028015889609032, 1.41]
# [0.19654742096505823, 1.47]
# [0.2053907229419139, 1.08]
# [0.20820320632937747, 0.94]
# [0.20793319415448852, 1.11]
# [0.20650372825186414, 1.13]
# [0.2013408757594804, 1.22]
# [0.20020833333333332, 1.36]
# [0.2029405674052599, 1.14]
# [0.20388552329224985, 1.29]
# [0.20581468312068604, 1.16]
# [0.20199916701374426, 1.16]
# [0.2092006661115737, 0.81]
# [0.20288642543400962, 1.22]
# [0.19732720818542493, 1.44]
# [0.20417536534446765, 1.48]
# [0.20440251572327045, 1.48]
# [0.20815899581589958, 1.05]
# [0.20370756092480732, 1.27]
# [0.19828845752452515, 1.48]
# [0.19720075203676624, 1.33]
# [0.20446950710108605, 1.27]
# [0.2035306334371755, 1.2]
# [0.20170868931027297, 1.21]
# [0.20266056952816464, 1.42]
# [0.19598410374398662, 1.43]
# [0.20337922403003755, 1.27]
# [0.19567477646080267, 1.64]
# [0.20137442732194918, 1.3]
# [0.20153910149750415, 1.24]
# [0.20446950710108605, 1.23]
# [0.20049710024855014, 1.26]
# ...

# %%
picky_test(100,'NBinom_c:100_p:0.5_s:5000.csv')
# Out:
# [0.0826204882119758, 3.52]
# [0.08216600459962367, 3.74]
# [0.07633111480865225, 4.02]
# [0.08399498537400753, 3.18]
# [0.09285863002290236, 2.56]
# [0.0778705636743215, 3.74]
# [0.08512841756420879, 3.38]
# [0.08527131782945736, 3.24]
# [0.08375, 3.56]
# [0.08117622696210396, 3.92]
# [0.0875287236264884, 3.02]
# [0.08575611796695252, 3.18]
# [0.08413161182840483, 3.36]
# [0.09221482098251457, 2.6]
# [0.08952102070696508, 2.94]
# [0.08749216955523073, 3.02]
# [0.08893528183716075, 3.02]
# [0.09266247379454927, 2.9]
# [0.08828451882845188, 3.28]
# [0.08956467402624453, 2.82]
# [0.09079524107701942, 2.74]
# [0.08982661374556089, 3.3]
# [0.09753550543024227, 2.76]
# [0.08785046728971962, 3.46]
# [0.09147739112315066, 3.06]
# [0.0856370816877988, 3.26]
# [0.0849194729136164, 3.6]
# [0.08719232373800584, 3.24]
# [0.08192971511748805, 3.88]
# [0.07580174927113703, 3.76]
# [0.08298668885191347, 3.48]
# [0.08897243107769423, 2.84]
# [0.0816072908036454, 3.38]
# [0.0885547201336675, 3.26]
# ...

# %%
picky_test(250,'NBinom_c:100_p:0.5_s:5000.csv')
# Out:
# [0.0358856665971208, 3.8]
# [0.036587915534183564, 3.5]
# [0.035981697171381034, 3.35]
# [0.03572921019640619, 3.65]
# [0.036643764313970435, 3.95]
# [0.03653444676409186, 3.1]
# [0.037903893951946974, 3.05]
# [0.03771213073538655, 3.6]
# [0.03854166666666667, 3.25]
# [0.03623938703665355, 3.6]
# [0.03196156256528097, 4.65]
# [0.03430244718678101, 3.9]
# [0.03727613494377343, 2.95]
# [0.03122398001665279, 4.45]
# [0.03639405982012131, 3.45]
# [0.039465441637084986, 2.8]
# [0.037578288100208766, 3.55]
# [0.03333333333333333, 4.55]
# [0.03619246861924686, 3.95]
# [0.031451780878983544, 4.5]
# [0.0329785013567105, 4.4]
# [0.03425945268435346, 3.9]
# [0.03529657477025898, 3.95]
# [0.03655244029075805, 3.7]
# [0.03646593040216712, 3.35]
# [0.0363749740178757, 3.7]
# [0.03534825350345116, 4.0]
# [0.03566958698372966, 4.1]
# [0.03451861093782491, 4.1]
# [0.03477717617659309, 3.8]
# [0.03369384359400998, 4.7]
# [0.029239766081871343, 5.15]
# [0.033347141673570835, 3.55]
# ...

# %%
picky_test(50,'NBinom_c:250_p:0.5_s:5000.csv')
# Out:
# [0.3212009047912811, 0.85]
# [0.31475409836065577, 0.77]
# [0.3148717948717949, 0.88]
# [0.33230895308338454, 0.73]
# [0.3114080164439877, 1.03]
# [0.3061516452074392, 0.92]
# [0.34057822431822843, 0.54]
# [0.3654988731817251, 0.2]
# [0.30895645028759244, 1.15]
# [0.34477796052631576, 0.3]
# [0.32519491177677473, 0.49]
# [0.3075180226570546, 0.99]
# [0.2976629766297663, 1.41]
# [0.35139002452984464, 0.39]
# [0.3341573959620931, 0.48]
# [0.3471937730438345, 0.51]
# [0.3241803278688525, 0.65]
# [0.3254049620668444, 0.74]
# [0.31463917525773194, 1.02]
# [0.32649712879409354, 0.5]
# [0.362128966223132, 0.3]
# [0.3239983646770237, 0.83]
# [0.3156923076923077, 0.69]
# [0.33647155137126483, 0.53]
# [0.3192142418661756, 0.74]
# [0.38799835593916976, 0.11]
# [0.3156596794081381, 0.82]
# [0.3137739345274861, 0.92]
# [0.3235655737704918, 0.69]
# [0.3445378151260504, 0.39]
# [0.29706002449979585, 1.19]
# [0.3227990970654628, 0.66]
# [0.32068894812384663, 0.74]
# [0.315443142093358, 0.9]
# ...

# %%
picky_test(100,'NBinom_c:250_p:0.5_s:5000.csv')
# Out:
# [0.14785112070738227, 3.16]
# [0.13831967213114754, 3.28]
# [0.15405128205128205, 2.36]
# [0.1436181110428191, 3.54]
# [0.1436793422404933, 3.32]
# [0.13243408951563457, 3.82]
# [0.14599138814845192, 2.78]
# [0.15283753329235814, 2.64]
# [0.14626129827444537, 2.72]
# [0.14597039473684212, 2.86]
# [0.1421830118998769, 3.32]
# [0.14067971163748713, 3.08]
# [0.14534645346453465, 2.86]
# [0.14472608340147178, 3.16]
# [0.15986814997939844, 2.3]
# [0.14072101597705858, 3.42]
# [0.13790983606557378, 3.42]
# [0.151117490260406, 2.26]
# [0.13381443298969073, 3.62]
# [0.1429450369155045, 2.86]
# [0.14002047082906857, 3.14]
# [0.1535159443990188, 2.7]
# [0.13476923076923078, 3.58]
# [0.13855914858780188, 3.5]
# [0.14119091467157766, 3.34]
# [0.15104808877928483, 2.82]
# [0.1467324290998767, 2.82]
# [0.13691579164093062, 3.42]
# [0.14016393442622951, 3.04]
# [0.16273826603812255, 2.42]
# [0.13168640261331155, 3.66]
# [0.16355427867843217, 2.36]
# [0.15173262251384048, 2.76]
# ...

# %%
picky_test(250,'NBinom_c:250_p:0.5_s:5000.csv')
# Out:
# [0.05593255192268147, 4.5]
# [0.05778688524590164, 3.9]
# [0.059487179487179485, 4.25]
# [0.0631018233968449, 3.5]
# [0.05405960945529291, 5.85]
# [0.054976497036582875, 4.35]
# [0.059052696329710885, 3.8]
# [0.055111657447244417, 4.45]
# [0.06059983566146261, 3.75]
# [0.059416118421052634, 4.45]
# [0.05949938448912597, 3.9]
# [0.05540679711637487, 4.6]
# [0.06211562115621156, 3.4]
# [0.05825838103025348, 4.5]
# [0.05953852492789452, 4.0]
# [0.05755837771405162, 4.35]
# [0.05819672131147541, 4.6]
# [0.06110313717449251, 3.65]
# [0.06309278350515464, 3.35]
# [0.05578342904019688, 4.8]
# [0.05547594677584442, 4.8]
# [0.06377759607522486, 3.1]
# [0.059076923076923075, 4.4]
# [0.05689725747032337, 4.55]
# [0.06384284837323512, 3.9]
# [0.04849979449239622, 5.95]
# [0.0581586518701192, 4.8]
# [0.05579575869878526, 4.75]
# [0.05778688524590164, 3.8]
# [0.059643369542939126, 4.1]
# [0.05553287055941201, 4.5]
# [0.05848553252616458, 3.85]
# [0.05884765224523272, 4.45]
# ...

# %%
picky_test(100,'NBinom_c:100_p:0.5_s:10000.csv')
# Out:
# [0.08701095461658842, 3.14]
# [0.08355879292403746, 3.48]
# [0.07983676886052109, 3.83]
# [0.08775595486836607, 3.16]
# [0.0833159105164123, 3.66]
# [0.08381351492928235, 3.54]
# [0.07816739720308913, 3.92]
# [0.08645054031587697, 3.1]
# [0.08827514330380407, 3.04]
# [0.08480933527818295, 3.32]
# [0.08445277517442466, 3.56]
# [0.08434610989924171, 3.26]
# [0.08932666249739421, 2.96]
# [0.08359423919849718, 3.18]
# [0.08986535852207495, 2.9]
# [0.08710147947489061, 3.07]
# [0.08556539864512767, 3.28]
# [0.08737258165175785, 3.55]
# [0.08176427754083013, 3.6]
# [0.0851952390895803, 3.06]
# [0.08237867111018538, 3.55]
# [0.08259556296219144, 3.46]
# [0.07927720910800083, 3.7]
# [0.08636173767752715, 3.14]
# [0.08873897249610795, 3.05]
# [0.08581271531475101, 3.32]
# [0.08829676071055381, 3.04]
# [0.08753122398001666, 2.99]
# [0.08684320266889074, 3.27]
# [0.08340301003344482, 3.11]
# [0.08131181676210307, 3.57]
# [0.08627532901608523, 2.99]
# [0.08388773388773389, 3.49]
# ...

# %%
picky_test(200,'NBinom_c:100_p:0.5_s:10000.csv')
# Out:
# [0.039019300991131975, 3.78]
# [0.04162330905306972, 4.16]
# [0.042168044365386625, 3.66]
# [0.045027162557459255, 3.62]
# [0.04150114990591679, 3.66]
# [0.0428496595075956, 3.68]
# [0.041953663118346904, 3.56]
# [0.03678304239401496, 4.94]
# [0.039395518499218345, 4.02]
# [0.04011252344238383, 4.2]
# [0.04498594189315839, 3.5]
# [0.044562168899968835, 3.42]
# [0.0402334792578695, 4.28]
# [0.04184930077228136, 4.18]
# [0.043836760254670704, 3.7]
# [0.041883725776203376, 4.0]
# [0.041479937467430956, 4.14]
# [0.04368629082587892, 3.42]
# [0.03921772599604702, 4.02]
# [0.04259761954479015, 3.9]
# [0.04374088731514268, 4.12]
# [0.03853765232788251, 4.46]
# [0.043033214957175686, 3.44]
# [0.038011695906432746, 4.62]
# [0.03923196678775298, 4.28]
# [0.040400876918258694, 4.0]
# [0.03928944618599791, 3.92]
# [0.040695253955037466, 4.1]
# [0.04034612176814012, 4.06]
# [0.041910535117056856, 3.5]
# [0.0431025507548152, 3.54]
# [0.03989972843116774, 4.14]
# [0.04147609147609148, 3.74]
# ...

# %%
picky_test(500,'NBinom_c:100_p:0.5_s:10000.csv')
# Out:
# [0.01637976004173187, 3.8]
# [0.020395421436004164, 3.5]
# [0.014439677723134875, 5.5]
# [0.02026744671959883, 3.55]
# [0.018293957767091782, 3.85]
# [0.016867469879518072, 4.6]
# [0.017219787100814028, 4.65]
# [0.018807148794679967, 3.15]
# [0.016466909848879625, 4.55]
# [0.016461762867264012, 4.1]
# [0.018015203582213892, 3.85]
# [0.018178040926560713, 4.05]
# [0.020220971440483636, 3.15]
# [0.01920267167605928, 3.85]
# [0.01826531677277946, 3.95]
# [0.01760783496561784, 3.95]
# [0.01782178217821782, 3.8]
# [0.01955481589348866, 3.45]
# [0.01997295329241652, 2.6]
# [0.018688661515974106, 3.45]
# [0.016454905228077483, 4.05]
# [0.01676908655348401, 4.25]
# [0.017965322749112177, 3.65]
# [0.01796157059314954, 3.85]
# [0.021380384016606125, 2.3]
# [0.01920868566656227, 3.2]
# [0.017659352142110764, 3.95]
# [0.017173189009159033, 4.3]
# [0.01730608840700584, 4.3]
# [0.016617892976588628, 4.55]
# [0.01978136387298282, 3.25]
# [0.016294129935241278, 4.7]
# [0.019334719334719336, 3.45]
# ...

# %%
picky_test(100,'NBinom_c:200_p:0.5_s:10000.csv')
# Out:
# [0.12327497425334706, 3.22]
# [0.12626936096009847, 2.88]
# [0.12541084634346755, 3.29]
# [0.12793089263677498, 2.88]
# [0.12529599505816946, 2.93]
# [0.12025056479769973, 3.55]
# [0.11865979381443299, 3.83]
# [0.12288833951380305, 3.18]
# [0.12633634868421054, 3.01]
# [0.1195137028642077, 3.19]
# [0.12462663508085281, 3.27]
# [0.12761570972064737, 2.93]
# [0.12214916786521471, 3.24]
# [0.12456248713197447, 3.11]
# [0.11848049281314169, 3.64]
# [0.12150493421052631, 3.39]
# [0.12071274075599958, 3.25]
# [0.12339463680263023, 3.08]
# [0.12669822972416633, 2.87]
# [0.12110583866309058, 3.64]
# [0.12326371025825703, 3.26]
# [0.1312777147571414, 2.49]
# [0.12256869404137079, 3.21]
# [0.12380364309972214, 3.27]
# [0.12514185494686889, 3.09]
# [0.1181799464690138, 3.67]
# [0.12447408927655208, 2.92]
# [0.12571957236842105, 2.91]
# [0.12266776620966911, 3.34]
# [0.12512862728956575, 3.31]
# [0.12327355184498041, 3.12]
# [0.12091199834932426, 3.54]
# [0.12177841667522332, 3.18]
# ...

# %%
picky_test(200,'NBinom_c:200_p:0.5_s:10000.csv')
# Out:
# [0.05890834191555098, 4.2]
# [0.058775259000923175, 4.36]
# [0.0628594905505341, 4.02]
# [0.06160016454134101, 3.94]
# [0.06269947493050551, 3.66]
# [0.05740398439104539, 4.72]
# [0.059278350515463915, 4.32]
# [0.06437989287185826, 3.58]
# [0.05643503289473684, 4.96]
# [0.05872656089017103, 4.26]
# [0.062313317540426405, 3.64]
# [0.05875682919286671, 4.28]
# [0.056708444627080336, 4.58]
# [0.05733992176240477, 4.62]
# [0.061806981519507184, 3.88]
# [0.061986019736842105, 3.88]
# [0.060253373158924706, 3.94]
# [0.06092674406657762, 3.9]
# [0.05866611774392754, 4.56]
# [0.059211883639364554, 4.16]
# [0.06440991871591728, 3.46]
# [0.0644529235846138, 3.68]
# [0.06040959143768653, 3.94]
# [0.060821241123803646, 4.1]
# [0.060352831940575676, 4.48]
# [0.05857525221330039, 4.7]
# [0.058081067213955874, 4.5]
# [0.06219161184210526, 4.24]
# [0.061024636635398415, 3.88]
# [0.06349043012965631, 3.88]
# [0.06029684601113173, 4.16]
# [0.061694005983699576, 3.7]
# [0.05873292945887668, 4.28]
# ...

# %%
picky_test(500,'NBinom_c:200_p:0.5_s:10000.csv')
# Out:
# [0.025334706488156538, 4.45]
# [0.028208021335521593, 3.7]
# [0.02608874281018899, 4.3]
# [0.026120937885643767, 4.4]
# [0.02656233913312056, 4.35]
# [0.024645717806531114, 4.75]
# [0.025670103092783506, 4.35]
# [0.026679027606098065, 4.4]
# [0.023231907894736843, 5.3]
# [0.026581495981866887, 4.2]
# [0.025028324235245647, 4.3]
# [0.023193485207710546, 5.8]
# [0.029587014588041916, 3.1]
# [0.02635371628577311, 4.1]
# [0.02597535934291581, 4.5]
# [0.026932565789473683, 3.6]
# [0.025028324235245647, 4.6]
# [0.02815164902907634, 3.0]
# [0.028200905722519556, 4.75]
# [0.028058592944089127, 3.9]
# [0.023767877353637206, 4.55]
# [0.026503042177993194, 4.2]
# [0.025007718431614697, 5.4]
# [0.023669856951734073, 5.75]
# [0.025275972351181265, 4.7]
# [0.0254272184476014, 4.6]
# [0.026577732170343767, 4.15]
# [0.025699013157894735, 4.75]
# [0.02484279971136996, 4.9]
# [0.027268985387939905, 4.25]
# [0.030199958771387342, 2.55]
# [0.02620447745795935, 4.55]
# [0.026080706438032654, 4.45]
# ...

# %%
picky_test(100,'NBinom_c:500_p:0.5_s:10000.csv')
# Out:
# [0.20879568359971495, 2.41]
# [0.2092857142857143, 2.13]
# [0.21031746031746032, 2.22]
# [0.2029531568228106, 2.64]
# [0.20225977198697068, 2.48]
# [0.21936074918566775, 1.88]
# [0.20868945868945868, 2.58]
# [0.2088259274357929, 2.16]
# [0.21086978688691752, 2.1]
# [0.20619712567526247, 2.8]
# [0.20958205912334352, 2.29]
# [0.20464027678844002, 2.26]
# [0.2063734473630625, 2.27]
# [0.21203788573174456, 2.07]
# [0.20492721164613661, 2.31]
# [0.19930675909878684, 2.63]
# [0.20637994292702813, 2.33]
# [0.2070999898280948, 2.26]
# [0.20252648736756315, 2.46]
# [0.2144239584394418, 1.89]
# [0.20439739413680783, 2.27]
# [0.20808307034510842, 2.11]
# [0.20350376858830718, 2.41]
# [0.21044078813731465, 2.18]
# [0.2087665647298675, 2.04]
# [0.21355173466273272, 2.01]
# [0.20659049173638033, 2.74]
# [0.2047164057735312, 2.37]
# [0.20595152878617445, 2.56]
# [0.20772602181225155, 2.33]
# [0.20623598940289384, 2.37]
# [0.20307410423452768, 2.75]
# [0.20452230596862905, 2.27]
# ...

# %%
picky_test(200,'NBinom_c:500_p:0.5_s:10000.csv')
# Out:
# [0.09803522345515626, 4.44]
# [0.09183673469387756, 4.88]
# [0.09666259666259666, 4.5]
# [0.0989816700610998, 4.52]
# [0.09629478827361564, 4.7]
# [0.0885586319218241, 5.5]
# [0.10175010175010175, 4.02]
# [0.09855279249898084, 4.72]
# [0.1058427653716733, 3.88]
# [0.09795127917643462, 4.48]
# [0.09531090723751275, 4.24]
# [0.09280553576880024, 5.04]
# [0.10405212787619629, 3.32]
# [0.09766778694368061, 4.52]
# [0.09040008144151482, 4.9]
# [0.09552451829952084, 4.4]
# [0.09814512841418671, 4.04]
# [0.09948123283490998, 4.52]
# [0.10004074979625102, 4.18]
# [0.09565040236324743, 4.32]
# [0.09201954397394137, 5.14]
# [0.09335233635345618, 4.92]
# [0.09003870442045223, 5.04]
# [0.09912654885232582, 4.34]
# [0.1019367991845056, 4.12]
# [0.0972632007325262, 4.48]
# [0.10232605590695776, 3.78]
# [0.10154502947753609, 4.02]
# [0.09908988649146129, 4.2]
# [0.09703394149424116, 4.26]
# [0.10006113715100877, 3.88]
# [0.0989413680781759, 4.46]
# [0.10022407822367081, 4.24]
# ...

# %%
picky_test(500,'NBinom_c:500_p:0.5_s:10000.csv')
# Out:
# [0.043571210424513895, 4.15]
# [0.04295918367346939, 4.0]
# [0.03958078958078958, 5.85]
# [0.04429735234215886, 3.8]
# [0.04499185667752443, 3.95]
# [0.04244706840390879, 5.05]
# [0.043752543752543754, 4.65]
# [0.04229514879739095, 4.4]
# [0.04721117569083308, 3.45]
# [0.039343593925186014, 6.3]
# [0.04067278287461774, 5.35]
# [0.04121298463417116, 4.7]
# [0.04337202199144777, 4.3]
# [0.04307974335472044, 4.35]
# [0.04601445586887916, 3.0]
# [0.04424508104801713, 4.35]
# [0.040766408479412965, 5.45]
# [0.041094496999287966, 5.4]
# [0.042787286063569685, 4.55]
# [0.040440052969338905, 5.0]
# [0.04387214983713355, 3.9]
# [0.04296039906342258, 5.3]
# [0.04430637604400081, 3.8]
# [0.04428194190534227, 4.05]
# [0.04159021406727829, 4.65]
# [0.04405331162885339, 3.7]
# [0.03907365843705366, 6.0]
# [0.04309819068916446, 4.6]
# [0.04161979752530934, 6.0]
# [0.03944552033431862, 6.1]
# [0.04157326268595883, 4.65]
# [0.0440757328990228, 4.5]
# [0.04359339987777552, 4.2]
# ...
