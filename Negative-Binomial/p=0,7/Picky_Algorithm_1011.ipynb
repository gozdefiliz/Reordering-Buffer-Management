# %%
#all necessary side algorithms

#finds the number of color changes in a given list
def nb_of_change(x):
    count=0
    i=0
    while i<(len(x)-1):
        if x[i]!=x[i+1]:
            count=count+1
            i=i+1
        else:
            i=i+1
    return count

#adds k items to the buffer from the input
def add(k, data,buffer):
    while k>0:
        buffer.append(data.pop(0))
        k=k-1
        
#finds and lists the unique items in a given list
def unique(list1): 
    unique_list = [] 
    for x in list1: 
        if x not in unique_list: 
            unique_list.append(x)
    return unique_list

#finds the most freq color in buffer
def most_freq(List): 
    return max(set(List), key = List.count)

#evicts c_act, appends output, removes from buffer, fills buffer till there is no c_act in buffer 
def evict(c_act, data, buffer,output_,k):
    while (c_act in buffer)==True:
        count=0
        buffer.remove(c_act)
        count=count+1
        for i in range(0,count):
            output_.append(c_act)
        while len(buffer)<k and len(data)!=0:
            add(k-len(buffer), data,buffer)
    return output_

#finds the second most frequent color in a given list
def second_most_freq(List): 
    from collections import Counter 
    occurence_count = Counter(List) 
    if len(occurence_count)>=2:
        return occurence_count.most_common(2)[1][0]
    else:
        return -1
    
#finds the occurence of a given color in a given list      
def occurence(List, x): 
    count=0
    for i in range (0, len(List)):
        if List[i]==x:
            count=count+1
    return count


#finds the least freq color in buffer
def least_freq(List): 
    return min(set(List), key = List.count)

# %%
def picky(k,input_):
    import numpy as np
    import math
    buffer=input_[0:0]
    output_=input_[0:0]
    data=input_[:]
    nb_of_delays=0
    c_act=-1
    result=[0]*2
    
    while len(data)!=0:
        ex=0
        while len(buffer)<k and len(data)!=0:
            
            add(min((k-len(buffer)), len(data)), data, buffer)
            
            
            if (c_act!=-1 and (c_act in buffer)==True):
                while (c_act in buffer)==True:
                    buffer.remove(c_act)
                    output_.append(c_act)
                    
                    add(min(1,len(data)), data, buffer)
            else:
                continue
            if len(buffer)==0:
                break
                
            #nb of colors in the buffer is sigma
            sigma=len(unique(buffer))
            #most frequent color in the buffer
            o_1=most_freq(buffer)
            size_of_o1=occurence(buffer,o_1)
        
            
            while (size_of_o1 >= 2 * (math.ceil(len(buffer)/sigma))) and ex<len(data):
                
                delayed=least_freq(buffer)
                while (delayed in buffer)==True:
                    nb_of_delays=nb_of_delays+1
                    ex=ex+1
                    buffer.remove(delayed)
                    data.append(delayed)
                if len(buffer)==0:
                    break
                    
                    
        if len(buffer)!=0:
            c_act=most_freq(buffer)
            while(c_act in buffer)==True:
                buffer.remove(c_act)
                output_.append(c_act)
            
        
    while len(buffer)!=0:
        c_act=most_freq(buffer)
        while (c_act in buffer)==True:
            buffer.remove(c_act)
            output_.append(c_act)
            
    result[0]=float(nb_of_change(output_)/nb_of_change(input_))
    result[1]=float(nb_of_delays/len(input_))
    print(result)

# %%
#reads data from given text and makes test of delay alg.
def picky_test(k,text):
    import pandas as pd
    data=pd.read_csv(text, header=None)

    input_1=(data.iloc[0]).tolist()
    input_2=(data.iloc[1]).tolist()
    input_3=(data.iloc[2]).tolist()
    input_4=(data.iloc[3]).tolist()
    input_5=(data.iloc[4]).tolist()
    input_6=(data.iloc[5]).tolist()
    input_7=(data.iloc[6]).tolist()
    input_8=(data.iloc[7]).tolist()
    input_9=(data.iloc[8]).tolist()
    input_10=(data.iloc[9]).tolist()

    input_11=(data.iloc[10]).tolist()
    input_12=(data.iloc[11]).tolist()
    input_13=(data.iloc[12]).tolist()
    input_14=(data.iloc[13]).tolist()
    input_15=(data.iloc[14]).tolist()
    input_16=(data.iloc[15]).tolist()
    input_17=(data.iloc[16]).tolist()
    input_18=(data.iloc[17]).tolist()
    input_19=(data.iloc[18]).tolist()
    input_20=(data.iloc[19]).tolist()

    input_21=(data.iloc[20]).tolist()
    input_22=(data.iloc[21]).tolist()
    input_23=(data.iloc[22]).tolist()
    input_24=(data.iloc[23]).tolist()
    input_25=(data.iloc[24]).tolist()
    input_26=(data.iloc[25]).tolist()
    input_27=(data.iloc[26]).tolist()
    input_28=(data.iloc[27]).tolist()
    input_29=(data.iloc[28]).tolist()
    input_30=(data.iloc[29]).tolist()

    input_31=(data.iloc[30]).tolist()
    input_32=(data.iloc[31]).tolist()
    input_33=(data.iloc[32]).tolist()
    input_34=(data.iloc[33]).tolist()
    input_35=(data.iloc[34]).tolist()
    input_36=(data.iloc[35]).tolist()
    input_37=(data.iloc[36]).tolist()
    input_38=(data.iloc[37]).tolist()
    input_39=(data.iloc[38]).tolist()
    input_40=(data.iloc[39]).tolist()

    input_41=(data.iloc[40]).tolist()
    input_42=(data.iloc[41]).tolist()
    input_43=(data.iloc[42]).tolist()
    input_44=(data.iloc[43]).tolist()
    input_45=(data.iloc[44]).tolist()
    input_46=(data.iloc[45]).tolist()
    input_47=(data.iloc[46]).tolist()
    input_48=(data.iloc[47]).tolist()
    input_49=(data.iloc[48]).tolist()
    input_50=(data.iloc[49]).tolist()

    picky(k,input_1)
    picky(k,input_2)
    picky(k,input_3)
    picky(k,input_4)
    picky(k,input_5)
    picky(k,input_6)
    picky(k,input_7)
    picky(k,input_8)
    picky(k,input_9)
    picky(k,input_10)

    picky(k,input_11)
    picky(k,input_12)
    picky(k,input_13)
    picky(k,input_14)
    picky(k,input_15)
    picky(k,input_16)
    picky(k,input_17)
    picky(k,input_18)
    picky(k,input_19)
    picky(k,input_20)

    picky(k,input_21)
    picky(k,input_22)
    picky(k,input_23)
    picky(k,input_24)
    picky(k,input_25)
    picky(k,input_26)
    picky(k,input_27)
    picky(k,input_28)
    picky(k,input_29)
    picky(k,input_30)

    picky(k,input_31)
    picky(k,input_32)
    picky(k,input_33)
    picky(k,input_34)
    picky(k,input_35)
    picky(k,input_36)
    picky(k,input_37)
    picky(k,input_38)
    picky(k,input_39)
    picky(k,input_40)

    picky(k,input_41)
    picky(k,input_42)
    picky(k,input_43)
    picky(k,input_44)
    picky(k,input_45)
    picky(k,input_46)
    picky(k,input_47)
    picky(k,input_48)
    picky(k,input_49)
    picky(k,input_50)

# %%
picky_test(10,'NBinom_c:10_p:0.7_s:1000.csv')
# Out:
# [0.3613348676639816, 0.14]
# [0.35870818915801617, 0.11]
# [0.37400228050171036, 0.08]
# [0.3793911007025761, 0.15]
# [0.35017221584385766, 0.17]
# [0.35491329479768785, 0.16]
# [0.37217598097502974, 0.11]
# [0.3620689655172414, 0.1]
# [0.3607305936073059, 0.08]
# [0.3664036076662909, 0.07]
# [0.37657864523536166, 0.1]
# [0.3447488584474886, 0.22]
# [0.36502347417840375, 0.07]
# [0.35206422018348627, 0.2]
# [0.37662337662337664, 0.2]
# [0.3532863849765258, 0.17]
# [0.3832752613240418, 0.13]
# [0.3672055427251732, 0.11]
# [0.358683314415437, 0.18]
# [0.36280137772675086, 0.09]
# [0.35555555555555557, 0.18]
# [0.3504566210045662, 0.15]
# [0.36498855835240274, 0.13]
# [0.384703196347032, 0.07]
# [0.36123853211009177, 0.1]
# [0.3711691259931896, 0.11]
# [0.34772462077012833, 0.2]
# [0.3567318757192175, 0.12]
# [0.3550228310502283, 0.13]
# [0.35630841121495327, 0.15]
# [0.38171428571428573, 0.1]
# [0.35853379152348225, 0.1]
# [0.370242214532872, 0.09]
# [0.34846765039727584, 0.13]
# ...

# %%
picky_test(20,'NBinom_c:10_p:0.7_s:1000.csv')
# Out:
# [0.1714614499424626, 0.82]
# [0.18223760092272204, 0.52]
# [0.19384264538198404, 0.54]
# [0.17447306791569087, 0.62]
# [0.17336394948335246, 0.56]
# [0.19421965317919074, 0.54]
# [0.178359096313912, 0.54]
# [0.167816091954023, 0.76]
# [0.1917808219178082, 0.24]
# [0.17812852311161217, 0.48]
# [0.18140068886337543, 0.4]
# [0.1780821917808219, 0.56]
# [0.1983568075117371, 0.36]
# [0.18922018348623854, 0.46]
# [0.15702479338842976, 0.66]
# [0.18427230046948356, 0.38]
# [0.1753774680603949, 0.56]
# [0.18822170900692842, 0.44]
# [0.18047673098751418, 0.44]
# [0.17106773823191734, 0.56]
# [0.18362573099415205, 0.48]
# [0.1780821917808219, 0.52]
# [0.1945080091533181, 0.34]
# [0.19292237442922375, 0.34]
# [0.16743119266055045, 0.64]
# [0.18047673098751418, 0.44]
# [0.1855309218203034, 0.34]
# [0.1852704257767549, 0.42]
# [0.19292237442922375, 0.28]
# [0.16822429906542055, 0.76]
# [0.176, 0.62]
# [0.17411225658648338, 0.64]
# [0.1845444059976932, 0.46]
# [0.18161180476730987, 0.38]
# ...

# %%
picky_test(50,'NBinom_c:10_p:0.7_s:1000.csv')
# Out:
# [0.0759493670886076, 0.75]
# [0.07497116493656286, 0.65]
# [0.07981755986316989, 0.55]
# [0.06791569086651054, 1.05]
# [0.07347876004592423, 0.65]
# [0.06820809248554913, 0.95]
# [0.06658739595719382, 1.1]
# [0.07816091954022988, 0.5]
# [0.06735159817351598, 0.9]
# [0.06764374295377677, 0.95]
# [0.06544202066590127, 0.8]
# [0.0684931506849315, 0.75]
# [0.07042253521126761, 0.8]
# [0.08256880733944955, 0.55]
# [0.07319952774498228, 0.75]
# [0.07042253521126761, 0.75]
# [0.06155632984901278, 1.1]
# [0.06351039260969978, 1.05]
# [0.06923950056753689, 0.85]
# [0.07692307692307693, 0.5]
# [0.07368421052631578, 0.75]
# [0.06278538812785388, 1.0]
# [0.08237986270022883, 0.4]
# [0.06164383561643835, 1.2]
# [0.0779816513761468, 0.55]
# [0.08172531214528944, 0.4]
# [0.06534422403733955, 1.2]
# [0.07710011507479862, 0.65]
# [0.06963470319634703, 1.1]
# [0.07827102803738317, 0.7]
# [0.07657142857142857, 0.55]
# [0.07560137457044673, 0.7]
# [0.08650519031141868, 0.45]
# ...

# %%
picky_test(10,'NBinom_c:20_p:0.7_s:1000.csv')
# Out:
# [0.527448869752422, 0.01]
# [0.5422993492407809, 0.0]
# [0.516629711751663, 0.02]
# [0.5525164113785558, 0.0]
# [0.5726970033296337, 0.0]
# [0.5702036441586281, 0.01]
# [0.5110132158590308, 0.0]
# [0.5567805953693495, 0.01]
# [0.5298672566371682, 0.03]
# [0.5043478260869565, 0.01]
# [0.5442622950819672, 0.0]
# [0.5447598253275109, 0.0]
# [0.528835690968444, 0.0]
# [0.5388828039430449, 0.0]
# [0.5302530253025303, 0.0]
# [0.5224534501642936, 0.01]
# [0.5755237045203969, 0.0]
# [0.5410733844468785, 0.0]
# [0.5603070175438597, 0.0]
# [0.5458612975391499, 0.0]
# [0.5316863587540279, 0.02]
# [0.5722100656455142, 0.0]
# [0.5110375275938189, 0.0]
# [0.525909592061742, 0.0]
# [0.5147864184008762, 0.01]
# [0.5137211855104281, 0.02]
# [0.5261437908496732, 0.0]
# [0.5, 0.0]
# [0.5181119648737651, 0.0]
# [0.510989010989011, 0.01]
# [0.5223555070883316, 0.01]
# [0.5478547854785478, 0.01]
# [0.5629139072847682, 0.0]
# [0.5527747551686616, 0.01]
# [0.5237068965517241, 0.03]
# ...

# %%
picky_test(20,'NBinom_c:20_p:0.7_s:1000.csv')
# Out:
# [0.24973089343379978, 0.76]
# [0.2592190889370933, 0.8]
# [0.2727272727272727, 0.72]
# [0.24070021881838075, 0.9]
# [0.27192008879023305, 0.58]
# [0.26366559485530544, 0.52]
# [0.2709251101321586, 0.54]
# [0.23814773980154355, 0.98]
# [0.2831858407079646, 0.52]
# [0.24891304347826088, 0.78]
# [0.2612021857923497, 1.0]
# [0.26965065502183405, 0.6]
# [0.2252448313384113, 1.18]
# [0.244249726177437, 0.76]
# [0.2684268426842684, 0.62]
# [0.276013143483023, 0.62]
# [0.24807056229327454, 0.78]
# [0.24644030668127054, 0.76]
# [0.26864035087719296, 0.62]
# [0.28523489932885904, 0.6]
# [0.24489795918367346, 0.96]
# [0.25054704595185995, 0.8]
# [0.2814569536423841, 0.6]
# [0.24807056229327454, 0.7]
# [0.28258488499452356, 0.5]
# [0.2491767288693743, 0.76]
# [0.30610021786492375, 0.4]
# [0.2710583153347732, 0.78]
# [0.2645444566410538, 0.7]
# [0.25934065934065936, 0.84]
# [0.28680479825517996, 0.52]
# [0.2563256325632563, 0.68]
# [0.2869757174392936, 0.38]
# [0.28726877040261156, 0.6]
# ...

# %%
picky_test(50,'NBinom_c:20_p:0.7_s:1000.csv')
# Out:
# [0.08826695371367062, 2.15]
# [0.08568329718004339, 1.95]
# [0.10753880266075388, 1.35]
# [0.08971553610503283, 2.05]
# [0.09988901220865705, 1.65]
# [0.09646302250803858, 1.5]
# [0.09911894273127753, 1.65]
# [0.08269018743109151, 2.15]
# [0.06858407079646017, 2.9]
# [0.08586956521739131, 2.1]
# [0.11038251366120219, 1.3]
# [0.10262008733624454, 1.55]
# [0.08922742110990206, 2.15]
# [0.08652792990142388, 1.9]
# [0.1111111111111111, 1.15]
# [0.08543263964950712, 2.3]
# [0.09040793825799338, 2.35]
# [0.09090909090909091, 2.15]
# [0.10307017543859649, 1.7]
# [0.09284116331096197, 1.65]
# [0.09452201933404941, 2.0]
# [0.08643326039387308, 1.95]
# [0.08498896247240618, 2.45]
# [0.08269018743109151, 2.05]
# [0.09857612267250822, 1.75]
# [0.0889132821075741, 1.7]
# [0.09912854030501089, 1.45]
# [0.10043196544276457, 1.6]
# [0.09549945115257959, 1.75]
# [0.08901098901098901, 2.05]
# [0.1025081788440567, 1.75]
# [0.0968096809680968, 1.75]
# [0.10044150110375276, 1.65]
# ...

# %%
picky_test(10,'NBinom_c:50_p:0.7_s:1000.csv')
# Out:
# [0.586864406779661, 0.0]
# [0.6, 0.01]
# [0.6038135593220338, 0.0]
# [0.5835995740149095, 0.0]
# [0.6263157894736842, 0.0]
# [0.608324439701174, 0.0]
# [0.6182396606574762, 0.0]
# [0.6178947368421053, 0.0]
# [0.6069182389937107, 0.0]
# [0.6074468085106383, 0.0]
# [0.5793901156677181, 0.0]
# [0.5919661733615222, 0.0]
# [0.6136842105263158, 0.0]
# [0.5769644779332616, 0.0]
# [0.6051502145922747, 0.0]
# [0.5982996811902231, 0.0]
# [0.5985247629083246, 0.0]
# [0.5944798301486199, 0.0]
# [0.5997865528281751, 0.0]
# [0.5981210855949896, 0.0]
# [0.582089552238806, 0.0]
# [0.625, 0.0]
# [0.6079484425349087, 0.0]
# [0.6084656084656085, 0.0]
# [0.6184486373165619, 0.0]
# [0.6054564533053515, 0.0]
# [0.5934873949579832, 0.0]
# [0.578556263269639, 0.0]
# [0.5993723849372385, 0.0]
# [0.5870488322717622, 0.0]
# [0.6044303797468354, 0.0]
# [0.5932560590094836, 0.02]
# [0.6261879619852164, 0.0]
# [0.5919661733615222, 0.0]
# [0.6039707419017764, 0.0]
# [0.5741728922091782, 0.01]
# ...

# %%
picky_test(20,'NBinom_c:50_p:0.7_s:1000.csv')
# Out:
# [0.4491525423728814, 0.0]
# [0.4574468085106383, 0.1]
# [0.4703389830508475, 0.0]
# [0.46325878594249204, 0.0]
# [0.47157894736842104, 0.0]
# [0.47705442902881534, 0.0]
# [0.4559915164369035, 0.06]
# [0.45473684210526316, 0.0]
# [0.4716981132075472, 0.0]
# [0.41382978723404257, 0.1]
# [0.4616193480546793, 0.0]
# [0.4608879492600423, 0.02]
# [0.46421052631578946, 0.0]
# [0.4520990312163617, 0.02]
# [0.4366952789699571, 0.08]
# [0.487778958554729, 0.0]
# [0.4731296101159115, 0.02]
# [0.4002123142250531, 0.24]
# [0.4343649946638207, 0.08]
# [0.4572025052192067, 0.0]
# [0.42963752665245203, 0.04]
# [0.4658119658119658, 0.0]
# [0.43071965628356607, 0.06]
# [0.4444444444444444, 0.04]
# [0.44863731656184486, 0.0]
# [0.4700944386149003, 0.0]
# [0.4684873949579832, 0.0]
# [0.440552016985138, 0.02]
# [0.4382845188284519, 0.0]
# [0.4288747346072187, 0.14]
# [0.4525316455696203, 0.02]
# [0.4383561643835616, 0.12]
# [0.4350580781414995, 0.06]
# [0.4249471458773784, 0.12]
# ...

# %%
picky_test(50,'NBinom_c:50_p:0.7_s:1000.csv')
# Out:
# [0.1684322033898305, 1.65]
# [0.2074468085106383, 0.9]
# [0.17478813559322035, 1.6]
# [0.20234291799787008, 0.9]
# [0.17157894736842105, 1.35]
# [0.1728922091782284, 1.5]
# [0.17179215270413573, 1.7]
# [0.17789473684210527, 1.2]
# [0.1761006289308176, 2.1]
# [0.14361702127659576, 1.65]
# [0.15247108307045215, 1.75]
# [0.14059196617336153, 3.0]
# [0.18421052631578946, 1.1]
# [0.13885898815931108, 2.6]
# [0.2092274678111588, 0.65]
# [0.17640807651434645, 1.85]
# [0.18124341412012646, 1.15]
# [0.14861995753715498, 2.05]
# [0.18890074706510138, 0.9]
# [0.1722338204592902, 1.6]
# [0.15884861407249468, 1.95]
# [0.16987179487179488, 1.45]
# [0.15467239527389903, 1.85]
# [0.16507936507936508, 1.45]
# [0.149895178197065, 2.0]
# [0.14900314795383002, 1.85]
# [0.15756302521008403, 2.3]
# [0.13906581740976645, 2.55]
# [0.14958158995815898, 2.05]
# [0.1762208067940552, 1.35]
# [0.16561181434599156, 1.85]
# [0.14436248682824027, 2.4]
# [0.1678986272439282, 1.45]
# [0.20613107822410148, 0.55]
# ...

# %%
picky_test(50,'NBinom_c:50_p:0.7_s:5000.csv')
# Out:
# [0.16090985678180286, 1.82]
# [0.1650010631511801, 1.48]
# [0.16223067173637515, 1.84]
# [0.16024555461473328, 1.72]
# [0.16423280423280423, 1.67]
# [0.1694736842105263, 1.46]
# [0.15358720807910795, 1.8]
# [0.1703157894736842, 1.52]
# [0.15272188095742428, 2.15]
# [0.15783920658366743, 1.86]
# [0.1528421052631579, 1.97]
# [0.15381373788453434, 1.89]
# [0.1678616617460987, 1.49]
# [0.16712386579447142, 1.68]
# [0.16821052631578948, 1.6]
# [0.16209371042634022, 1.61]
# [0.1627661817415138, 1.58]
# [0.16347381864623245, 2.0]
# [0.1555932922946296, 1.94]
# [0.15498849613051663, 1.74]
# [0.16613890648089508, 1.44]
# [0.1511969760604788, 2.16]
# [0.1759899434318039, 1.28]
# [0.15585509688289806, 1.73]
# [0.1615011596036264, 1.48]
# [0.1554524361948956, 1.83]
# [0.15617075232459848, 2.09]
# [0.16398305084745762, 1.59]
# [0.15700737618545837, 1.82]
# [0.16864155734236141, 1.44]
# [0.15839694656488548, 1.88]
# [0.1563092479460712, 1.78]
# [0.1488283723875871, 2.09]
# ...

# %%
picky_test(100,'NBinom_c:50_p:0.7_s:5000.csv')
# Out:
# [0.05812973883740522, 4.18]
# [0.06995534765043589, 2.98]
# [0.06801858893113646, 3.06]
# [0.07070279424216766, 3.12]
# [0.06708994708994709, 3.18]
# [0.0688421052631579, 3.24]
# [0.07006101409636019, 3.24]
# [0.06378947368421052, 3.36]
# [0.07371319635670409, 2.76]
# [0.058662165013715975, 4.14]
# [0.06842105263157895, 3.32]
# [0.07058575642646439, 2.84]
# [0.06474061577393504, 3.28]
# [0.060350284870225784, 4.02]
# [0.06757894736842106, 3.26]
# [0.06352891515407345, 3.84]
# [0.06535947712418301, 3.28]
# [0.07535121328224777, 2.78]
# [0.07004882190617703, 3.16]
# [0.06881405563689605, 3.58]
# [0.06881992822461473, 3.32]
# [0.0743385132297354, 2.5]
# [0.07186256023465326, 3.06]
# [0.05539174389216512, 3.9]
# [0.059666877503689646, 3.62]
# [0.06918371651550306, 3.24]
# [0.06424344885883347, 3.78]
# [0.06567796610169492, 3.5]
# [0.07017913593256059, 3.1]
# [0.06728734659331359, 3.2]
# [0.07951653944020357, 2.42]
# [0.06467242468927743, 3.3]
# [0.07135317711631835, 3.08]
# ...

# %%
picky_test(250,'NBinom_c:50_p:0.7_s:5000.csv')
# Out:
# [0.02316764953664701, 4.55]
# [0.02551562832234744, 4.3]
# [0.02260245035910435, 4.65]
# [0.030059271803556307, 3.35]
# [0.02306878306878307, 4.55]
# [0.02926315789473684, 3.35]
# [0.02966547443719756, 3.2]
# [0.02568421052631579, 4.1]
# [0.022029231095106967, 4.8]
# [0.026376872757965814, 3.9]
# [0.028210526315789474, 3.2]
# [0.02465233881163085, 4.4]
# [0.030366933783213833, 3.5]
# [0.027431947668284447, 3.55]
# [0.027789473684210527, 4.35]
# [0.025116082735331363, 4.25]
# [0.029306346194391736, 3.3]
# [0.03022562792677735, 3.45]
# [0.030354489492676714, 2.95]
# [0.024681029073415604, 4.15]
# [0.027021321511505172, 3.8]
# [0.028559428811423773, 3.5]
# [0.028493609888958726, 3.4]
# [0.02358887952822241, 4.7]
# [0.0290955091714105, 3.0]
# [0.025311115798354777, 3.95]
# [0.023668639053254437, 4.5]
# [0.029449152542372882, 3.65]
# [0.028029504741833508, 3.75]
# [0.02687261955141769, 4.15]
# [0.03244274809160305, 2.7]
# [0.02591110174847272, 3.85]
# [0.027021321511505172, 4.15]
# ...

# %%
picky_test(50,'NBinom_c:100_p:0.7_s:5000.csv')
# Out:
# [0.23174273858921163, 1.23]
# [0.21307405875051716, 1.57]
# [0.21864021492043811, 1.73]
# [0.22530220925385577, 1.38]
# [0.22113380575239683, 1.48]
# [0.22076570952975447, 1.38]
# [0.21696743414229414, 1.62]
# [0.21059216013344453, 1.62]
# [0.23985853962970669, 1.07]
# [0.21058091286307054, 1.63]
# [0.2208307242746817, 1.39]
# [0.21715706589307915, 1.68]
# [0.21973929236499068, 1.44]
# [0.21943118123313265, 1.64]
# [0.21817429103705238, 1.6]
# [0.21296871762999792, 1.91]
# [0.21653543307086615, 1.74]
# [0.22367059797227395, 1.31]
# [0.22947061275531472, 1.34]
# [0.21638394704178734, 1.7]
# [0.21315570358034971, 1.85]
# [0.22272915802571547, 1.51]
# [0.2239950269374223, 1.57]
# [0.21584984358706985, 1.66]
# [0.21079851055026894, 1.75]
# [0.21744548286604362, 1.52]
# [0.21564526249738547, 1.8]
# [0.21753515301902399, 1.68]
# [0.21118909991742363, 1.64]
# [0.22284527518172378, 1.41]
# [0.213604313562837, 1.9]
# [0.22577276524644946, 1.32]
# [0.23140839218944745, 1.17]
# ...

# %%
picky_test(100,'NBinom_c:100_p:0.7_s:5000.csv')
# Out:
# [0.1053941908713693, 2.82]
# [0.0990897807199007, 2.94]
# [0.10146724529861542, 3.34]
# [0.09253855773238849, 4.0]
# [0.09649854105877449, 3.76]
# [0.10445276737411568, 2.76]
# [0.10184609002281685, 2.96]
# [0.10758965804837364, 2.5]
# [0.11212814645308924, 2.42]
# [0.10062240663900415, 3.0]
# [0.11292005844291379, 2.16]
# [0.1027766266058848, 3.22]
# [0.10717980550382784, 2.88]
# [0.1027610545982977, 3.34]
# [0.10701718070792797, 2.88]
# [0.09612595815206132, 3.78]
# [0.10464152507252383, 3.0]
# [0.09869646182495345, 3.0]
# [0.0948311796581909, 3.46]
# [0.09867604468349193, 3.06]
# [0.1017901748542881, 2.74]
# [0.10369141435089174, 3.22]
# [0.11065064235391629, 2.74]
# [0.1032325338894682, 3.16]
# [0.10591642532064542, 3.04]
# [0.10259605399792315, 3.34]
# [0.10290734156034302, 3.08]
# [0.10525227460711331, 2.92]
# [0.10838150289017341, 2.8]
# [0.1102803738317757, 2.9]
# [0.09954375777685608, 3.78]
# [0.09377610693400167, 3.7]
# [0.10573327793934358, 3.14]
# ...

# %%
picky_test(250,'NBinom_c:100_p:0.7_s:5000.csv')
# Out:
# [0.03921161825726141, 4.1]
# [0.03847745138601572, 4.1]
# [0.04298408762140938, 3.65]
# [0.03939141308878699, 4.2]
# [0.03939141308878699, 4.5]
# [0.039950062421972535, 3.7]
# [0.03754407799211782, 4.75]
# [0.04190992493744787, 4.0]
# [0.04618265030164344, 3.1]
# [0.03858921161825726, 4.65]
# [0.03861406804424963, 4.15]
# [0.03833402403646913, 4.55]
# [0.03951996689426857, 4.1]
# [0.040066431388831224, 4.2]
# [0.043469261022562614, 3.55]
# [0.043919618810855605, 3.65]
# [0.03874844591794447, 4.6]
# [0.03993378853714049, 4.35]
# [0.040225093789078785, 3.9]
# [0.04323541580471659, 3.3]
# [0.04288093255620316, 3.35]
# [0.042928245541269186, 3.55]
# [0.04144218814753419, 4.35]
# [0.038790406673618355, 4.55]
# [0.03992552751344642, 4.05]
# [0.035306334371754934, 5.2]
# [0.04204141393014014, 3.35]
# [0.04032258064516129, 3.7]
# [0.04314616019818332, 3.3]
# [0.04319833852544133, 3.2]
# [0.04168394856905848, 4.15]
# [0.037385129490392646, 4.95]
# [0.04424594931449938, 3.4]
# ...

# %%
picky_test(50,'NBinom_c:250_p:0.7_s:5000.csv')
# Out:
# [0.4180110271594854, 0.11]
# [0.4149590163934426, 0.02]
# [0.38639149979566817, 0.5]
# [0.44089325957795533, 0.01]
# [0.4519033974621367, 0.0]
# [0.41216355044175057, 0.08]
# [0.4188578471651602, 0.35]
# [0.42216304793117576, 0.09]
# [0.44317018226500104, 0.0]
# [0.44099632503062475, 0.0]
# [0.44884150092269837, 0.0]
# [0.43526283493556966, 0.04]
# [0.4144346759353915, 0.22]
# [0.4532786885245902, 0.0]
# [0.4462354621505815, 0.0]
# [0.40290269828291086, 0.17]
# [0.43423202614379086, 0.0]
# [0.4298245614035088, 0.25]
# [0.42258986928104575, 0.16]
# [0.4172986267677803, 0.11]
# [0.41744993870044955, 0.07]
# [0.4302707136997539, 0.05]
# [0.40310394118848275, 0.28]
# [0.39300327332242224, 0.25]
# [0.42318663406682966, 0.13]
# [0.4528533442421763, 0.0]
# [0.3725168953512185, 0.62]
# [0.3952965235173824, 0.47]
# [0.4367438999384868, 0.09]
# [0.4077868852459016, 0.01]
# [0.40871878837494885, 0.18]
# [0.4283374283374283, 0.02]
# [0.39350622830304266, 0.13]
# [0.43213920163766634, 0.1]
# ...

# %%
picky_test(100,'NBinom_c:250_p:0.7_s:5000.csv')
# Out:
# [0.17868082499489482, 2.18]
# [0.17418032786885246, 2.38]
# [0.17143440948099714, 2.2]
# [0.18828108994058596, 1.8]
# [0.1774457634056488, 2.14]
# [0.17444010684199712, 2.16]
# [0.17953985209531634, 2.28]
# [0.18230233510856206, 2.3]
# [0.16854392791316813, 2.38]
# [0.16843609636586362, 2.6]
# [0.17777322124256714, 2.46]
# [0.16792800163632646, 2.96]
# [0.18217133510529543, 1.92]
# [0.1831967213114754, 2.04]
# [0.17873903285043868, 2.42]
# [0.19276369582992642, 1.62]
# [0.17258986928104575, 2.24]
# [0.17197062423500611, 2.6]
# [0.18075980392156862, 2.3]
# [0.15966386554621848, 3.38]
# [0.18205966489579076, 2.18]
# [0.17739950779327318, 2.28]
# [0.19215846436593834, 1.64]
# [0.16796235679214402, 2.78]
# [0.16666666666666666, 2.74]
# [0.14972386991204745, 3.9]
# [0.188613557239402, 2.26]
# [0.19120654396728015, 2.08]
# [0.18864055771990978, 1.98]
# [0.17274590163934425, 2.4]
# [0.1641424478100696, 3.06]
# [0.16564291564291564, 2.88]
# [0.17459669185215437, 2.44]
# ...

# %%
picky_test(250,'NBinom_c:250_p:0.7_s:5000.csv')
# Out:
# [0.07065550336940984, 3.4]
# [0.05963114754098361, 5.3]
# [0.06456885982836126, 4.1]
# [0.06699446834665028, 3.55]
# [0.06467458043389275, 3.65]
# [0.06841997123484693, 4.15]
# [0.06450287592440428, 4.7]
# [0.06534207292093404, 4.6]
# [0.06717182060208889, 3.45]
# [0.06737443854634545, 4.4]
# [0.06602419520196842, 3.8]
# [0.06893025158519124, 4.1]
# [0.06992435084849724, 3.65]
# [0.0680327868852459, 4.4]
# [0.06631299734748011, 4.05]
# [0.05703188879803761, 5.6]
# [0.07066993464052287, 3.35]
# [0.07547939616483068, 3.25]
# [0.06270424836601307, 4.85]
# [0.06722689075630252, 4.95]
# [0.060073559460563954, 4.55]
# [0.05906480721903199, 5.4]
# [0.06738819685521748, 3.9]
# [0.06771685761047463, 3.75]
# [0.06132844335778321, 5.4]
# [0.06586213949682962, 4.7]
# [0.06655744419414295, 4.85]
# [0.06625766871165645, 4.05]
# [0.06581915111749026, 4.55]
# [0.06987704918032787, 3.75]
# [0.058125255832992224, 6.0]
# [0.06695331695331695, 4.3]
# [0.06861343679803962, 3.65]
# ...

# %%
picky_test(100,'NBinom_c:100_p:0.7_s:10000.csv')
# Out:
# [0.0999687922604806, 3.25]
# [0.0999168226242462, 3.01]
# [0.0912884715701617, 3.51]
# [0.10120783007080383, 3.19]
# [0.10428748964374482, 2.66]
# [0.10128817785165177, 3.01]
# [0.09977135730617336, 3.28]
# [0.10150336962156557, 3.24]
# [0.10455346955709989, 3.02]
# [0.10271056184442828, 3.04]
# [0.09991699522722557, 3.32]
# [0.09968911917098446, 3.18]
# [0.10156087408949012, 3.18]
# [0.10288321924911845, 3.03]
# [0.09692499480573447, 3.25]
# [0.09125750984048063, 3.72]
# [0.10326933056564608, 2.64]
# [0.09775524981897175, 3.21]
# [0.09382459782044629, 3.53]
# [0.10335863574919414, 2.82]
# [0.10194528243004265, 2.87]
# [0.10892320447714789, 2.72]
# [0.10072614107883818, 3.06]
# [0.09902225920532556, 3.38]
# [0.09542143600416234, 3.63]
# [0.09727140179129348, 3.42]
# [0.09886917730054985, 3.08]
# [0.10374909128673798, 2.73]
# [0.0960539979231568, 3.39]
# [0.09892741851504738, 3.11]
# [0.10238341968911917, 2.94]
# [0.10593351972662317, 2.94]
# [0.100859480169825, 3.14]
# ...

# %%
picky_test(200,'NBinom_c:100_p:0.7_s:10000.csv')
# Out:
# [0.05149277020701134, 3.14]
# [0.04793096277812435, 3.98]
# [0.048826291079812206, 3.6]
# [0.04862557267805081, 4.14]
# [0.045049710024855014, 4.28]
# [0.04809889881570746, 4.2]
# [0.04957389316150489, 3.76]
# [0.04800414722654225, 3.78]
# [0.04470490613006949, 4.46]
# [0.04538373662893343, 4.32]
# [0.049906619630628764, 3.74]
# [0.04683937823834197, 4.2]
# [0.049427679500520294, 3.72]
# [0.045322547189379794, 4.36]
# [0.043424059837938914, 4.66]
# [0.04868448311580692, 3.88]
# [0.04909185262065387, 3.82]
# [0.046136340126202546, 3.74]
# [0.04348728593668916, 4.58]
# [0.0457523136113133, 4.36]
# [0.04483511910953917, 4.08]
# [0.05047155145610944, 3.76]
# [0.04968879668049792, 3.6]
# [0.044102350738506345, 4.86]
# [0.04734651404786681, 4.34]
# [0.04936471568423245, 3.6]
# [0.04793028322440087, 3.92]
# [0.04476061896354762, 4.22]
# [0.04849428868120457, 3.68]
# [0.04300739352285744, 4.62]
# [0.0489119170984456, 3.78]
# [0.044009526768147456, 4.9]
# [0.04556280418349384, 4.22]
# ...

# %%
picky_test(500,'NBinom_c:100_p:0.7_s:10000.csv')
# Out:
# [0.019556850098824508, 4.2]
# [0.021418174256602203, 4.45]
# [0.01836202399582681, 5.4]
# [0.021449396084964597, 3.95]
# [0.01967688483844242, 4.7]
# [0.02067317681279867, 4.5]
# [0.022760340885470798, 3.75]
# [0.02208398133748056, 3.25]
# [0.02022611762265325, 4.15]
# [0.02336691245196801, 3.7]
# [0.021166217057480806, 3.7]
# [0.018963730569948187, 4.5]
# [0.020187304890738812, 4.85]
# [0.0213648620618129, 3.95]
# [0.021088718055266985, 4.0]
# [0.019266625233064015, 4.9]
# [0.020965230928905034, 4.3]
# [0.01996482879900693, 4.5]
# [0.019719771665801765, 3.95]
# [0.01944473328480815, 4.3]
# [0.0230937272443566, 3.35]
# [0.020623898849621722, 4.1]
# [0.02199170124481328, 4.05]
# [0.01997087580611608, 4.5]
# [0.02206035379812695, 3.9]
# [0.021349718808581546, 4.3]
# [0.01815541031227306, 5.1]
# [0.02191297123273445, 3.65]
# [0.020976116303219106, 3.8]
# [0.021139227324794334, 4.1]
# [0.02155440414507772, 4.25]
# [0.019157088122605363, 4.9]
# [0.019881950916433674, 4.25]
# ...

# %%
picky_test(100,'NBinom_c:200_p:0.7_s:10000.csv')
# Out:
# [0.14350143501435014, 3.01]
# [0.15709598031173092, 2.61]
# [0.1452094267778121, 2.66]
# [0.14638920366745647, 3.14]
# [0.1517793046866988, 2.64]
# [0.15073679901760131, 2.69]
# [0.14006782447847085, 3.29]
# [0.14653933045799958, 3.24]
# [0.13790272932485123, 3.38]
# [0.13869810353664788, 3.1]
# [0.145702844234521, 2.93]
# [0.14564102564102563, 2.94]
# [0.14919396241913954, 2.79]
# [0.15494257588187038, 2.64]
# [0.1496507806080526, 2.97]
# [0.14897119341563786, 2.85]
# [0.1361675908810844, 3.24]
# [0.14348672747770833, 3.06]
# [0.1494665572425113, 2.75]
# [0.1411728521632151, 2.97]
# [0.14297461198478775, 2.8]
# [0.1332306111967129, 3.17]
# [0.14880707527766351, 2.75]
# [0.13852769530050169, 3.33]
# [0.14583547293827667, 3.12]
# [0.14265188834154352, 3.22]
# [0.13617196338578627, 3.36]
# [0.14566888774987186, 3.0]
# [0.14586125141737966, 3.19]
# [0.14608820808060038, 3.04]
# [0.14316480360988618, 3.02]
# [0.14092307692307693, 3.35]
# [0.13425641025641025, 3.55]
# ...

# %%
picky_test(200,'NBinom_c:200_p:0.7_s:10000.csv')
# Out:
# [0.06467814678146781, 4.9]
# [0.06316652994257588, 4.82]
# [0.06864258516002882, 4.14]
# [0.07025857628515504, 4.1]
# [0.06532663316582915, 4.86]
# [0.06569791240278346, 4.64]
# [0.06998253005857569, 3.98]
# [0.06602998562333127, 4.52]
# [0.06710445310896779, 4.9]
# [0.06663249615581752, 4.56]
# [0.06581784577472019, 4.34]
# [0.06994871794871795, 4.3]
# [0.06684464524078447, 4.6]
# [0.07095980311730928, 4.16]
# [0.06984387838948233, 4.2]
# [0.0661522633744856, 4.42]
# [0.06859724789484493, 4.18]
# [0.06456902736496874, 5.06]
# [0.06483381206401313, 4.64]
# [0.0688948123846627, 4.32]
# [0.06783842121492445, 4.18]
# [0.06543400102722137, 4.5]
# [0.06972439325380501, 4.24]
# [0.07166990887683014, 3.52]
# [0.0682961897915169, 4.44]
# [0.06927339901477833, 4.04]
# [0.0697315643319963, 3.96]
# [0.065504869297796, 4.6]
# [0.0708174415008762, 4.12]
# [0.07052534183201398, 3.72]
# [0.06994154445697877, 3.66]
# [0.06615384615384616, 4.44]
# [0.06574358974358975, 4.76]
# ...

# %%
picky_test(500,'NBinom_c:200_p:0.7_s:10000.csv')
# Out:
# [0.02952029520295203, 4.5]
# [0.028609515996718623, 5.25]
# [0.03334362457548626, 3.35]
# [0.0304934583290409, 4.75]
# [0.032817146959286225, 3.65]
# [0.03131395824805567, 3.95]
# [0.029390607337375398, 4.7]
# [0.030499075785582256, 4.1]
# [0.03129489021136877, 3.95]
# [0.031368528959507945, 3.75]
# [0.03152274360817332, 4.5]
# [0.030564102564102563, 3.9]
# [0.02977718451586405, 4.1]
# [0.031378178835110744, 4.65]
# [0.02804026294165982, 5.3]
# [0.02911522633744856, 4.8]
# [0.029574861367837338, 5.2]
# [0.028697345495541662, 4.8]
# [0.027595404185473942, 5.05]
# [0.028398605700225548, 4.15]
# [0.02744372494603762, 5.0]
# [0.0315356959424756, 3.9]
# [0.029823118058412177, 4.4]
# [0.030203747312378418, 4.55]
# [0.030707610146862484, 4.35]
# [0.031198686371100164, 4.3]
# [0.027357811375089993, 5.55]
# [0.0292157867760123, 4.1]
# [0.03236779713431605, 4.25]
# [0.02960830677495631, 4.15]
# [0.02830478925238437, 5.8]
# [0.03107692307692308, 4.15]
# [0.030256410256410255, 3.85]
# ...

# %%
picky_test(100,'NBinom_c:500_p:0.7_s:10000.csv')
# Out:
# [0.2034191513177979, 3.74]
# [0.22173558769606844, 2.72]
# [0.23297709923664123, 2.47]
# [0.2296665311102074, 2.31]
# [0.23147208121827412, 2.57]
# [0.23999187157081894, 2.19]
# [0.22693520496388975, 2.37]
# [0.22094676960585127, 2.66]
# [0.21061730906132412, 3.09]
# [0.22270831213755213, 2.87]
# [0.22204148027653517, 2.8]
# [0.22365613250685906, 2.73]
# [0.23784387371840424, 2.07]
# [0.22815583358763097, 2.48]
# [0.23408582468985153, 2.26]
# [0.22331674621712197, 2.62]
# [0.22797032218721414, 2.52]
# [0.23858900071159905, 2.47]
# [0.22433421427119332, 2.57]
# [0.2255669683718092, 2.72]
# [0.22393822393822393, 2.57]
# [0.21808564744176584, 2.65]
# [0.23784387371840424, 2.25]
# [0.20923857868020304, 3.07]
# [0.2256326862486025, 2.88]
# [0.2162738724095896, 2.98]
# [0.22564571893430954, 2.56]
# [0.23620847302651632, 2.11]
# [0.20928338762214985, 3.27]
# [0.213755968708727, 2.88]
# [0.23115986187284177, 2.39]
# [0.2158652870764861, 2.83]
# [0.23014339469134548, 2.46]
# ...

# %%
picky_test(200,'NBinom_c:500_p:0.7_s:10000.csv')
# Out:
# [0.10715376004884501, 4.72]
# [0.10918720717050316, 4.28]
# [0.11206106870229007, 4.18]
# [0.10492069947132981, 4.7]
# [0.10964467005076142, 4.48]
# [0.10577118471855314, 4.9]
# [0.11189095717627912, 4.08]
# [0.10991466883380739, 4.24]
# [0.10830875622902471, 4.5]
# [0.11018414894699359, 4.3]
# [0.11142740951606345, 4.5]
# [0.1115740270297734, 4.12]
# [0.10993807735255304, 3.76]
# [0.10456718543383176, 4.66]
# [0.10972137482204597, 4.58]
# [0.11049050472225043, 4.58]
# [0.10488870820205305, 4.56]
# [0.10806140083358748, 4.74]
# [0.10977841024598496, 4.34]
# [0.10810535950371199, 4.82]
# [0.1016053647632595, 5.5]
# [0.11219611433221442, 4.34]
# [0.10861841437417522, 4.18]
# [0.10730964467005076, 4.48]
# [0.11139343429210286, 4.4]
# [0.10656237301909793, 4.52]
# [0.1114500711816148, 4.14]
# [0.10809712486030681, 4.76]
# [0.10331840390879479, 5.04]
# [0.11155135629381287, 4.0]
# [0.10582977859029047, 4.9]
# [0.10225197808886184, 4.84]
# [0.10586799552527204, 4.6]
# ...

# %%
picky_test(500,'NBinom_c:500_p:0.7_s:10000.csv')
# Out:
# [0.048743258369797496, 4.15]
# [0.044000814829904256, 5.65]
# [0.046412213740458015, 5.4]
# [0.04503863359089061, 4.95]
# [0.04751269035532995, 5.0]
# [0.0476529160739687, 4.8]
# [0.045773573390296, 4.85]
# [0.044798862251117434, 5.7]
# [0.04861181734974067, 4.0]
# [0.04751246311934073, 5.1]
# [0.04656364375762505, 5.0]
# [0.046844832842190834, 4.85]
# [0.04781240483199675, 5.0]
# [0.04831654968975689, 4.8]
# [0.04738661785641651, 4.7]
# [0.04610541281608612, 5.1]
# [0.04563471897550564, 5.05]
# [0.04798210836637186, 4.45]
# [0.04391136409839398, 4.95]
# [0.05013729278958609, 4.6]
# [0.04836415362731152, 4.7]
# [0.04780795442986471, 4.65]
# [0.043244340676073495, 6.75]
# [0.04568527918781726, 5.05]
# [0.048073991259274314, 5.1]
# [0.04581470946769606, 5.15]
# [0.047895057962172055, 4.0]
# [0.046124149141521895, 5.6]
# [0.03980048859934853, 6.7]
# [0.0454129838463883, 5.05]
# [0.048039813122080034, 4.6]
# [0.0426049908703591, 6.05]
# [0.04545916810739347, 5.95]
# ...
