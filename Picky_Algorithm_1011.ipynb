# %%
#all necessary side algorithms

#finds the number of color changes in a given list
def nb_of_change(x):
    count=0
    i=0
    while i<(len(x)-1):
        if x[i]!=x[i+1]:
            count=count+1
            i=i+1
        else:
            i=i+1
    return count

#adds k items to the buffer from the input
def add(k, data,buffer):
    while k>0:
        buffer.append(data.pop(0))
        k=k-1
        
#finds and lists the unique items in a given list
def unique(list1): 
    unique_list = [] 
    for x in list1: 
        if x not in unique_list: 
            unique_list.append(x)
    return unique_list

#finds the most freq color in buffer
def most_freq(List): 
    return max(set(List), key = List.count)

#evicts c_act, appends output, removes from buffer, fills buffer till there is no c_act in buffer 
def evict(c_act, data, buffer,output_,k):
    while (c_act in buffer)==True:
        count=0
        buffer.remove(c_act)
        count=count+1
        for i in range(0,count):
            output_.append(c_act)
        while len(buffer)<k and len(data)!=0:
            add(k-len(buffer), data,buffer)
    return output_

#finds the second most frequent color in a given list
def second_most_freq(List): 
    from collections import Counter 
    occurence_count = Counter(List) 
    if len(occurence_count)>=2:
        return occurence_count.most_common(2)[1][0]
    else:
        return -1
    
#finds the occurence of a given color in a given list      
def occurence(List, x): 
    count=0
    for i in range (0, len(List)):
        if List[i]==x:
            count=count+1
    return count


#finds the least freq color in buffer
def least_freq(List): 
    return min(set(List), key = List.count)

# %%
def picky(k,input_):
    import numpy as np
    import math
    buffer=input_[0:0]
    output_=input_[0:0]
    data=input_[:]
    nb_of_delays=0
    c_act=-1
    result=[0]*2
    

    while len(data)!=0:
        ex=0
        while len(buffer)<k and len(data)!=0:

            add(min((k-len(buffer)), len(data)), data, buffer)
            

            if (c_act!=-1 and (c_act in buffer)==True):
                while (c_act in buffer)==True:
                    buffer.remove(c_act)
                    output_.append(c_act)

                    add(min(1,len(data)), data, buffer)
            else:
                continue
            if len(buffer)==0:
                break
                
            #nb of colors in the buffer is sigma
            sigma=len(unique(buffer))
            #most frequent color in the buffer
            o_1=most_freq(buffer)
            size_of_o1=occurence(buffer,o_1)
        

            while (size_of_o1 >= 2 * (math.ceil(len(buffer)/sigma))) and ex<len(data):

                delayed=least_freq(buffer)
                while (delayed in buffer)==True:
                    nb_of_delays=nb_of_delays+1
                    ex=ex+1
                    buffer.remove(delayed)
                    data.append(delayed)
                if len(buffer)==0:
                    break
                    
                    

        if len(buffer)!=0:
            c_act=most_freq(buffer)
            while(c_act in buffer)==True:
                buffer.remove(c_act)
                output_.append(c_act)
            

    while len(buffer)!=0:
        c_act=most_freq(buffer)
        while (c_act in buffer)==True:
            buffer.remove(c_act)
            output_.append(c_act)
            
    result[0]=float(nb_of_change(output_)/nb_of_change(input_))
    result[1]=float(nb_of_delays/len(input_))
    print(result)

# %%
#reads data from given text and makes test of delay alg.
def picky_test(k,text):
    import pandas as pd
    data=pd.read_csv(text, header=None)

    input_1=(data.iloc[0]).tolist()
    input_2=(data.iloc[1]).tolist()
    input_3=(data.iloc[2]).tolist()
    input_4=(data.iloc[3]).tolist()
    input_5=(data.iloc[4]).tolist()
    input_6=(data.iloc[5]).tolist()
    input_7=(data.iloc[6]).tolist()
    input_8=(data.iloc[7]).tolist()
    input_9=(data.iloc[8]).tolist()
    input_10=(data.iloc[9]).tolist()

    input_11=(data.iloc[10]).tolist()
    input_12=(data.iloc[11]).tolist()
    input_13=(data.iloc[12]).tolist()
    input_14=(data.iloc[13]).tolist()
    input_15=(data.iloc[14]).tolist()
    input_16=(data.iloc[15]).tolist()
    input_17=(data.iloc[16]).tolist()
    input_18=(data.iloc[17]).tolist()
    input_19=(data.iloc[18]).tolist()
    input_20=(data.iloc[19]).tolist()

    input_21=(data.iloc[20]).tolist()
    input_22=(data.iloc[21]).tolist()
    input_23=(data.iloc[22]).tolist()
    input_24=(data.iloc[23]).tolist()
    input_25=(data.iloc[24]).tolist()
    input_26=(data.iloc[25]).tolist()
    input_27=(data.iloc[26]).tolist()
    input_28=(data.iloc[27]).tolist()
    input_29=(data.iloc[28]).tolist()
    input_30=(data.iloc[29]).tolist()

    input_31=(data.iloc[30]).tolist()
    input_32=(data.iloc[31]).tolist()
    input_33=(data.iloc[32]).tolist()
    input_34=(data.iloc[33]).tolist()
    input_35=(data.iloc[34]).tolist()
    input_36=(data.iloc[35]).tolist()
    input_37=(data.iloc[36]).tolist()
    input_38=(data.iloc[37]).tolist()
    input_39=(data.iloc[38]).tolist()
    input_40=(data.iloc[39]).tolist()

    input_41=(data.iloc[40]).tolist()
    input_42=(data.iloc[41]).tolist()
    input_43=(data.iloc[42]).tolist()
    input_44=(data.iloc[43]).tolist()
    input_45=(data.iloc[44]).tolist()
    input_46=(data.iloc[45]).tolist()
    input_47=(data.iloc[46]).tolist()
    input_48=(data.iloc[47]).tolist()
    input_49=(data.iloc[48]).tolist()
    input_50=(data.iloc[49]).tolist()

    picky(k,input_1)
    picky(k,input_2)
    picky(k,input_3)
    picky(k,input_4)
    picky(k,input_5)
    picky(k,input_6)
    picky(k,input_7)
    picky(k,input_8)
    picky(k,input_9)
    picky(k,input_10)

    picky(k,input_11)
    picky(k,input_12)
    picky(k,input_13)
    picky(k,input_14)
    picky(k,input_15)
    picky(k,input_16)
    picky(k,input_17)
    picky(k,input_18)
    picky(k,input_19)
    picky(k,input_20)

    picky(k,input_21)
    picky(k,input_22)
    picky(k,input_23)
    picky(k,input_24)
    picky(k,input_25)
    picky(k,input_26)
    picky(k,input_27)
    picky(k,input_28)
    picky(k,input_29)
    picky(k,input_30)

    picky(k,input_31)
    picky(k,input_32)
    picky(k,input_33)
    picky(k,input_34)
    picky(k,input_35)
    picky(k,input_36)
    picky(k,input_37)
    picky(k,input_38)
    picky(k,input_39)
    picky(k,input_40)

    picky(k,input_41)
    picky(k,input_42)
    picky(k,input_43)
    picky(k,input_44)
    picky(k,input_45)
    picky(k,input_46)
    picky(k,input_47)
    picky(k,input_48)
    picky(k,input_49)
    picky(k,input_50)

# %%
picky_test(10,'Binom_c:10_p:0.3_s:1000.csv')
# Out:
# [0.2630241423125794, 0.3]
# [0.25738916256157635, 0.36]
# [0.22875, 0.35]
# [0.24433249370277077, 0.34]
# [0.26282853566958697, 0.23]
# [0.25753768844221103, 0.29]
# [0.25031446540880503, 0.24]
# [0.23934837092731828, 0.3]
# [0.2588957055214724, 0.25]
# [0.24967490247074123, 0.41]
# [0.2400990099009901, 0.24]
# [0.2344139650872818, 0.31]
# [0.26717557251908397, 0.29]
# [0.2531969309462916, 0.3]
# [0.2546353522867738, 0.35]
# [0.2728442728442728, 0.2]
# [0.23337515683814303, 0.39]
# [0.2421185372005044, 0.29]
# [0.2310513447432763, 0.32]
# [0.25710754017305315, 0.19]
# [0.24714828897338403, 0.2]
# [0.23484848484848486, 0.35]
# [0.2503176620076239, 0.28]
# [0.2645962732919255, 0.23]
# [0.2398477157360406, 0.39]
# [0.23918575063613232, 0.25]
# [0.2506234413965087, 0.26]
# [0.25318066157760816, 0.33]
# [0.24436090225563908, 0.31]
# [0.2396486825595985, 0.44]
# [0.2475609756097561, 0.3]
# [0.2506297229219144, 0.29]
# [0.24528301886792453, 0.27]
# [0.2610340479192938, 0.25]
# ...

# %%
picky_test(20,'Binom_c:10_p:0.3_s:1000.csv')
# Out:
# [0.09783989834815757, 0.98]
# [0.10714285714285714, 0.94]
# [0.12, 0.58]
# [0.10201511335012595, 0.82]
# [0.11389236545682102, 0.7]
# [0.11055276381909548, 0.76]
# [0.10817610062893082, 0.74]
# [0.11654135338345864, 0.58]
# [0.1116564417177914, 0.6]
# [0.10923276983094929, 0.78]
# [0.10767326732673267, 0.76]
# [0.11596009975062344, 0.74]
# [0.11450381679389313, 0.76]
# [0.11508951406649616, 0.76]
# [0.12360939431396786, 0.66]
# [0.11454311454311454, 0.68]
# [0.12296110414052698, 0.64]
# [0.11979823455233292, 0.7]
# [0.09657701711491443, 0.9]
# [0.13226205191594562, 0.46]
# [0.11280101394169835, 0.62]
# [0.10353535353535354, 0.86]
# [0.11308767471410419, 0.72]
# [0.12298136645962733, 0.54]
# [0.1116751269035533, 0.58]
# [0.1183206106870229, 0.62]
# [0.13216957605985039, 0.58]
# [0.12340966921119594, 0.6]
# [0.11654135338345864, 0.8]
# [0.11417816813048934, 0.68]
# [0.1024390243902439, 0.88]
# [0.13602015113350127, 0.5]
# [0.13081761006289308, 0.56]
# [0.13745271122320302, 0.34]
# ...

# %%
picky_test(50,'Binom_c:10_p:0.3_s:1000.csv')
# Out:
# [0.03811944091486658, 1.0]
# [0.04310344827586207, 1.05]
# [0.03625, 1.15]
# [0.031486146095717885, 1.2]
# [0.0425531914893617, 1.2]
# [0.04396984924623116, 0.9]
# [0.042767295597484274, 1.1]
# [0.042606516290726815, 1.3]
# [0.04539877300613497, 0.95]
# [0.05981794538361508, 0.7]
# [0.0297029702970297, 1.4]
# [0.03865336658354115, 1.2]
# [0.05343511450381679, 0.75]
# [0.028132992327365727, 1.55]
# [0.042027194066749075, 0.9]
# [0.05276705276705277, 0.6]
# [0.03889585947302384, 1.05]
# [0.04665825977301387, 0.8]
# [0.04523227383863081, 0.8]
# [0.04326328800988875, 1.05]
# [0.035487959442332066, 1.4]
# [0.03787878787878788, 1.15]
# [0.045743329097839895, 0.95]
# [0.06335403726708075, 0.35]
# [0.048223350253807105, 0.9]
# [0.030534351145038167, 1.4]
# [0.04114713216957606, 1.05]
# [0.04071246819338423, 1.2]
# [0.05137844611528822, 0.7]
# [0.028858218318695106, 1.25]
# [0.03170731707317073, 1.3]
# [0.05415617128463476, 0.6]
# [0.03522012578616352, 1.2]
# [0.04791929382093316, 0.75]
# ...

# %%
picky_test(50,'Binom_c:10_p:0.3_s:5000.csv')
# Out:
# [0.0368985290451259, 1.16]
# [0.033582089552238806, 1.29]
# [0.030027756749936917, 1.31]
# [0.04003002251688766, 1.12]
# [0.035982008995502246, 1.17]
# [0.03447414439170622, 1.19]
# [0.030627490039840638, 1.29]
# [0.03427719821162444, 1.24]
# [0.03673163418290855, 1.14]
# [0.03781617831204608, 1.1]
# [0.03182496270512183, 1.26]
# [0.040459540459540456, 1.03]
# [0.0365, 1.16]
# [0.034629861982434125, 1.21]
# [0.03292284493591355, 1.32]
# [0.04246814888833375, 0.94]
# [0.04490106544901065, 0.83]
# [0.04732824427480916, 0.79]
# [0.03770739064856712, 1.2]
# [0.031076301162203133, 1.26]
# [0.029678068410462777, 1.43]
# [0.03602232369355657, 1.1]
# [0.036418816388467376, 1.13]
# [0.03800654417316889, 1.14]
# [0.029705441837244134, 1.56]
# [0.038761641077271584, 1.12]
# [0.03253467843631778, 1.29]
# [0.03944083874188717, 1.14]
# [0.04186394218788936, 0.94]
# [0.03541823662396383, 1.2]
# [0.034947578632051925, 1.16]
# [0.03918143249313701, 1.09]
# [0.0373266078184111, 1.01]
# ...

# %%
picky_test(100,'Binom_c:10_p:0.3_s:5000.csv')
# Out:
# [0.011219147344801795, 1.7]
# [0.013681592039800995, 1.6]
# [0.008831693161746153, 1.54]
# [0.010007505629221916, 1.68]
# [0.009995002498750625, 1.68]
# [0.014489133150137397, 1.48]
# [0.012699203187250997, 1.56]
# [0.01838052657724789, 1.16]
# [0.008745627186406797, 1.72]
# [0.013774104683195593, 1.54]
# [0.01268025857782198, 1.44]
# [0.008241758241758242, 1.96]
# [0.01275, 1.62]
# [0.012296110414052697, 1.48]
# [0.008042221663734606, 1.68]
# [0.015488383712215838, 1.26]
# [0.0136986301369863, 1.46]
# [0.01857506361323155, 1.24]
# [0.011060834590246356, 1.58]
# [0.006568974229408792, 1.64]
# [0.011066398390342052, 1.62]
# [0.014205986808726534, 1.7]
# [0.00834597875569044, 1.78]
# [0.012584948401711553, 1.74]
# [0.009485771342985522, 1.66]
# [0.013088346337780015, 1.5]
# [0.009079445145018916, 1.72]
# [0.016225661507738392, 1.46]
# [0.01619735858460005, 1.44]
# [0.015071590052750565, 1.38]
# [0.008736894658012981, 1.86]
# [0.011729473421512353, 1.58]
# [0.016897856242118536, 1.2]
# ...

# %%
picky_test(250,'Binom_c:10_p:0.3_s:5000.csv')
# Out:
# [0.004238344552480678, 1.65]
# [0.002238805970149254, 1.75]
# [0.0020186727226848347, 1.65]
# [0.003002251688766575, 1.65]
# [0.0069965017491254375, 1.25]
# [0.0022483137646764927, 1.65]
# [0.007719123505976096, 1.25]
# [0.004719324391455539, 1.65]
# [0.005247376311844078, 1.5]
# [0.003756574004507889, 1.65]
# [0.0029835902536051715, 1.35]
# [0.0034965034965034965, 1.75]
# [0.00325, 1.4]
# [0.005269761606022585, 1.5]
# [0.003769791404875597, 1.5]
# [0.0044966275293529855, 1.55]
# [0.00380517503805175, 1.45]
# [0.0035623409669211198, 1.8]
# [0.003519356460532931, 1.5]
# [0.0025265285497726125, 1.95]
# [0.0030181086519114686, 1.65]
# [0.00380517503805175, 1.45]
# [0.0025290844714213456, 1.75]
# [0.0022652907123080794, 1.7]
# [0.0022466300549176237, 1.7]
# [0.0025169896803423106, 1.75]
# [0.0027742749054224464, 1.7]
# [0.0032451323015476783, 1.55]
# [0.0024919013207077, 1.7]
# [0.002260738507912585, 1.7]
# [0.005991013479780329, 1.6]
# [0.0034938857000249564, 1.6]
# ...

# %%
picky_test(100,'Binom_c:10_p:0.3_s:10000.csv')
# Out:
# [0.012296110414052697, 1.56]
# [0.008601062484189223, 1.79]
# [0.015572443004858601, 1.32]
# [0.011408730158730158, 1.55]
# [0.011262670504317358, 1.6]
# [0.013748738647830475, 1.48]
# [0.015037593984962405, 1.36]
# [0.013486261658684145, 1.58]
# [0.013563189250855623, 1.5]
# [0.01313297133476449, 1.44]
# [0.016563408774813503, 1.29]
# [0.010421898543445504, 1.71]
# [0.011706948640483383, 1.64]
# [0.01444179329398468, 1.55]
# [0.011209068010075566, 1.64]
# [0.0080170362019291, 1.77]
# [0.012257661038148843, 1.56]
# [0.012465719272001994, 1.43]
# [0.011635180783185288, 1.65]
# [0.014220991693934055, 1.43]
# [0.010980783628649862, 1.61]
# [0.010806735360643378, 1.79]
# [0.013004876828810803, 1.64]
# [0.01443273092369478, 1.48]
# [0.012548625925461162, 1.51]
# [0.01563294356888663, 1.4]
# [0.009652751661025449, 1.79]
# [0.012473226659947084, 1.72]
# [0.013974568802719375, 1.59]
# [0.011271529888551166, 1.72]
# [0.012353381582231095, 1.59]
# [0.00986636692893718, 1.58]
# ...

# %%
picky_test(200,'Binom_c:10_p:0.3_s:10000.csv')
# Out:
# [0.004265997490589712, 1.62]
# [0.0029091828990640022, 1.82]
# [0.004360284041360409, 1.72]
# [0.002728174603174603, 2.1]
# [0.004004505068201727, 1.62]
# [0.0030272452068617556, 1.76]
# [0.007142857142857143, 1.42]
# [0.005167632972019158, 1.68]
# [0.006718215236405121, 1.54]
# [0.004672307109483521, 1.76]
# [0.002402326463522569, 2.02]
# [0.0035158211953792064, 1.92]
# [0.005161127895266868, 1.76]
# [0.006027878940097953, 1.44]
# [0.003778337531486146, 2.06]
# [0.0023800576224477015, 2.14]
# [0.00375234521575985, 1.66]
# [0.0029917726252804786, 1.74]
# [0.0046290504191167274, 1.72]
# [0.005033979360684621, 1.48]
# [0.00399301222859995, 1.86]
# [0.0031414928373963307, 1.94]
# [0.00512692259597349, 1.66]
# [0.00426706827309237, 1.98]
# [0.003513615259129125, 1.84]
# [0.004067107269954245, 1.84]
# [0.0036354519242823118, 1.84]
# [0.0025198437696862795, 1.82]
# [0.006546644844517185, 1.7]
# [0.001646403242147923, 2.08]
# [0.002869977539306214, 1.8]
# [0.0027475958536280756, 1.6]
# ...

# %%
picky_test(500,'Binom_c:10_p:0.3_s:10000.csv')
# Out:
# [0.0010037641154328732, 1.7]
# [0.0017708069820389577, 1.5]
# [0.0016195340725052947, 1.75]
# [0.000992063492063492, 1.7]
# [0.0023776748842447753, 1.45]
# [0.0011352169525731585, 1.75]
# [0.002380952380952381, 1.4]
# [0.0017645576002016637, 1.6]
# [0.0016478641145899354, 1.9]
# [0.001389064275792398, 1.95]
# [0.0020230117587558476, 1.55]
# [0.0011300853842290306, 1.65]
# [0.002014098690835851, 1.65]
# [0.0011302273012683663, 1.75]
# [0.0010075566750629723, 1.7]
# [0.001377928097206564, 1.85]
# [0.0010006253908692933, 1.7]
# [0.002617801047120419, 1.35]
# [0.0011259852370824471, 1.75]
# [0.0011326453561540397, 1.6]
# [0.0023708510107312204, 1.4]
# [0.001130937421462679, 1.7]
# [0.0011254220332624733, 1.7]
# [0.002133534136546185, 1.7]
# [0.0018822938888191742, 1.35]
# [0.0016522623284189121, 1.85]
# [0.0020057665789143786, 1.45]
# [0.0010079375078745117, 1.7]
# [0.001258970162407151, 1.65]
# [0.0011398176291793312, 1.9]
# [0.0017469428500124782, 1.85]
# [0.0011240164855751218, 1.5]
# ...

# %%
picky_test(10,'Binom_c:20_p:0.3_s:1000.csv')
# Out:
# [0.3763313609467456, 0.13]
# [0.408466819221968, 0.03]
# [0.40232558139534885, 0.06]
# [0.3645955451348183, 0.16]
# [0.3941860465116279, 0.11]
# [0.4160839160839161, 0.08]
# [0.4055619930475087, 0.03]
# [0.38156359393232203, 0.12]
# [0.3945267958950969, 0.08]
# [0.37891077636152953, 0.14]
# [0.38649592549476136, 0.07]
# [0.35361653272101035, 0.16]
# [0.41480611045828436, 0.08]
# [0.3538812785388128, 0.17]
# [0.4102259215219976, 0.07]
# [0.35122520420070014, 0.14]
# [0.4065040650406504, 0.05]
# [0.38287752675386444, 0.14]
# [0.37222870478413067, 0.12]
# [0.3668571428571429, 0.17]
# [0.4057471264367816, 0.09]
# [0.3690337601862631, 0.15]
# [0.37894736842105264, 0.17]
# [0.3770491803278688, 0.15]
# [0.3957345971563981, 0.06]
# [0.3528735632183908, 0.18]
# [0.3641755634638197, 0.16]
# [0.38985005767012687, 0.13]
# [0.4018801410105758, 0.06]
# [0.3654292343387471, 0.11]
# [0.4026128266033254, 0.05]
# [0.3523375142531357, 0.16]
# [0.3498233215547703, 0.18]
# [0.3768613974799542, 0.12]
# ...

# %%
picky_test(20,'Binom_c:20_p:0.3_s:1000.csv')
# Out:
# [0.15976331360946747, 0.92]
# [0.18649885583524028, 0.62]
# [0.17674418604651163, 0.72]
# [0.1817116060961313, 0.48]
# [0.16744186046511628, 0.78]
# [0.1794871794871795, 0.58]
# [0.17381228273464658, 0.46]
# [0.17152858809801633, 0.76]
# [0.1653363740022805, 0.84]
# [0.16222479721900349, 0.88]
# [0.17927823050058206, 0.74]
# [0.18025258323765786, 0.54]
# [0.1692126909518214, 0.66]
# [0.1598173515981735, 0.68]
# [0.18906064209274673, 0.6]
# [0.18319719953325556, 0.5]
# [0.1672473867595819, 0.9]
# [0.15695600475624258, 0.84]
# [0.15402567094515754, 0.88]
# [0.16228571428571428, 0.74]
# [0.18045977011494252, 0.54]
# [0.1769499417927823, 0.64]
# [0.16140350877192983, 0.7]
# [0.16978922716627634, 0.72]
# [0.15995260663507108, 0.96]
# [0.16896551724137931, 0.7]
# [0.17912218268090155, 0.68]
# [0.1707035755478662, 0.6]
# [0.172737955346651, 0.72]
# [0.18329466357308585, 0.48]
# [0.166270783847981, 0.68]
# [0.18015963511972635, 0.54]
# [0.14487632508833923, 0.98]
# ...

# %%
picky_test(50,'Binom_c:20_p:0.3_s:1000.csv')
# Out:
# [0.06982248520710059, 1.15]
# [0.05491990846681922, 2.1]
# [0.06162790697674419, 1.45]
# [0.05627198124267292, 1.65]
# [0.06395348837209303, 1.1]
# [0.055944055944055944, 1.7]
# [0.05330243337195829, 1.85]
# [0.058343057176196034, 1.75]
# [0.06043329532497149, 1.5]
# [0.05214368482039398, 1.55]
# [0.05238649592549476, 1.95]
# [0.04707233065442021, 1.7]
# [0.06110458284371328, 1.25]
# [0.05821917808219178, 1.4]
# [0.06302021403091558, 1.55]
# [0.047841306884480746, 2.0]
# [0.059233449477351915, 1.35]
# [0.06420927467300833, 1.05]
# [0.07467911318553092, 0.9]
# [0.07314285714285715, 1.0]
# [0.05632183908045977, 1.35]
# [0.047729918509895226, 2.05]
# [0.05497076023391813, 1.45]
# [0.06088992974238876, 1.25]
# [0.041469194312796206, 2.1]
# [0.059770114942528735, 1.3]
# [0.06880189798339265, 1.1]
# [0.05767012687427912, 1.45]
# [0.06698002350176263, 1.2]
# [0.0568445475638051, 1.35]
# [0.07007125890736342, 1.05]
# [0.04104903078677309, 2.1]
# [0.05653710247349823, 1.5]
# ...

# %%
picky_test(50,'Binom_c:20_p:0.3_s:5000.csv')
# Out:
# [0.05124588622472966, 1.6]
# [0.05484545665814548, 1.67]
# [0.050768514205868656, 1.67]
# [0.045475638051044084, 1.96]
# [0.044709737827715354, 2.07]
# [0.05505436039787185, 1.56]
# [0.05298318359824925, 1.71]
# [0.05365853658536585, 1.63]
# [0.05372093023255814, 1.53]
# [0.052995391705069124, 1.5]
# [0.05187586845761927, 1.7]
# [0.04860948819817715, 1.81]
# [0.04878612716763006, 1.84]
# [0.053517176910493104, 1.47]
# [0.054377880184331796, 1.65]
# [0.05252198056455345, 1.55]
# [0.05459171871385612, 1.52]
# [0.05541386505912358, 1.55]
# [0.04864359214218896, 1.66]
# [0.05511627906976744, 1.45]
# [0.05351326198231736, 1.57]
# [0.05240992044922789, 1.82]
# [0.05080027835768963, 1.81]
# [0.04295333178546552, 2.14]
# [0.05107963779893197, 1.67]
# [0.05217996289424861, 1.62]
# [0.05225267069205759, 1.65]
# [0.05573694029850746, 1.49]
# [0.05372290292177191, 1.54]
# [0.05642340871998135, 1.34]
# [0.0517120894479385, 1.87]
# [0.05395172740179839, 1.51]
# [0.04711919757406111, 1.84]
# ...

# %%
picky_test(100,'Binom_c:20_p:0.3_s:5000.csv')
# Out:
# [0.023977433004231313, 1.8]
# [0.017429700209156403, 2.48]
# [0.014904517931998137, 2.42]
# [0.010904872389791183, 2.82]
# [0.021301498127340824, 2.18]
# [0.01642377978255841, 2.68]
# [0.012209168394379175, 2.64]
# [0.017421602787456445, 2.22]
# [0.020930232558139535, 2.06]
# [0.01566820276497696, 2.34]
# [0.01760074108383511, 2.52]
# [0.01822855807431643, 2.58]
# [0.014566473988439306, 2.5]
# [0.014723066136947885, 2.68]
# [0.022119815668202765, 1.9]
# [0.018741323461360482, 2.24]
# [0.018043025676613464, 2.32]
# [0.020171574310224902, 2.3]
# [0.020112254443405052, 2.2]
# [0.01813953488372093, 2.64]
# [0.018845974872033502, 2.78]
# [0.016144127281235376, 2.58]
# [0.022964509394572025, 1.82]
# [0.015091711167866265, 2.78]
# [0.01694915254237288, 2.68]
# [0.02295918367346939, 2.1]
# [0.015327450069670227, 2.54]
# [0.021222014925373133, 2.26]
# [0.020499528746465597, 2.2]
# [0.01981813942643973, 2.24]
# [0.018867924528301886, 2.4]
# [0.018457169900615238, 2.34]
# ...

# %%
picky_test(250,'Binom_c:20_p:0.3_s:5000.csv')
# Out:
# [0.007522331922896097, 2.5]
# [0.005345108064141297, 2.65]
# [0.004191895668374476, 2.5]
# [0.004640371229698376, 2.3]
# [0.007958801498127341, 2.15]
# [0.006939625260235947, 2.45]
# [0.0073715733701912, 2.5]
# [0.006039488966318235, 2.95]
# [0.005813953488372093, 2.25]
# [0.005299539170506912, 2.65]
# [0.006716072255673923, 2.2]
# [0.005842486562280907, 2.45]
# [0.006011560693641618, 2.45]
# [0.007244683337228324, 2.35]
# [0.005069124423963134, 2.45]
# [0.005784359093012495, 2.55]
# [0.008327550312283136, 1.9]
# [0.005564572223510317, 2.7]
# [0.006548175865294668, 2.5]
# [0.0060465116279069765, 2.4]
# [0.006514657980456026, 2.65]
# [0.006785212915301825, 2.7]
# [0.004407330085826954, 2.6]
# [0.005107963779893197, 2.4]
# [0.0076619456698397955, 2.5]
# [0.004406307977736549, 3.2]
# [0.006502554575011612, 2.4]
# [0.0032649253731343282, 2.6]
# [0.004476908576814326, 2.6]
# [0.005362555374213103, 2.85]
# [0.006522245515956208, 2.7]
# [0.005915759583530526, 2.6]
# ...

# %%
picky_test(100,'Binom_c:20_p:0.3_s:10000.csv')
# Out:
# [0.015063054647361046, 2.37]
# [0.015880429705744978, 2.55]
# [0.013637953141391771, 2.48]
# [0.023363942810647447, 1.84]
# [0.016147769516728624, 2.45]
# [0.017367991607413452, 2.43]
# [0.014798415287811699, 2.54]
# [0.016816536260656312, 2.61]
# [0.01673056814220983, 2.33]
# [0.020273401297497683, 2.19]
# [0.016771488469601678, 2.47]
# [0.019077349982656956, 2.35]
# [0.013392337253988588, 2.7]
# [0.019811210814590374, 2.19]
# [0.017592916229756495, 2.26]
# [0.0183282745738968, 2.3]
# [0.015420289855072464, 2.46]
# [0.014357417999299639, 2.64]
# [0.020320483046911288, 2.14]
# [0.01375131103600979, 2.67]
# [0.015195452963693307, 2.62]
# [0.019797368114591825, 2.15]
# [0.01828771112405358, 2.47]
# [0.01545253863134658, 2.72]
# [0.015957446808510637, 2.46]
# [0.015908293367645338, 2.32]
# [0.016433566433566433, 2.54]
# [0.019886033259681357, 2.32]
# [0.014784633294528522, 2.74]
# [0.017035577703094218, 2.46]
# [0.012152777777777778, 2.87]
# [0.014973882762623332, 2.63]
# ...

# %%
picky_test(200,'Binom_c:20_p:0.3_s:10000.csv')
# Out:
# [0.006539000467071462, 2.76]
# [0.0067725361980383, 2.5]
# [0.004196293274274391, 2.88]
# [0.007671742415436476, 2.46]
# [0.005111524163568773, 2.5]
# [0.006061312507285231, 2.74]
# [0.004311349335819156, 2.76]
# [0.005371949083265211, 2.64]
# [0.0046473800395027305, 2.86]
# [0.004054680259499536, 2.8]
# [0.005124621476822734, 2.88]
# [0.003699849693606197, 2.92]
# [0.004425294049144055, 2.74]
# [0.0062929728469875304, 2.66]
# [0.003495281370150297, 2.64]
# [0.007237917347653514, 2.72]
# [0.004521739130434782, 2.74]
# [0.005252713902182795, 3.02]
# [0.004760798885276358, 2.9]
# [0.005710290175970167, 2.76]
# [0.00811970769052314, 2.44]
# [0.0047746593688133224, 2.7]
# [0.00419336051252184, 2.74]
# [0.007435808063204368, 2.52]
# [0.008209990749306197, 2.74]
# [0.004678909814013335, 2.7]
# [0.0050116550116550114, 2.9]
# [0.004070240725665775, 2.6]
# [0.00919674039580908, 2.6]
# [0.0062579673195039985, 2.62]
# [0.005208333333333333, 2.88]
# [0.004178757980266976, 2.94]
# ...

# %%
picky_test(500,'Binom_c:20_p:0.3_s:10000.csv')
# Out:
# [0.002685660906118636, 2.35]
# [0.002335357309668379, 2.8]
# [0.0023312740412635507, 2.7]
# [0.0034871556433802163, 2.2]
# [0.002091078066914498, 2.5]
# [0.0039631658701480355, 2.45]
# [0.003495688650664181, 2.35]
# [0.003737008057923625, 2.15]
# [0.001858952015801092, 2.5]
# [0.003243744207599629, 2.45]
# [0.0031446540880503146, 2.6]
# [0.0035842293906810036, 2.15]
# [0.00232910213112845, 2.7]
# [0.0020976576156625103, 2.55]
# [0.002446696959105208, 2.4]
# [0.0025682932523931824, 2.55]
# [0.002318840579710145, 2.9]
# [0.003268355316913739, 2.5]
# [0.0026706920575940546, 2.7]
# [0.003263022957697238, 2.4]
# [0.0031318872520589257, 2.25]
# [0.00326074298357983, 2.5]
# [0.00489225393127548, 1.95]
# [0.0029046125246892066, 2.65]
# [0.0026595744680851063, 2.65]
# [0.0021055094163060007, 2.4]
# [0.003962703962703963, 2.25]
# [0.0025584370275613445, 2.55]
# [0.0026775320139697323, 2.4]
# [0.0030130953760574807, 2.5]
# [0.0020833333333333333, 2.4]
# [0.0032501450957632036, 2.25]
# ...

# %%
picky_test(10,'Binom_c:50_p:0.3_s:1000.csv')
# Out:
# [0.5119305856832972, 0.0]
# [0.6019522776572668, 0.0]
# [0.5086767895878525, 0.0]
# [0.5225522552255225, 0.0]
# [0.526258205689278, 0.0]
# [0.5301866081229418, 0.01]
# [0.5559246954595792, 0.0]
# [0.5603070175438597, 0.0]
# [0.5937846836847946, 0.0]
# [0.5456545654565457, 0.01]
# [0.5, 0.0]
# [0.5076923076923077, 0.0]
# [0.5145739910313901, 0.0]
# [0.5321701199563795, 0.0]
# [0.49058693244739754, 0.0]
# [0.5295404814004376, 0.01]
# [0.5579868708971554, 0.01]
# [0.4610318331503842, 0.02]
# [0.6222466960352423, 0.0]
# [0.6136114160263447, 0.01]
# [0.5250544662309368, 0.0]
# [0.5193370165745856, 0.01]
# [0.4983783783783784, 0.01]
# [0.5098468271334792, 0.0]
# [0.5043763676148797, 0.0]
# [0.6024229074889867, 0.0]
# [0.5152838427947598, 0.01]
# [0.48488120950323976, 0.01]
# [0.5352422907488987, 0.0]
# [0.5285714285714286, 0.0]
# [0.4703296703296703, 0.07]
# [0.5520607375271149, 0.0]
# [0.4793926247288503, 0.02]
# [0.5294117647058824, 0.0]
# [0.5038335158817087, 0.0]
# ...

# %%
picky_test(20,'Binom_c:50_p:0.3_s:1000.csv')
# Out:
# [0.23210412147505424, 0.9]
# [0.23752711496746204, 0.96]
# [0.24078091106290672, 0.76]
# [0.24532453245324531, 0.66]
# [0.2363238512035011, 0.94]
# [0.24368825466520308, 0.82]
# [0.2502768549280177, 0.68]
# [0.25877192982456143, 0.66]
# [0.24528301886792453, 0.64]
# [0.25742574257425743, 0.9]
# [0.24780701754385964, 0.76]
# [0.23846153846153847, 0.64]
# [0.24103139013452915, 1.0]
# [0.2802617230098146, 0.64]
# [0.24363233665559247, 0.94]
# [0.2647702407002188, 0.58]
# [0.25711159737417943, 0.58]
# [0.23929747530186607, 0.96]
# [0.2918502202643172, 0.7]
# [0.2711306256860593, 0.6]
# [0.23638344226579522, 0.8]
# [0.2419889502762431, 0.78]
# [0.2691891891891892, 0.74]
# [0.24288840262582057, 0.86]
# [0.2647702407002188, 0.56]
# [0.28634361233480177, 0.68]
# [0.22270742358078602, 1.26]
# [0.22894168466522677, 0.88]
# [0.2654185022026432, 0.7]
# [0.256043956043956, 0.7]
# [0.25164835164835164, 0.8]
# [0.25379609544468545, 0.7]
# [0.25379609544468545, 0.66]
# [0.25925925925925924, 0.78]
# ...

# %%
picky_test(50,'Binom_c:50_p:0.3_s:1000.csv')
# Out:
# [0.08134490238611713, 2.15]
# [0.1019522776572668, 1.55]
# [0.09761388286334056, 1.55]
# [0.08800880088008801, 2.0]
# [0.1050328227571116, 1.65]
# [0.10428100987925357, 1.55]
# [0.10077519379844961, 1.3]
# [0.08771929824561403, 1.85]
# [0.08102108768035517, 2.25]
# [0.10561056105610561, 1.65]
# [0.09429824561403509, 1.85]
# [0.0967032967032967, 1.4]
# [0.09192825112107623, 2.1]
# [0.0970556161395856, 1.7]
# [0.10631229235880399, 1.3]
# [0.09737417943107221, 1.8]
# [0.08424507658643327, 2.1]
# [0.07793633369923161, 2.45]
# [0.10352422907488987, 1.8]
# [0.07025246981339188, 3.05]
# [0.07407407407407407, 2.35]
# [0.10165745856353592, 1.75]
# [0.08216216216216216, 2.15]
# [0.11597374179431072, 1.3]
# [0.11597374179431072, 1.15]
# [0.08480176211453745, 2.2]
# [0.07314410480349345, 2.55]
# [0.11555075593952484, 0.75]
# [0.09361233480176212, 2.15]
# [0.0967032967032967, 1.85]
# [0.0989010989010989, 1.65]
# [0.113882863340564, 1.1]
# [0.0878524945770065, 2.1]
# [0.09586056644880174, 1.85]
# ...

# %%
picky_test(50,'Binom_c:50_p:0.3_s:5000.csv')
# Out:
# [0.0936058009228741, 1.64]
# [0.08382838283828382, 2.38]
# [0.07722685388328214, 2.28]
# [0.08470124753775443, 2.12]
# [0.09348441926345609, 1.83]
# [0.09275618374558305, 1.7]
# [0.08485381402506045, 2.21]
# [0.07956560283687943, 2.23]
# [0.08347940403155127, 2.1]
# [0.09190371991247265, 1.72]
# [0.08227012758468984, 2.39]
# [0.08991706678306416, 1.98]
# [0.08917616126205083, 1.9]
# [0.08419660568657704, 2.04]
# [0.0913907284768212, 1.81]
# [0.08111672895141789, 2.26]
# [0.09194645600175554, 1.79]
# [0.09260070052539404, 1.88]
# [0.0861275476660092, 1.99]
# [0.08393759613271809, 2.04]
# [0.07791357485814054, 2.34]
# [0.0819277108433735, 2.2]
# [0.08780380994088023, 1.9]
# [0.07857299190194791, 2.48]
# [0.0843585237258348, 2.3]
# [0.08994941719815262, 1.94]
# [0.0909892046706323, 1.92]
# [0.08243332598633459, 2.24]
# [0.0756578947368421, 2.54]
# [0.08565823888404533, 2.07]
# [0.08276469293418445, 2.08]
# [0.0941202281702501, 1.86]
# [0.08638456478842359, 2.01]
# ...

# %%
picky_test(100,'Binom_c:50_p:0.3_s:5000.csv')
# Out:
# [0.04108987035816304, 2.5]
# [0.031023102310231022, 3.46]
# [0.035761298815269855, 2.74]
# [0.0280148829065441, 3.5]
# [0.03987796905643931, 2.44]
# [0.03312720848056537, 3.04]
# [0.03055616619037151, 3.06]
# [0.028147163120567375, 3.66]
# [0.029798422436459245, 3.52]
# [0.03347921225382932, 3.2]
# [0.036735591728992524, 2.98]
# [0.04124836316019206, 2.5]
# [0.03659070990359334, 2.92]
# [0.03151862464183381, 3.26]
# [0.03421633554083885, 3.22]
# [0.04154759287755551, 2.7]
# [0.030502523590081192, 3.28]
# [0.029115586690017514, 3.46]
# [0.037913653298268686, 2.78]
# [0.03823335530652604, 2.72]
# [0.032736796158882586, 3.0]
# [0.033515881708652794, 3.16]
# [0.03459601488942413, 3.48]
# [0.03655066754213176, 2.9]
# [0.028558875219683654, 3.74]
# [0.03738728832197053, 2.68]
# [0.03657193214364397, 2.88]
# [0.027110425391227683, 3.8]
# [0.03289473684210526, 3.36]
# [0.037053182214472534, 2.78]
# [0.035219018269865725, 3.02]
# [0.03400614304519526, 3.5]
# [0.031791273843455384, 3.6]
# ...

# %%
picky_test(250,'Binom_c:50_p:0.3_s:5000.csv')
# Out:
# [0.013843111404087014, 3.15]
# [0.01606160616061606, 2.7]
# [0.011627906976744186, 3.15]
# [0.015320639089516306, 2.85]
# [0.0169971671388102, 2.8]
# [0.010379858657243815, 3.9]
# [0.010991426687183996, 3.55]
# [0.013962765957446808, 3.35]
# [0.015118317265556529, 2.75]
# [0.014660831509846827, 2.95]
# [0.01759788825340959, 2.55]
# [0.011567001309471846, 3.75]
# [0.014680105170902716, 3.0]
# [0.01278377782675777, 3.5]
# [0.012803532008830023, 3.25]
# [0.012310397889646076, 3.45]
# [0.01184990125082291, 3.55]
# [0.016418563922942206, 2.8]
# [0.01358755204909051, 3.55]
# [0.012744451768842013, 3.7]
# [0.018550851156700132, 2.2]
# [0.014019715224534502, 2.9]
# [0.012699802934092402, 3.25]
# [0.015101772816808929, 2.9]
# [0.013181019332161687, 3.1]
# [0.015174840554211567, 2.8]
# [0.01233751927737387, 3.45]
# [0.014326647564469915, 3.25]
# [0.012719298245614035, 3.75]
# [0.01002615518744551, 3.8]
# [0.012546775258639665, 3.3]
# [0.014699429574374727, 3.0]
# [0.01381276035957027, 3.05]
# ...

# %%
picky_test(100,'Binom_c:50_p:0.3_s:10000.csv')
# Out:
# [0.03276525563496427, 2.98]
# [0.033260153677277714, 3.2]
# [0.034490262213034494, 2.99]
# [0.03508578970523537, 2.91]
# [0.038187205091627346, 2.56]
# [0.03343632752151843, 3.17]
# [0.036003501860363316, 2.9]
# [0.03274005713030103, 3.05]
# [0.03542055049895822, 3.14]
# [0.03333697671876708, 3.0]
# [0.03306690025183401, 3.08]
# [0.03397097625329815, 3.07]
# [0.03624918602127198, 2.66]
# [0.031133523350142512, 3.44]
# [0.0379400830964356, 2.88]
# [0.031661684933023355, 3.32]
# [0.03232545354590434, 3.27]
# [0.03189041095890411, 3.25]
# [0.03377933757402939, 3.13]
# [0.03713498622589532, 2.98]
# [0.03138766519823789, 3.19]
# [0.03661602360913761, 2.96]
# [0.038088947600176136, 2.73]
# [0.030728709394205442, 3.32]
# [0.033970507919169855, 3.0]
# [0.03416657570134265, 3.2]
# [0.03238199780461032, 3.39]
# [0.03513009111867384, 3.24]
# [0.03549517966695881, 3.02]
# [0.032557631377690376, 3.19]
# [0.03457708720866615, 3.01]
# [0.0335784044771206, 3.1]
# [0.02906208718626156, 3.59]
# ...

# %%
picky_test(200,'Binom_c:50_p:0.3_s:10000.csv')
# Out:
# [0.015063221550302364, 3.7]
# [0.015367727771679473, 3.36]
# [0.012512240235012512, 3.92]
# [0.013308402991641002, 3.94]
# [0.013606935147591353, 3.58]
# [0.01280070624586184, 3.72]
# [0.01400744145327205, 3.78]
# [0.013843111404087014, 3.66]
# [0.015352560587783748, 3.6]
# [0.013881298502568586, 3.56]
# [0.015985984889959486, 3.28]
# [0.014731750219876869, 3.42]
# [0.012806598654221837, 3.9]
# [0.013922385441789082, 3.58]
# [0.014979225891099934, 3.7]
# [0.014280969777482564, 3.64]
# [0.011105002748763056, 3.72]
# [0.01326027397260274, 3.68]
# [0.015463917525773196, 3.26]
# [0.013994490358126721, 3.68]
# [0.014537444933920705, 3.66]
# [0.01311618756148213, 3.92]
# [0.009907529722589167, 3.96]
# [0.011084284460052678, 3.78]
# [0.011469142545057346, 3.88]
# [0.015391332823927519, 3.18]
# [0.014050493962678375, 3.66]
# [0.013064002634756834, 3.82]
# [0.015556529360210342, 3.48]
# [0.01365672457117885, 3.86]
# [0.015209541525331, 3.42]
# [0.015033468671129157, 3.62]
# ...

# %%
picky_test(500,'Binom_c:50_p:0.3_s:10000.csv')
# Out:
# [0.006047278724573941, 3.5]
# [0.005927552140504939, 3.3]
# [0.006963333696006963, 3.35]
# [0.004839419269687638, 4.1]
# [0.006254800833973445, 3.7]
# [0.005076142131979695, 3.95]
# [0.005143357408623331, 4.2]
# [0.0061524939573720065, 3.3]
# [0.005263735058668713, 3.7]
# [0.007541807847852224, 3.05]
# [0.008649950728128764, 2.6]
# [0.007255936675461741, 3.15]
# [0.005860646841762535, 3.75]
# [0.007783380837535628, 3.2]
# [0.004920183686857643, 3.9]
# [0.006753016716484003, 3.35]
# [0.0075865860362836724, 3.3]
# [0.005917808219178082, 4.0]
# [0.0069094099583241935, 3.1]
# [0.007823691460055097, 2.95]
# [0.007048458149779736, 3.1]
# [0.005683681276642256, 3.8]
# [0.005614266842800529, 3.55]
# [0.00504828797190518, 3.9]
# [0.0056799563080283996, 3.7]
# [0.0049121274969981445, 4.05]
# [0.0053787047200878155, 3.65]
# [0.005269513667801076, 4.0]
# [0.007668711656441718, 2.9]
# [0.0063367202010269855, 3.15]
# [0.005580479264689791, 3.7]
# [0.008339734445297927, 2.9]
# ...
