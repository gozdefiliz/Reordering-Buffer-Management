# %%
#all necessary side algorithms

#finds the number of color changes in a given list
def nb_of_change(x):
    count=0
    i=0
    while i<(len(x)-1):
        if x[i]!=x[i+1]:
            count=count+1
            i=i+1
        else:
            i=i+1
    return count

#adds k items to the buffer from the input
def add(k, data,buffer):
    while k>0:
        buffer.append(data.pop(0))
        k=k-1
        
#finds and lists the unique items in a given list
def unique(list1): 
    unique_list = [] 
    for x in list1: 
        if x not in unique_list: 
            unique_list.append(x)
    return unique_list

#finds the most freq color in buffer
def most_freq(List): 
    return max(set(List), key = List.count)

#evicts c_act, appends output, removes from buffer, fills buffer till there is no c_act in buffer 
def evict(c_act, data, buffer,output_,k):
    while (c_act in buffer)==True:
        count=0
        buffer.remove(c_act)
        count=count+1
        for i in range(0,count):
            output_.append(c_act)
        while len(buffer)<k and len(data)!=0:
            add(k-len(buffer), data,buffer)
    return output_

#finds the second most frequent color in a given list
def second_most_freq(List): 
    from collections import Counter 
    occurence_count = Counter(List) 
    if len(occurence_count)>=2:
        return occurence_count.most_common(2)[1][0]
    else:
        return -1
    
#finds the occurence of a given color in a given list      
def occurence(List, x): 
    count=0
    for i in range (0, len(List)):
        if List[i]==x:
            count=count+1
    return count


#finds the least freq color in buffer
def least_freq(List): 
    return min(set(List), key = List.count)

# %%
def picky(k,input_):
    import numpy as np
    import math
    buffer=input_[0:0]
    output_=input_[0:0]
    data=input_[:]
    nb_of_delays=0
    c_act=-1
    result=[0]*2
    

    while len(data)!=0:
        ex=0
        while len(buffer)<k and len(data)!=0:

            add(min((k-len(buffer)), len(data)), data, buffer)
            

            if (c_act!=-1 and (c_act in buffer)==True):
                while (c_act in buffer)==True:
                    buffer.remove(c_act)
                    output_.append(c_act)

                    add(min(1,len(data)), data, buffer)
            else:
                continue
            if len(buffer)==0:
                break
                
            #nb of colors in the buffer is sigma
            sigma=len(unique(buffer))
            #most frequent color in the buffer
            o_1=most_freq(buffer)
            size_of_o1=occurence(buffer,o_1)
        

            while (size_of_o1 >= 2 * (math.ceil(len(buffer)/sigma))) and ex<len(data):

                delayed=least_freq(buffer)
                while (delayed in buffer)==True:
                    nb_of_delays=nb_of_delays+1
                    ex=ex+1
                    buffer.remove(delayed)
                    data.append(delayed)
                if len(buffer)==0:
                    break
                    
                    

        if len(buffer)!=0:
            c_act=most_freq(buffer)
            while(c_act in buffer)==True:
                buffer.remove(c_act)
                output_.append(c_act)
            

    while len(buffer)!=0:
        c_act=most_freq(buffer)
        while (c_act in buffer)==True:
            buffer.remove(c_act)
            output_.append(c_act)
            
    result[0]=float(nb_of_change(output_)/nb_of_change(input_))
    result[1]=float(nb_of_delays/len(input_))
    print(result)

# %%
#reads data from given text and makes test of delay alg.
def picky_test(k,text):
    import pandas as pd
    data=pd.read_csv(text, header=None)

    input_1=(data.iloc[0]).tolist()
    input_2=(data.iloc[1]).tolist()
    input_3=(data.iloc[2]).tolist()
    input_4=(data.iloc[3]).tolist()
    input_5=(data.iloc[4]).tolist()
    input_6=(data.iloc[5]).tolist()
    input_7=(data.iloc[6]).tolist()
    input_8=(data.iloc[7]).tolist()
    input_9=(data.iloc[8]).tolist()
    input_10=(data.iloc[9]).tolist()

    input_11=(data.iloc[10]).tolist()
    input_12=(data.iloc[11]).tolist()
    input_13=(data.iloc[12]).tolist()
    input_14=(data.iloc[13]).tolist()
    input_15=(data.iloc[14]).tolist()
    input_16=(data.iloc[15]).tolist()
    input_17=(data.iloc[16]).tolist()
    input_18=(data.iloc[17]).tolist()
    input_19=(data.iloc[18]).tolist()
    input_20=(data.iloc[19]).tolist()

    input_21=(data.iloc[20]).tolist()
    input_22=(data.iloc[21]).tolist()
    input_23=(data.iloc[22]).tolist()
    input_24=(data.iloc[23]).tolist()
    input_25=(data.iloc[24]).tolist()
    input_26=(data.iloc[25]).tolist()
    input_27=(data.iloc[26]).tolist()
    input_28=(data.iloc[27]).tolist()
    input_29=(data.iloc[28]).tolist()
    input_30=(data.iloc[29]).tolist()

    input_31=(data.iloc[30]).tolist()
    input_32=(data.iloc[31]).tolist()
    input_33=(data.iloc[32]).tolist()
    input_34=(data.iloc[33]).tolist()
    input_35=(data.iloc[34]).tolist()
    input_36=(data.iloc[35]).tolist()
    input_37=(data.iloc[36]).tolist()
    input_38=(data.iloc[37]).tolist()
    input_39=(data.iloc[38]).tolist()
    input_40=(data.iloc[39]).tolist()

    input_41=(data.iloc[40]).tolist()
    input_42=(data.iloc[41]).tolist()
    input_43=(data.iloc[42]).tolist()
    input_44=(data.iloc[43]).tolist()
    input_45=(data.iloc[44]).tolist()
    input_46=(data.iloc[45]).tolist()
    input_47=(data.iloc[46]).tolist()
    input_48=(data.iloc[47]).tolist()
    input_49=(data.iloc[48]).tolist()
    input_50=(data.iloc[49]).tolist()

    picky(k,input_1)
    picky(k,input_2)
    picky(k,input_3)
    picky(k,input_4)
    picky(k,input_5)
    picky(k,input_6)
    picky(k,input_7)
    picky(k,input_8)
    picky(k,input_9)
    picky(k,input_10)

    picky(k,input_11)
    picky(k,input_12)
    picky(k,input_13)
    picky(k,input_14)
    picky(k,input_15)
    picky(k,input_16)
    picky(k,input_17)
    picky(k,input_18)
    picky(k,input_19)
    picky(k,input_20)

    picky(k,input_21)
    picky(k,input_22)
    picky(k,input_23)
    picky(k,input_24)
    picky(k,input_25)
    picky(k,input_26)
    picky(k,input_27)
    picky(k,input_28)
    picky(k,input_29)
    picky(k,input_30)

    picky(k,input_31)
    picky(k,input_32)
    picky(k,input_33)
    picky(k,input_34)
    picky(k,input_35)
    picky(k,input_36)
    picky(k,input_37)
    picky(k,input_38)
    picky(k,input_39)
    picky(k,input_40)

    picky(k,input_41)
    picky(k,input_42)
    picky(k,input_43)
    picky(k,input_44)
    picky(k,input_45)
    picky(k,input_46)
    picky(k,input_47)
    picky(k,input_48)
    picky(k,input_49)
    picky(k,input_50)

# %%
picky_test(10,'Poisson_m:1_c:10_s:1000.csv')
# Out:
# [0.1925287356321839, 0.07]
# [0.1880466472303207, 0.11]
# [0.20348837209302326, 0.11]
# [0.20689655172413793, 0.11]
# [0.2020497803806735, 0.12]
# [0.19115549215406563, 0.14]
# [0.20694645441389292, 0.1]
# [0.21060171919770773, 0.06]
# [0.1971631205673759, 0.09]
# [0.19236417033773862, 0.11]
# [0.18194254445964433, 0.13]
# [0.19145802650957292, 0.14]
# [0.1829971181556196, 0.14]
# [0.20118343195266272, 0.11]
# [0.19193324061196107, 0.11]
# [0.21407624633431085, 0.08]
# [0.17073170731707318, 0.13]
# [0.20743919885550788, 0.04]
# [0.2153392330383481, 0.05]
# [0.19420289855072465, 0.11]
# [0.1887052341597796, 0.14]
# [0.20088626292466766, 0.12]
# [0.19236417033773862, 0.2]
# [0.20140845070422536, 0.09]
# [0.19607843137254902, 0.12]
# [0.20839363241678727, 0.09]
# [0.1867816091954023, 0.12]
# [0.21562952243125905, 0.07]
# [0.1971223021582734, 0.09]
# [0.20221606648199447, 0.11]
# [0.20562130177514792, 0.16]
# [0.22125181950509462, 0.08]
# [0.18518518518518517, 0.07]
# ...

# %%
picky_test(20,'Poisson_m:1_c:10_s:1000.csv')
# Out:
# [0.08908045977011494, 0.4]
# [0.06705539358600583, 0.5]
# [0.07848837209302326, 0.44]
# [0.07496251874062969, 0.54]
# [0.08052708638360176, 0.28]
# [0.07132667617689016, 0.56]
# [0.0723589001447178, 0.52]
# [0.08166189111747851, 0.36]
# [0.06950354609929078, 0.52]
# [0.06754772393538913, 0.6]
# [0.06292749658002736, 0.64]
# [0.07658321060382917, 0.52]
# [0.08645533141210375, 0.34]
# [0.07100591715976332, 0.5]
# [0.06815020862308763, 0.56]
# [0.07624633431085044, 0.44]
# [0.06859756097560976, 0.48]
# [0.07582260371959942, 0.42]
# [0.07964601769911504, 0.4]
# [0.08115942028985507, 0.48]
# [0.0674931129476584, 0.48]
# [0.06646971935007386, 0.64]
# [0.08516886930983847, 0.42]
# [0.07464788732394366, 0.5]
# [0.07983193277310924, 0.48]
# [0.07670043415340087, 0.32]
# [0.07183908045977011, 0.52]
# [0.06657018813314038, 0.48]
# [0.07482014388489208, 0.56]
# [0.06925207756232687, 0.52]
# [0.07396449704142012, 0.62]
# [0.0858806404657933, 0.44]
# [0.08404558404558404, 0.26]
# ...

# %%
picky_test(50,'Poisson_m:1_c:10_s:1000.csv')
# Out:
# [0.02442528735632184, 0.55]
# [0.027696793002915453, 0.75]
# [0.030523255813953487, 0.55]
# [0.017991004497751123, 1.0]
# [0.036603221083455345, 0.55]
# [0.015691868758915834, 0.85]
# [0.027496382054992764, 0.8]
# [0.027220630372492838, 0.6]
# [0.02695035460992908, 0.9]
# [0.01762114537444934, 0.8]
# [0.025991792065663474, 0.7]
# [0.026509572901325478, 0.5]
# [0.025936599423631124, 0.6]
# [0.026627218934911243, 0.65]
# [0.02086230876216968, 0.75]
# [0.026392961876832845, 0.6]
# [0.03048780487804878, 0.55]
# [0.01859799713876967, 0.65]
# [0.030973451327433628, 0.5]
# [0.02463768115942029, 0.75]
# [0.026170798898071626, 0.75]
# [0.025110782865583457, 0.85]
# [0.01762114537444934, 0.8]
# [0.023943661971830985, 0.8]
# [0.02100840336134454, 0.9]
# [0.023154848046309694, 0.7]
# [0.021551724137931036, 0.7]
# [0.020260492040520984, 0.7]
# [0.015827338129496403, 0.9]
# [0.012465373961218837, 0.85]
# [0.03254437869822485, 0.65]
# [0.01455604075691412, 0.9]
# [0.03561253561253561, 0.6]
# ...

# %%
picky_test(10,'Poisson_m:1_c:20_s:1000.csv')
# Out:
# [0.23065902578796563, 0.08]
# [0.20148148148148148, 0.06]
# [0.17812061711079943, 0.12]
# [0.20296296296296296, 0.09]
# [0.20148148148148148, 0.07]
# [0.20694645441389292, 0.08]
# [0.2106038291605302, 0.04]
# [0.21052631578947367, 0.04]
# [0.21940928270042195, 0.07]
# [0.1927536231884058, 0.12]
# [0.1988388969521045, 0.1]
# [0.21397379912663755, 0.04]
# [0.17780938833570412, 0.07]
# [0.1925925925925926, 0.14]
# [0.19298245614035087, 0.16]
# [0.19828815977175462, 0.07]
# [0.2145922746781116, 0.04]
# [0.21333333333333335, 0.04]
# [0.21044776119402986, 0.06]
# [0.2168141592920354, 0.04]
# [0.19596541786743515, 0.08]
# [0.22238372093023256, 0.06]
# [0.1854014598540146, 0.1]
# [0.19943019943019943, 0.06]
# [0.21060171919770773, 0.12]
# [0.18985507246376812, 0.11]
# [0.19133034379671152, 0.13]
# [0.1949509116409537, 0.14]
# [0.18497109826589594, 0.07]
# [0.19694868238557559, 0.09]
# [0.19456366237482117, 0.11]
# [0.18222222222222223, 0.15]
# [0.18041958041958042, 0.13]
# ...

# %%
picky_test(20,'Poisson_m:1_c:20_s:1000.csv')
# Out:
# [0.07020057306590258, 0.5]
# [0.0725925925925926, 0.56]
# [0.08274894810659186, 0.26]
# [0.06962962962962962, 0.42]
# [0.10074074074074074, 0.18]
# [0.0723589001447178, 0.52]
# [0.07658321060382917, 0.42]
# [0.07017543859649122, 0.46]
# [0.06188466947960619, 0.6]
# [0.08550724637681159, 0.38]
# [0.06966618287373004, 0.48]
# [0.08005822416302766, 0.36]
# [0.08392603129445235, 0.32]
# [0.07111111111111111, 0.52]
# [0.06871345029239766, 0.52]
# [0.06990014265335236, 0.48]
# [0.0715307582260372, 0.44]
# [0.06666666666666667, 0.48]
# [0.08059701492537313, 0.5]
# [0.07374631268436578, 0.5]
# [0.07636887608069164, 0.44]
# [0.08430232558139535, 0.4]
# [0.08759124087591241, 0.26]
# [0.08262108262108261, 0.32]
# [0.07736389684813753, 0.44]
# [0.07391304347826087, 0.48]
# [0.07473841554559044, 0.5]
# [0.06591865357643759, 0.68]
# [0.07803468208092486, 0.48]
# [0.08876560332871013, 0.3]
# [0.07725321888412018, 0.5]
# [0.06814814814814815, 0.54]
# [0.07272727272727272, 0.62]
# ...

# %%
picky_test(50,'Poisson_m:1_c:20_s:1000.csv')
# Out:
# [0.02005730659025788, 0.85]
# [0.01925925925925926, 0.8]
# [0.019635343618513323, 0.9]
# [0.02666666666666667, 0.7]
# [0.03851851851851852, 0.4]
# [0.024602026049204053, 0.7]
# [0.026509572901325478, 0.5]
# [0.027777777777777776, 0.5]
# [0.016877637130801686, 0.85]
# [0.017391304347826087, 0.8]
# [0.01451378809869376, 0.85]
# [0.02911208151382824, 0.45]
# [0.021337126600284494, 0.6]
# [0.02074074074074074, 0.8]
# [0.02046783625730994, 0.8]
# [0.015691868758915834, 0.95]
# [0.027181688125894134, 0.55]
# [0.028148148148148148, 0.55]
# [0.029850746268656716, 0.65]
# [0.030973451327433628, 0.6]
# [0.01729106628242075, 0.9]
# [0.024709302325581394, 0.8]
# [0.027737226277372264, 0.55]
# [0.022792022792022793, 0.7]
# [0.03724928366762178, 0.5]
# [0.028985507246376812, 0.6]
# [0.02242152466367713, 0.7]
# [0.02244039270687237, 0.85]
# [0.033236994219653176, 0.45]
# [0.033287101248266296, 0.45]
# [0.02575107296137339, 0.75]
# [0.01925925925925926, 0.8]
# [0.019580419580419582, 0.95]
# ...

# %%
picky_test(10,'Poisson_m:1_c:50_s:1000.csv')
# Out:
# [0.1991643454038997, 0.09]
# [0.20913107511045656, 0.08]
# [0.1819505094614265, 0.12]
# [0.1834319526627219, 0.11]
# [0.20765832106038293, 0.07]
# [0.2017291066282421, 0.1]
# [0.19738751814223512, 0.12]
# [0.20967741935483872, 0.09]
# [0.20864381520119224, 0.06]
# [0.1901931649331352, 0.14]
# [0.19047619047619047, 0.13]
# [0.1924198250728863, 0.11]
# [0.19882179675994108, 0.1]
# [0.22140762463343108, 0.04]
# [0.21148036253776434, 0.11]
# [0.19359534206695778, 0.13]
# [0.2040520984081042, 0.08]
# [0.20943952802359883, 0.1]
# [0.1703056768558952, 0.13]
# [0.22852983988355166, 0.05]
# [0.19616519174041297, 0.11]
# [0.21944035346097202, 0.07]
# [0.21515151515151515, 0.06]
# [0.1808972503617945, 0.1]
# [0.1765536723163842, 0.11]
# [0.21153846153846154, 0.09]
# [0.193033381712627, 0.09]
# [0.19432624113475178, 0.09]
# [0.19593613933236576, 0.11]
# [0.20710059171597633, 0.08]
# [0.207492795389049, 0.08]
# [0.19130434782608696, 0.16]
# [0.21262002743484226, 0.07]
# ...

# %%
picky_test(20,'Poisson_m:1_c:50_s:1000.csv')
# Out:
# [0.0766016713091922, 0.52]
# [0.07658321060382917, 0.46]
# [0.09461426491994178, 0.22]
# [0.07840236686390532, 0.4]
# [0.08100147275405008, 0.4]
# [0.07348703170028818, 0.42]
# [0.06676342525399129, 0.66]
# [0.0718475073313783, 0.44]
# [0.07153502235469449, 0.54]
# [0.0861812778603269, 0.38]
# [0.06782106782106782, 0.44]
# [0.08163265306122448, 0.3]
# [0.07363770250368189, 0.44]
# [0.08504398826979472, 0.3]
# [0.0634441087613293, 0.56]
# [0.08296943231441048, 0.46]
# [0.06801736613603473, 0.52]
# [0.07079646017699115, 0.44]
# [0.049490538573508006, 0.62]
# [0.07423580786026202, 0.46]
# [0.07669616519174041, 0.5]
# [0.08689248895434462, 0.3]
# [0.09545454545454546, 0.38]
# [0.07959479015918958, 0.46]
# [0.07344632768361582, 0.4]
# [0.07396449704142012, 0.46]
# [0.07982583454281568, 0.4]
# [0.07801418439716312, 0.42]
# [0.06676342525399129, 0.5]
# [0.07692307692307693, 0.44]
# [0.09077809798270893, 0.3]
# [0.08260869565217391, 0.4]
# [0.06584362139917696, 0.62]
# ...

# %%
picky_test(50,'Poisson_m:1_c:50_s:1000.csv')
# Out:
# [0.019498607242339833, 0.6]
# [0.030927835051546393, 0.5]
# [0.018922852983988356, 0.75]
# [0.023668639053254437, 0.7]
# [0.017673048600883652, 0.85]
# [0.01440922190201729, 0.75]
# [0.018867924528301886, 0.9]
# [0.01466275659824047, 0.9]
# [0.01788375558867362, 0.75]
# [0.020802377414561663, 0.8]
# [0.02886002886002886, 0.65]
# [0.018950437317784258, 0.8]
# [0.013254786450662739, 1.0]
# [0.030791788856304986, 0.6]
# [0.01812688821752266, 0.9]
# [0.020378457059679767, 0.9]
# [0.03473227206946455, 0.4]
# [0.029498525073746312, 0.65]
# [0.021834061135371178, 0.6]
# [0.018922852983988356, 0.9]
# [0.022123893805309734, 0.75]
# [0.03240058910162003, 0.5]
# [0.025757575757575757, 0.75]
# [0.023154848046309694, 0.8]
# [0.011299435028248588, 0.85]
# [0.02514792899408284, 0.75]
# [0.030478955007256895, 0.7]
# [0.02127659574468085, 0.75]
# [0.01741654571843251, 0.75]
# [0.010355029585798817, 0.85]
# [0.025936599423631124, 0.75]
# [0.02608695652173913, 0.5]
# [0.03017832647462277, 0.45]
# ...

# %%
picky_test(50,'Poisson_m:1_c:50_s:5000.csv')
# Out:
# [0.021700879765395895, 0.82]
# [0.026041666666666668, 0.68]
# [0.021551724137931036, 0.84]
# [0.02270767461914343, 0.75]
# [0.019674935842600515, 0.76]
# [0.017271157167530225, 0.91]
# [0.016398158803222096, 0.81]
# [0.02109216989309448, 0.73]
# [0.020437535981577434, 0.73]
# [0.019488074461896453, 0.8]
# [0.023878858474082703, 0.71]
# [0.018989190768331873, 0.71]
# [0.018275271273557967, 0.9]
# [0.019347386658966213, 0.84]
# [0.02194628934449899, 0.73]
# [0.022413793103448276, 0.81]
# [0.018399532710280372, 0.76]
# [0.022491861497484462, 0.69]
# [0.01871042026482441, 0.8]
# [0.022627093740816926, 0.79]
# [0.02107390300230947, 0.78]
# [0.021701388888888888, 0.82]
# [0.01943719176095155, 0.71]
# [0.02486267707429893, 0.67]
# [0.02257402521254764, 0.8]
# [0.024882903981264637, 0.71]
# [0.02186421173762946, 0.83]
# [0.01862464183381089, 0.79]
# [0.020126509488211614, 0.89]
# [0.024864246927693626, 0.65]
# [0.01756406564929456, 0.83]
# [0.016260162601626018, 0.88]
# ...

# %%
picky_test(100,'Poisson_m:1_c:50_s:5000.csv')
# Out:
# [0.00498533724340176, 0.96]
# [0.004340277777777778, 0.96]
# [0.003160919540229885, 1.0]
# [0.0025869502730669733, 1.08]
# [0.00570287995437696, 0.94]
# [0.0020149683362118594, 1.02]
# [0.005753739930955121, 1.1]
# [0.005489742848887605, 1.08]
# [0.003742084052964882, 0.96]
# [0.009016870273414777, 1.0]
# [0.007280139778683751, 0.98]
# [0.0052585451358457495, 1.04]
# [0.006853226727584237, 1.08]
# [0.005775339301183945, 1.08]
# [0.004331504475887958, 1.02]
# [0.005747126436781609, 0.96]
# [0.002628504672897196, 1.12]
# [0.0023675643681562593, 1.04]
# [0.003742084052964882, 0.94]
# [0.007052600646488392, 1.0]
# [0.008371824480369515, 0.84]
# [0.001736111111111111, 0.96]
# [0.00841311285175515, 0.84]
# [0.008094825093957791, 0.98]
# [0.0032248607446496626, 1.08]
# [0.004391100702576112, 0.98]
# [0.0017261219792865361, 1.16]
# [0.004297994269340974, 1.06]
# [0.008050603795284647, 1.02]
# [0.0054301228922549296, 1.02]
# [0.005758710048949035, 1.06]
# [0.006097560975609756, 1.02]
# ...

# %%
picky_test(250,'Poisson_m:1_c:50_s:5000.csv')
# Out:
# [0.0020527859237536657, 0.9]
# [0.002025462962962963, 0.85]
# [0.002011494252873563, 0.9]
# [0.0017246335153779822, 1.05]
# [0.001996007984031936, 0.85]
# [0.0017271157167530224, 0.9]
# [0.0020138089758342925, 0.85]
# [0.0020225368390638545, 0.85]
# [0.0020149683362118594, 0.85]
# [0.002617801047120419, 0.9]
# [0.0020384391380314504, 0.9]
# [0.002044989775051125, 0.9]
# [0.0017133066818960593, 0.9]
# [0.0028876696505919725, 0.9]
# [0.0028876696505919725, 0.9]
# [0.002011494252873563, 0.9]
# [0.0020443925233644858, 0.85]
# [0.0017756732761171944, 1.1]
# [0.0017271157167530224, 1.05]
# [0.002057008521892448, 1.05]
# [0.001443418013856813, 1.05]
# [0.001736111111111111, 1.05]
# [0.0017406440382941688, 0.85]
# [0.0017346053772766695, 1.05]
# [0.0020521841102316037, 0.85]
# [0.00234192037470726, 1.05]
# [0.0017261219792865361, 1.05]
# [0.0020057306590257878, 0.85]
# [0.0017251293847038527, 1.05]
# [0.0017147756501857674, 1.05]
# [0.0020155485171321624, 1.1]
# ...

# %%
picky_test(50,'Poisson_m:1_c:100_s:5000.csv')
# Out:
# [0.019539224263633713, 0.86]
# [0.017846693973083673, 0.79]
# [0.022331786542923435, 0.79]
# [0.021840419336051253, 0.69]
# [0.017543859649122806, 0.85]
# [0.017371163867979156, 0.79]
# [0.02380269572698595, 0.62]
# [0.021112696148359488, 0.81]
# [0.023666951810664385, 0.67]
# [0.021264200407806584, 0.77]
# [0.022022602144306, 0.83]
# [0.015629522431259046, 0.9]
# [0.02396259497369959, 0.72]
# [0.020338012030936693, 0.77]
# [0.023242300987797792, 0.65]
# [0.022920952101087275, 0.73]
# [0.022331786542923435, 0.77]
# [0.02398843930635838, 0.78]
# [0.02218978102189781, 0.77]
# [0.024869866975130134, 0.81]
# [0.015732265446224258, 0.91]
# [0.024096385542168676, 0.67]
# [0.02390552995391705, 0.68]
# [0.023543260741612712, 0.66]
# [0.01998841251448436, 0.78]
# [0.017960602549246814, 0.85]
# [0.02571595558153127, 0.66]
# [0.020711785297549593, 0.77]
# [0.022041763341067284, 0.74]
# [0.021399652978600348, 0.77]
# [0.02023706273489448, 0.84]
# [0.016078093597473444, 0.89]
# ...

# %%
picky_test(100,'Poisson_m:1_c:100_s:5000.csv')
# Out:
# [0.005249343832020997, 1.0]
# [0.004388531304856641, 0.94]
# [0.009280742459396751, 0.98]
# [0.005824111822947, 1.1]
# [0.004314063848144953, 0.96]
# [0.0052113491603937466, 0.98]
# [0.006022368798394035, 1.0]
# [0.003708987161198288, 1.0]
# [0.003421727972626176, 1.16]
# [0.0026216137489076608, 0.94]
# [0.004056795131845842, 1.02]
# [0.006078147612156295, 1.0]
# [0.008766803039158387, 0.86]
# [0.006301919220853624, 1.04]
# [0.004938988959907031, 0.92]
# [0.007640317367029092, 0.82]
# [0.0075406032482598605, 1.02]
# [0.002890173410404624, 0.92]
# [0.004963503649635037, 1.12]
# [0.004916136495083863, 1.08]
# [0.004290617848970252, 0.94]
# [0.005737234652897304, 1.12]
# [0.00576036866359447, 1.04]
# [0.004120070629782225, 0.98]
# [0.005214368482039398, 0.94]
# [0.002607184241019699, 0.94]
# [0.004675628287551139, 1.04]
# [0.003792298716452742, 1.06]
# [0.006090487238979118, 1.02]
# [0.0031810294968189707, 1.16]
# [0.0028910089621277824, 1.06]
# [0.0017226528854435831, 1.16]
# ...

# %%
picky_test(250,'Poisson_m:1_c:100_s:5000.csv')
# Out:
# [0.002041411490230388, 0.85]
# [0.002047981275599766, 0.85]
# [0.002320185614849188, 0.85]
# [0.0017472335468841002, 0.9]
# [0.001725625539257981, 1.05]
# [0.002026635784597568, 0.85]
# [0.0017206767995411529, 0.9]
# [0.0017118402282453639, 1.05]
# [0.001710863986313088, 1.1]
# [0.0026216137489076608, 0.9]
# [0.002028397565922921, 1.0]
# [0.0017366136034732273, 0.9]
# [0.0017533606078316774, 0.9]
# [0.0017187052420509883, 1.05]
# [0.0017431725740848344, 0.9]
# [0.0023508668821627977, 0.85]
# [0.0020301624129930394, 0.9]
# [0.0017341040462427746, 1.05]
# [0.0020437956204379564, 1.0]
# [0.0020242914979757085, 0.9]
# [0.002002288329519451, 0.9]
# [0.002294893861158921, 0.85]
# [0.0020161290322580645, 0.85]
# [0.0017657445556209534, 1.05]
# [0.0017381228273464658, 0.9]
# [0.002317497103128621, 0.85]
# [0.0017533606078316774, 1.05]
# [0.001750291715285881, 1.05]
# [0.0017401392111368909, 1.05]
# [0.0020242914979757085, 0.85]
# [0.0017346053772766695, 0.9]
# [0.0017226528854435831, 0.9]
# ...

# %%
picky_test(50,'Poisson_m:1_c:250_s:5000.csv')
# Out:
# [0.025544267053701015, 0.72]
# [0.01859924440569602, 0.79]
# [0.023079170318434122, 0.7]
# [0.02590221187427241, 0.72]
# [0.0137221269296741, 0.93]
# [0.02396765809991337, 0.72]
# [0.015103107754864944, 0.79]
# [0.019619157530294286, 0.8]
# [0.020589076351158135, 0.86]
# [0.018954623779437105, 0.9]
# [0.019202793133546697, 0.86]
# [0.02161214953271028, 0.85]
# [0.021870503597122302, 0.83]
# [0.01998262380538662, 0.8]
# [0.02318840579710145, 0.71]
# [0.01810344827586207, 0.81]
# [0.020017406440382943, 0.82]
# [0.01921397379912664, 0.75]
# [0.0219526285384171, 0.79]
# [0.019275028768699656, 0.88]
# [0.023142857142857142, 0.7]
# [0.023494860499265784, 0.72]
# [0.027697634160415464, 0.55]
# [0.019247594050743656, 0.77]
# [0.021025345622119815, 0.76]
# [0.017981438515081206, 0.78]
# [0.020618556701030927, 0.85]
# [0.020301624129930394, 0.84]
# [0.02145308924485126, 0.75]
# [0.016194331983805668, 0.79]
# [0.026568682871678916, 0.67]
# [0.016666666666666666, 0.9]
# ...

# %%
picky_test(100,'Poisson_m:1_c:250_s:5000.csv')
# Out:
# [0.002902757619738752, 1.04]
# [0.004068584713746004, 1.0]
# [0.0035056967572304996, 1.04]
# [0.005529685681024447, 1.02]
# [0.006289308176100629, 1.0]
# [0.006352873231302339, 1.04]
# [0.009875108916642464, 0.78]
# [0.0031736872475476054, 1.02]
# [0.004861309694023448, 1.0]
# [0.00402067777139575, 1.14]
# [0.003200465522257783, 0.94]
# [0.0035046728971962616, 0.94]
# [0.0028776978417266188, 1.1]
# [0.005212858384013901, 0.94]
# [0.007536231884057971, 0.98]
# [0.004310344827586207, 1.1]
# [0.004641717435451117, 0.96]
# [0.0017467248908296944, 1.16]
# [0.004332755632582322, 1.08]
# [0.007479861910241657, 0.94]
# [0.002285714285714286, 0.94]
# [0.005580029368575624, 0.92]
# [0.00894402769763416, 0.8]
# [0.007874015748031496, 0.96]
# [0.002304147465437788, 0.94]
# [0.0037703016241299302, 0.98]
# [0.003436426116838488, 1.02]
# [0.004640371229698376, 1.1]
# [0.004004576659038902, 1.06]
# [0.0020242914979757085, 0.94]
# [0.005087620124364048, 0.96]
# [0.002631578947368421, 0.96]
# ...

# %%
picky_test(250,'Poisson_m:1_c:250_s:5000.csv')
# Out:
# [0.0017416545718432512, 1.05]
# [0.0017436791630340018, 1.05]
# [0.0017528483786152498, 1.1]
# [0.002328288707799767, 0.85]
# [0.0017152658662092624, 0.9]
# [0.0020213687554143807, 1.05]
# [0.0017426662794074934, 0.9]
# [0.0017311021350259665, 0.9]
# [0.0017157563625965113, 1.05]
# [0.0017231476163124641, 1.05]
# [0.002036659877800407, 0.85]
# [0.0017523364485981308, 0.9]
# [0.0017266187050359713, 0.9]
# [0.0017376194613379669, 1.1]
# [0.0017391304347826088, 0.9]
# [0.002011494252873563, 0.85]
# [0.0017406440382941688, 1.05]
# [0.0017467248908296944, 0.9]
# [0.0017331022530329288, 0.9]
# [0.0017261219792865361, 1.1]
# [0.0017142857142857142, 0.9]
# [0.001762114537444934, 0.9]
# [0.00259665320253895, 0.85]
# [0.002041411490230388, 0.85]
# [0.0020161290322580645, 0.85]
# [0.0020301624129930394, 1.05]
# [0.001718213058419244, 0.9]
# [0.0017401392111368909, 0.9]
# [0.002002288329519451, 0.95]
# [0.0020242914979757085, 1.1]
# [0.0016958733747880158, 1.05]
# [0.0017543859649122807, 1.05]
# ...

# %%
picky_test(100,'Poisson_m:1_c:100_s:10000.csv')
# Out:
# [0.0037692084662220935, 1.01]
# [0.0031833309217189987, 1.08]
# [0.0045590539962957685, 1.02]
# [0.0024702121476315024, 1.16]
# [0.004053858404517156, 1.01]
# [0.0025955299206921415, 1.03]
# [0.00507393447376051, 1.1]
# [0.0050200803212851405, 0.98]
# [0.004620271440947156, 1.05]
# [0.003192106790481718, 1.05]
# [0.004508435136707388, 1.08]
# [0.006189722182236936, 1.04]
# [0.004473304473304474, 1.06]
# [0.003056323679231553, 1.11]
# [0.003771942550413463, 1.06]
# [0.0040650406504065045, 0.99]
# [0.004226173127368114, 1.09]
# [0.0032234432234432234, 1.07]
# [0.003343995347484734, 0.96]
# [0.005243991260014566, 0.95]
# [0.004194388197859416, 1.06]
# [0.00418712099335836, 0.96]
# [0.006199538638985006, 1.02]
# [0.0048500881834215165, 1.07]
# [0.004978038067349927, 1.08]
# [0.004909038406006353, 1.15]
# [0.004484953703703704, 1.07]
# [0.005305420131918555, 1.01]
# [0.003655505190817371, 0.97]
# [0.0021486892995272885, 1.02]
# [0.00332417979476803, 1.14]
# [0.002901494269548818, 1.08]
# ...

# %%
picky_test(200,'Poisson_m:1_c:100_s:10000.csv')
# Out:
# [0.001304726007538417, 0.94]
# [0.0008681811604688178, 0.94]
# [0.0009972930616896994, 0.98]
# [0.0011624527753560012, 0.92]
# [0.0013030259157376576, 0.94]
# [0.0010093727469358328, 0.94]
# [0.001014786894752102, 0.98]
# [0.0008605851979345956, 0.98]
# [0.0010106843777071904, 0.96]
# [0.0011607661056297156, 0.92]
# [0.0010180337405468296, 1.16]
# [0.001151576219951058, 1.0]
# [0.0011544011544011544, 0.94]
# [0.001018774559743851, 1.12]
# [0.0010155229943420861, 0.98]
# [0.0011614401858304297, 1.1]
# [0.0010201107548819587, 0.92]
# [0.0010256410256410256, 1.12]
# [0.0010177377144518756, 0.94]
# [0.0010196649672250546, 0.92]
# [0.0008678044547295343, 1.12]
# [0.0008663008951775916, 0.94]
# [0.0011534025374855825, 1.12]
# [0.002792475014697237, 1.04]
# [0.0010248901903367497, 1.08]
# [0.0010106843777071904, 0.98]
# [0.0014467592592592592, 1.04]
# [0.0010037281330656726, 0.96]
# [0.0014622020763269484, 0.92]
# [0.0008594757198109154, 0.96]
# [0.0013007660066483597, 1.14]
# ...

# %%
picky_test(500,'Poisson_m:1_c:100_s:10000.csv')
# Out:
# [0.0011597564511452595, 0.85]
# [0.0008681811604688178, 0.9]
# [0.0009972930616896994, 0.9]
# [0.0011624527753560012, 0.85]
# [0.001013464601129289, 0.9]
# [0.0011535688536409518, 0.85]
# [0.001014786894752102, 0.9]
# [0.001004016064257028, 0.9]
# [0.0010106843777071904, 1.1]
# [0.0010156703424260012, 1.05]
# [0.0010180337405468296, 1.05]
# [0.0010076291924571758, 1.05]
# [0.0011544011544011544, 0.85]
# [0.001164313782564401, 0.85]
# [0.0010155229943420861, 0.9]
# [0.0010162601626016261, 0.85]
# [0.0010201107548819587, 0.85]
# [0.0008791208791208791, 1.1]
# [0.0010177377144518756, 0.9]
# [0.0008739985433357611, 1.05]
# [0.0008678044547295343, 0.9]
# [0.0010106843777071904, 0.85]
# [0.0008650519031141869, 0.9]
# [0.00102880658436214, 1.05]
# [0.0008784773060029283, 1.05]
# [0.001155067860236789, 0.85]
# [0.0008680555555555555, 1.05]
# [0.0011471178663607685, 0.85]
# [0.0011697616610615586, 0.85]
# [0.0008594757198109154, 0.9]
# [0.0011562364503540975, 0.85]
# ...

# %%
picky_test(100,'Poisson_m:1_c:200_s:10000.csv')
# Out:
# [0.004342162396873643, 1.03]
# [0.004215729030382323, 0.99]
# [0.0020278099652375433, 1.11]
# [0.004592422502870264, 1.07]
# [0.0027468555732253867, 1.07]
# [0.002318840579710145, 1.14]
# [0.0028972910328842532, 1.09]
# [0.004786076867295141, 0.97]
# [0.00438532378307265, 0.96]
# [0.003948522959929804, 0.92]
# [0.0027468555732253867, 1.08]
# [0.007202535292422933, 1.03]
# [0.002717002717002717, 1.13]
# [0.002593286269989915, 0.99]
# [0.0030408340573414424, 1.09]
# [0.0018643338591710886, 0.99]
# [0.002616279069767442, 1.12]
# [0.004740017236426314, 1.03]
# [0.0027620293647332463, 1.09]
# [0.00489349453080023, 1.05]
# [0.004481711724736158, 1.0]
# [0.0042509527997654645, 1.03]
# [0.0030474531998258597, 1.1]
# [0.0032970183486238534, 1.07]
# [0.006578947368421052, 0.95]
# [0.004901960784313725, 1.08]
# [0.002774937929020009, 1.12]
# [0.002761627906976744, 1.01]
# [0.007822685788787484, 0.97]
# [0.004484953703703704, 1.1]
# [0.005455850681981335, 1.04]
# [0.006470165348670022, 0.96]
# ...

# %%
picky_test(200,'Poisson_m:1_c:200_s:10000.csv')
# Out:
# [0.0008684324793747286, 1.14]
# [0.0011629597325192615, 1.16]
# [0.0010139049826187717, 0.96]
# [0.0018656716417910447, 1.02]
# [0.0014457134595923088, 0.98]
# [0.0008695652173913044, 0.92]
# [0.0014486455164421266, 1.04]
# [0.0014503263234227702, 1.16]
# [0.001023242216050285, 1.08]
# [0.0010236911377595789, 0.94]
# [0.0008674280757553853, 1.12]
# [0.0011524056467876692, 0.96]
# [0.001001001001001001, 1.16]
# [0.0011525716755510734, 0.94]
# [0.0013032145960034753, 0.92]
# [0.0010038720780152016, 0.94]
# [0.0011627906976744186, 1.16]
# [0.0011490950876185005, 1.12]
# [0.0008722197993894462, 0.96]
# [0.0008635578583765112, 1.16]
# [0.001301142113633078, 0.92]
# [0.0008795074758135445, 0.92]
# [0.0017414018284719198, 0.94]
# [0.0010034403669724771, 0.94]
# [0.0008771929824561404, 0.94]
# [0.0011534025374855825, 0.98]
# [0.0008762961881115817, 0.98]
# [0.0008720930232558139, 1.14]
# [0.0010140518615094887, 0.96]
# [0.0010127314814814814, 0.94]
# [0.0015793251974156497, 0.9]
# ...

# %%
picky_test(500,'Poisson_m:1_c:200_s:10000.csv')
# Out:
# [0.0008684324793747286, 0.9]
# [0.0011629597325192615, 0.9]
# [0.0011587485515643105, 0.85]
# [0.0010045924225028703, 0.85]
# [0.0008674280757553853, 1.05]
# [0.0008695652173913044, 0.9]
# [0.0010140518615094887, 1.05]
# [0.001160261058738216, 0.85]
# [0.00087706475661453, 0.9]
# [0.0010236911377595789, 0.9]
# [0.0008674280757553853, 1.05]
# [0.0010083549409392106, 1.05]
# [0.001144001144001144, 0.85]
# [0.001008500216107189, 1.05]
# [0.0013032145960034753, 0.85]
# [0.001147282374874516, 0.85]
# [0.0008720930232558139, 1.1]
# [0.001005458201666188, 0.85]
# [0.001017589765954354, 0.85]
# [0.0008635578583765112, 1.05]
# [0.001011999421714616, 1.05]
# [0.0008795074758135445, 0.9]
# [0.0008707009142359599, 0.9]
# [0.0010034403669724771, 0.9]
# [0.0008771929824561404, 0.9]
# [0.0008650519031141869, 1.05]
# [0.0008762961881115817, 0.9]
# [0.0008720930232558139, 0.9]
# [0.0010140518615094887, 0.9]
# [0.0011574074074074073, 0.85]
# [0.0008614501076812635, 1.05]
# ...

# %%
picky_test(100,'Poisson_m:1_c:500_s:10000.csv')
# Out:
# [0.0045045045045045045, 1.02]
# [0.0034807831762146482, 1.03]
# [0.0030532131433556268, 1.11]
# [0.0034904013961605585, 1.07]
# [0.0018856977081520162, 1.06]
# [0.0027314548591144336, 1.01]
# [0.007861406318241374, 0.89]
# [0.004301075268817204, 1.1]
# [0.0039090777472129724, 1.12]
# [0.0019008626992250328, 1.12]
# [0.0027357811375089995, 1.17]
# [0.0027267508610792192, 1.05]
# [0.002440775305096913, 1.07]
# [0.005786199913207001, 0.98]
# [0.0030386340616408622, 1.06]
# [0.002336448598130841, 1.1]
# [0.003082795067527892, 1.11]
# [0.005716798592788039, 1.05]
# [0.004224941724941725, 1.0]
# [0.0036656891495601175, 0.93]
# [0.004071542823905773, 0.97]
# [0.0037703016241299302, 1.07]
# [0.004768097095795405, 1.07]
# [0.0034374104841019765, 1.13]
# [0.0021862702229995625, 1.14]
# [0.00508646998982706, 0.97]
# [0.005879822171231895, 1.02]
# [0.004601006470165349, 1.01]
# [0.003965922444183314, 1.02]
# [0.0054363376251788265, 1.04]
# [0.0011504170261719873, 1.14]
# ...

# %%
picky_test(200,'Poisson_m:1_c:500_s:10000.csv')
# Out:
# [0.0011624527753560012, 1.12]
# [0.0008701957940536621, 0.94]
# [0.0010177377144518756, 0.92]
# [0.0015997673065735892, 1.0]
# [0.0010153756890049319, 0.92]
# [0.0011500862564692352, 0.98]
# [0.0017469791818314165, 0.94]
# [0.0017204301075268817, 0.94]
# [0.001013464601129289, 0.96]
# [0.0016084222839596433, 0.96]
# [0.001007919366450684, 1.0]
# [0.0010045924225028703, 1.14]
# [0.0010050251256281408, 0.96]
# [0.0011572399826414003, 0.92]
# [0.0013022717407032266, 1.26]
# [0.0010221962616822429, 0.98]
# [0.0017615971814445098, 1.06]
# [0.0008795074758135445, 1.14]
# [0.0010198135198135198, 0.94]
# [0.0010263929618768328, 1.14]
# [0.0010178857059764432, 1.12]
# [0.0010150812064965197, 0.98]
# [0.0010114145354717526, 0.94]
# [0.0010025780578630766, 0.98]
# [0.0013117621337997377, 0.98]
# [0.0008719662839703532, 0.96]
# [0.000860461781155887, 1.14]
# [0.0008626887131560029, 1.14]
# [0.001028202115158637, 0.94]
# [0.0010014306151645207, 1.14]
# [0.0008628127696289905, 1.12]
# ...

# %%
picky_test(500,'Poisson_m:1_c:500_s:10000.csv')
# Out:
# [0.0013077593722755014, 0.85]
# [0.0010152284263959391, 0.85]
# [0.0010177377144518756, 0.85]
# [0.0010180337405468296, 1.05]
# [0.0008703220191470844, 1.1]
# [0.0011500862564692352, 0.9]
# [0.0008734895909157083, 1.05]
# [0.001003584229390681, 0.9]
# [0.0011582452584334732, 0.85]
# [0.000877321245796169, 1.05]
# [0.0008639308855291577, 0.9]
# [0.0008610792192881745, 1.1]
# [0.0010050251256281408, 1.05]
# [0.0010125849848112252, 1.1]
# [0.0010128780205469542, 0.9]
# [0.0011682242990654205, 0.85]
# [0.0008807985907222549, 1.05]
# [0.0008795074758135445, 1.1]
# [0.0011655011655011655, 0.85]
# [0.0011730205278592375, 0.85]
# [0.0010178857059764432, 1.05]
# [0.0010150812064965197, 0.9]
# [0.0010114145354717526, 0.9]
# [0.0010025780578630766, 0.9]
# [0.0008745080891998251, 1.05]
# [0.001017293997965412, 0.85]
# [0.000860461781155887, 1.05]
# [0.0008626887131560029, 1.05]
# [0.001028202115158637, 0.9]
# [0.0010014306151645207, 0.9]
# [0.0008628127696289905, 1.05]
# ...
