# %%
#creates inputs according to the written algorithm inside
#to have color size of 5 max_value needs to be 5
def inputs(low, high, n, text):
    import scipy.stats as sct
    import numpy as np
    import csv
    
    input_1=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_1)
    
    input_2=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_2)
    
    input_3=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_3)
    
    input_4=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_4)
    
    input_5=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_5)
    
    input_6=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_6)
    
    input_7=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_7)
    
    input_8=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_8)
    
    input_9=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_9)
    
    input_10=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_10)

    input_11=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_11)
    
    input_12=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_12)
    
    input_13=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_13)
    
    input_14=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_14)
    
    input_15=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_15)
    
    input_16=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_16)
    
    input_17=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_17)
    
    input_18=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_18)
    
    input_19=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_19)
    
    input_20=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_20)

    input_21=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_21)
    
    input_22=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_22)
    
    input_23=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_23)
    
    input_24=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_24)
    
    input_25=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_25)
    
    input_26=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_26)
    
    input_27=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_27)
    
    input_28=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_28)
    
    input_29=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_29)
    
    input_30=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_30)
    
    input_31=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_31)
    
    input_32=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_32)
    
    input_33=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_33)
    
    input_34=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_34)
    
    input_35=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_35)
    
    input_36=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_36)
    
    input_37=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_37)
    
    input_38=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_38)
    
    input_39=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_39)
    
    input_40=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_40)
    
    input_41=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_41)
    
    input_42=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_42)
    
    input_43=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_43)
    
    input_44=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_44)
    
    input_45=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_45)
    
    input_46=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_46)
    
    input_47=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_47)
    
    input_48=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_48)
    
    input_49=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_49)
    
    input_50=(sct.randint.rvs(low, high, size=n)).tolist()
    with open(text, "a", newline='') as fp:
        wr = csv.writer(fp, dialect='excel')
        wr.writerow(input_50)

# %%
inputs(0, 10, 1000, 'Uniform_c:10_s:1000.csv')

# %%
inputs(0, 20, 1000, 'Uniform_c:20_s:1000.csv')

# %%
inputs(0, 50, 1000, 'Uniform_c:50_s:1000.csv')

# %%
inputs(0, 50, 5000, 'Uniform_c:50_s:5000.csv')

# %%
inputs(0, 100, 5000, 'Uniform_c:100_s:5000.csv')

# %%
inputs(0, 250, 5000, 'Uniform_c:250_s:5000.csv')

# %%
inputs(0, 100, 10000, 'Uniform_c:100_s:10000.csv')

# %%
inputs(0, 200, 10000, 'Uniform_c:200_s:10000.csv')

# %%
inputs(0, 500, 10000, 'Uniform_c:500_s:10000.csv')
