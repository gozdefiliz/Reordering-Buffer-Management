# %%
#all necessary side algorithms

#finds the number of color changes in a given list
def nb_of_change(x):
    count=0
    i=0
    while i<(len(x)-1):
        if x[i]!=x[i+1]:
            count=count+1
            i=i+1
        else:
            i=i+1
    return count

#adds k items to the buffer from the input
def add(k, data,buffer):
    while k>0:
        buffer.append(data.pop(0))
        k=k-1
        
#finds and lists the unique items in a given list
def unique(list1): 
    unique_list = [] 
    for x in list1: 
        if x not in unique_list: 
            unique_list.append(x)
    return unique_list

#finds the most freq color in buffer
def most_freq(List): 
    return max(set(List), key = List.count)

#evicts c_act, appends output, removes from buffer, fills buffer till there is no c_act in buffer 
def evict(c_act, data, buffer,output_,k):
    while (c_act in buffer)==True:
        count=0
        buffer.remove(c_act)
        count=count+1
        for i in range(0,count):
            output_.append(c_act)
        while len(buffer)<k and len(data)!=0:
            add(k-len(buffer), data,buffer)
    return output_

#finds the second most frequent color in a given list
def second_most_freq(List): 
    from collections import Counter 
    occurence_count = Counter(List) 
    if len(occurence_count)>=2:
        return occurence_count.most_common(2)[1][0]
    else:
        return -1
    
#finds the occurence of a given color in a given list      
def occurence(List, x): 
    count=0
    for i in range (0, len(List)):
        if List[i]==x:
            count=count+1
    return count


#finds the least freq color in buffer
def least_freq(List): 
    return min(set(List), key = List.count)

# %%
def picky(k,input_):
    import numpy as np
    import math
    buffer=input_[0:0]
    output_=input_[0:0]
    data=input_[:]
    nb_of_delays=0
    c_act=-1
    result=[0]*2
    

    while len(data)!=0:
        ex=0
        while len(buffer)<k and len(data)!=0:

            add(min((k-len(buffer)), len(data)), data, buffer)
            

            if (c_act!=-1 and (c_act in buffer)==True):
                while (c_act in buffer)==True:
                    buffer.remove(c_act)
                    output_.append(c_act)

                    add(min(1,len(data)), data, buffer)
            else:
                continue
            if len(buffer)==0:
                break
                
            #nb of colors in the buffer is sigma
            sigma=len(unique(buffer))
            #most frequent color in the buffer
            o_1=most_freq(buffer)
            size_of_o1=occurence(buffer,o_1)
        

            while (size_of_o1 >= 2 * (math.ceil(len(buffer)/sigma))) and ex<len(data):

                delayed=least_freq(buffer)
                while (delayed in buffer)==True:
                    nb_of_delays=nb_of_delays+1
                    ex=ex+1
                    buffer.remove(delayed)
                    data.append(delayed)
                if len(buffer)==0:
                    break
                    
                    

        if len(buffer)!=0:
            c_act=most_freq(buffer)
            while(c_act in buffer)==True:
                buffer.remove(c_act)
                output_.append(c_act)
            

    while len(buffer)!=0:
        c_act=most_freq(buffer)
        while (c_act in buffer)==True:
            buffer.remove(c_act)
            output_.append(c_act)
            
    result[0]=float(nb_of_change(output_)/nb_of_change(input_))
    result[1]=float(nb_of_delays/len(input_))
    print(result)

# %%
#reads data from given text and makes test of delay alg.
def picky_test(k,text):
    import pandas as pd
    data=pd.read_csv(text, header=None)

    input_1=(data.iloc[0]).tolist()
    input_2=(data.iloc[1]).tolist()
    input_3=(data.iloc[2]).tolist()
    input_4=(data.iloc[3]).tolist()
    input_5=(data.iloc[4]).tolist()
    input_6=(data.iloc[5]).tolist()
    input_7=(data.iloc[6]).tolist()
    input_8=(data.iloc[7]).tolist()
    input_9=(data.iloc[8]).tolist()
    input_10=(data.iloc[9]).tolist()

    input_11=(data.iloc[10]).tolist()
    input_12=(data.iloc[11]).tolist()
    input_13=(data.iloc[12]).tolist()
    input_14=(data.iloc[13]).tolist()
    input_15=(data.iloc[14]).tolist()
    input_16=(data.iloc[15]).tolist()
    input_17=(data.iloc[16]).tolist()
    input_18=(data.iloc[17]).tolist()
    input_19=(data.iloc[18]).tolist()
    input_20=(data.iloc[19]).tolist()

    input_21=(data.iloc[20]).tolist()
    input_22=(data.iloc[21]).tolist()
    input_23=(data.iloc[22]).tolist()
    input_24=(data.iloc[23]).tolist()
    input_25=(data.iloc[24]).tolist()
    input_26=(data.iloc[25]).tolist()
    input_27=(data.iloc[26]).tolist()
    input_28=(data.iloc[27]).tolist()
    input_29=(data.iloc[28]).tolist()
    input_30=(data.iloc[29]).tolist()

    input_31=(data.iloc[30]).tolist()
    input_32=(data.iloc[31]).tolist()
    input_33=(data.iloc[32]).tolist()
    input_34=(data.iloc[33]).tolist()
    input_35=(data.iloc[34]).tolist()
    input_36=(data.iloc[35]).tolist()
    input_37=(data.iloc[36]).tolist()
    input_38=(data.iloc[37]).tolist()
    input_39=(data.iloc[38]).tolist()
    input_40=(data.iloc[39]).tolist()

    input_41=(data.iloc[40]).tolist()
    input_42=(data.iloc[41]).tolist()
    input_43=(data.iloc[42]).tolist()
    input_44=(data.iloc[43]).tolist()
    input_45=(data.iloc[44]).tolist()
    input_46=(data.iloc[45]).tolist()
    input_47=(data.iloc[46]).tolist()
    input_48=(data.iloc[47]).tolist()
    input_49=(data.iloc[48]).tolist()
    input_50=(data.iloc[49]).tolist()

    picky(k,input_1)
    picky(k,input_2)
    picky(k,input_3)
    picky(k,input_4)
    picky(k,input_5)
    picky(k,input_6)
    picky(k,input_7)
    picky(k,input_8)
    picky(k,input_9)
    picky(k,input_10)

    picky(k,input_11)
    picky(k,input_12)
    picky(k,input_13)
    picky(k,input_14)
    picky(k,input_15)
    picky(k,input_16)
    picky(k,input_17)
    picky(k,input_18)
    picky(k,input_19)
    picky(k,input_20)

    picky(k,input_21)
    picky(k,input_22)
    picky(k,input_23)
    picky(k,input_24)
    picky(k,input_25)
    picky(k,input_26)
    picky(k,input_27)
    picky(k,input_28)
    picky(k,input_29)
    picky(k,input_30)

    picky(k,input_31)
    picky(k,input_32)
    picky(k,input_33)
    picky(k,input_34)
    picky(k,input_35)
    picky(k,input_36)
    picky(k,input_37)
    picky(k,input_38)
    picky(k,input_39)
    picky(k,input_40)

    picky(k,input_41)
    picky(k,input_42)
    picky(k,input_43)
    picky(k,input_44)
    picky(k,input_45)
    picky(k,input_46)
    picky(k,input_47)
    picky(k,input_48)
    picky(k,input_49)
    picky(k,input_50)

# %%
picky_test(10,'Zipf_a:1,1_c:10_s:1000.csv')
# Out:
# [0.3716475095785441, 0.1]
# [0.3825, 0.06]
# [0.3761118170266836, 0.08]
# [0.36768447837150126, 0.16]
# [0.36503856041131105, 0.1]
# [0.36900369003690037, 0.07]
# [0.39846743295019155, 0.07]
# [0.3855721393034826, 0.06]
# [0.3641025641025641, 0.18]
# [0.3737244897959184, 0.13]
# [0.3630653266331658, 0.18]
# [0.3465346534653465, 0.13]
# [0.3653366583541147, 0.11]
# [0.3575, 0.12]
# [0.3370646766169154, 0.18]
# [0.36788874841972186, 0.04]
# [0.3686176836861768, 0.1]
# [0.3693107932379714, 0.09]
# [0.3631713554987212, 0.13]
# [0.33821733821733824, 0.17]
# [0.34005037783375314, 0.2]
# [0.35830212234706615, 0.11]
# [0.36540962288686607, 0.11]
# [0.37344913151364767, 0.15]
# [0.35945273631840796, 0.11]
# [0.3367088607594937, 0.18]
# [0.3778337531486146, 0.09]
# [0.3464467005076142, 0.2]
# [0.323037323037323, 0.24]
# [0.3569682151589242, 0.15]
# [0.37623762376237624, 0.08]
# [0.3595360824742268, 0.14]
# [0.38257575757575757, 0.07]
# [0.36151960784313725, 0.13]
# [0.3717277486910995, 0.17]
# ...

# %%
picky_test(20,'Zipf_a:1,1_c:10_s:1000.csv')
# Out:
# [0.16091954022988506, 0.62]
# [0.18125, 0.46]
# [0.18297331639135958, 0.3]
# [0.15903307888040713, 0.58]
# [0.17866323907455012, 0.42]
# [0.16728167281672818, 0.62]
# [0.1698595146871009, 0.34]
# [0.14303482587064675, 0.86]
# [0.16538461538461538, 0.62]
# [0.1989795918367347, 0.22]
# [0.1670854271356784, 0.44]
# [0.14108910891089108, 0.98]
# [0.14713216957605985, 0.68]
# [0.15875, 0.6]
# [0.15422885572139303, 0.72]
# [0.1706700379266751, 0.42]
# [0.14196762141967623, 0.96]
# [0.14304291287386217, 0.74]
# [0.17774936061381075, 0.4]
# [0.15262515262515264, 1.0]
# [0.13602015113350127, 0.7]
# [0.14481897627965043, 0.84]
# [0.15734720416124837, 0.66]
# [0.1588089330024814, 0.56]
# [0.16169154228855723, 0.7]
# [0.14303797468354432, 0.86]
# [0.16498740554156172, 0.76]
# [0.13705583756345177, 0.8]
# [0.1402831402831403, 1.08]
# [0.1552567237163814, 0.68]
# [0.14356435643564355, 1.02]
# [0.1327319587628866, 1.06]
# [0.15404040404040403, 0.64]
# [0.15318627450980393, 0.8]
# ...

# %%
picky_test(50,'Zipf_a:1,1_c:10_s:1000.csv')
# Out:
# [0.06130268199233716, 0.75]
# [0.085, 0.35]
# [0.06734434561626429, 0.95]
# [0.06361323155216285, 1.25]
# [0.05012853470437018, 1.45]
# [0.05412054120541206, 1.0]
# [0.06641123882503193, 0.6]
# [0.055970149253731345, 0.55]
# [0.07564102564102564, 0.6]
# [0.05994897959183673, 0.6]
# [0.06030150753768844, 1.2]
# [0.06311881188118812, 0.95]
# [0.06109725685785536, 1.15]
# [0.0475, 0.9]
# [0.06840796019900497, 0.55]
# [0.051833122629582805, 1.35]
# [0.057285180572851806, 1.15]
# [0.055916775032509754, 0.95]
# [0.061381074168797956, 0.75]
# [0.05616605616605617, 1.05]
# [0.05163727959697733, 1.25]
# [0.056179775280898875, 0.65]
# [0.05201560468140442, 1.1]
# [0.06823821339950373, 0.65]
# [0.04975124378109453, 1.5]
# [0.056962025316455694, 1.3]
# [0.061712846347607056, 0.85]
# [0.04060913705583756, 1.5]
# [0.0489060489060489, 1.0]
# [0.07946210268948656, 0.4]
# [0.050742574257425746, 0.85]
# [0.05670103092783505, 1.1]
# [0.07702020202020202, 0.55]
# [0.0625, 1.2]
# ...

# %%
picky_test(50,'Zipf_a:1,1_c:10_s:5000.csv')
# Out:
# [0.04864593781344032, 1.55]
# [0.0431077694235589, 1.79]
# [0.05001244090569793, 1.27]
# [0.05447175069673169, 1.1]
# [0.057028514257128564, 0.94]
# [0.04870700477027366, 1.49]
# [0.05046215338496128, 1.7]
# [0.05242036619011788, 1.24]
# [0.05979899497487437, 1.19]
# [0.05013719131953105, 1.39]
# [0.053642714570858285, 1.0]
# [0.04159358556752694, 1.79]
# [0.04825332998240764, 1.35]
# [0.04593110334498253, 1.54]
# [0.05712147667747568, 1.07]
# [0.04780777805300966, 1.64]
# [0.047214589058206344, 1.4]
# [0.058014503625906474, 1.13]
# [0.059273894788836747, 1.1]
# [0.059920437593237195, 1.02]
# [0.06240676280457484, 0.9]
# [0.03680676448644616, 1.95]
# [0.04498269896193772, 1.58]
# [0.04426559356136821, 1.73]
# [0.05754315736802602, 1.15]
# [0.05634505110944901, 1.03]
# [0.05663716814159292, 1.13]
# [0.051859347331140906, 1.17]
# [0.05775, 1.15]
# [0.05416149068322981, 1.16]
# [0.05002526528549773, 1.33]
# [0.06413480885311872, 0.84]
# [0.05985915492957746, 0.95]
# ...

# %%
picky_test(100,'Zipf_a:1,1_c:10_s:5000.csv')
# Out:
# [0.022066198595787363, 1.42]
# [0.01804511278195489, 2.28]
# [0.02214481214232396, 1.4]
# [0.026095768938434252, 1.34]
# [0.024262131065532766, 1.12]
# [0.03037911122269646, 1.14]
# [0.02573070197351986, 1.06]
# [0.026837220968146475, 1.26]
# [0.02035175879396985, 1.96]
# [0.02768770266899476, 0.96]
# [0.028193612774451097, 1.16]
# [0.024304685542470558, 1.56]
# [0.01859763759738628, 1.94]
# [0.02496255616575137, 1.36]
# [0.02469443751558992, 1.54]
# [0.027247956403269755, 1.26]
# [0.023482388208843366, 1.62]
# [0.0277569392348087, 1.34]
# [0.020251914052852555, 1.7]
# [0.018896071606166086, 2.18]
# [0.026106414719045252, 1.54]
# [0.022631186272071623, 1.36]
# [0.02990608007909046, 0.9]
# [0.029678068410462777, 0.9]
# [0.026770077558168626, 1.46]
# [0.02443280977312391, 1.28]
# [0.02579013906447535, 1.46]
# [0.02251454591449532, 1.28]
# [0.02075, 1.66]
# [0.02608695652173913, 1.58]
# [0.02854977261243052, 1.2]
# [0.025653923541247486, 1.88]
# [0.024899396378269618, 1.14]
# ...

# %%
picky_test(250,'Zipf_a:1,1_c:10_s:5000.csv')
# Out:
# [0.011283851554663993, 0.95]
# [0.012531328320802004, 0.6]
# [0.010699178900223935, 0.9]
# [0.010134279199391943, 0.95]
# [0.010505252626313157, 0.9]
# [0.012553351744915892, 0.6]
# [0.011491381463902073, 0.85]
# [0.011286681715575621, 0.95]
# [0.013567839195979899, 1.25]
# [0.011723621850835619, 0.8]
# [0.011477045908183632, 0.75]
# [0.011024805813079429, 0.8]
# [0.01130937421462679, 0.85]
# [0.010234648027958064, 0.9]
# [0.0074831628835120975, 1.35]
# [0.0121377260341838, 0.85]
# [0.012740444666500124, 0.75]
# [0.008752188047011753, 1.0]
# [0.012595702642627809, 0.6]
# [0.010193933366484336, 1.3]
# [0.011934361014420686, 0.75]
# [0.011439940313354886, 0.85]
# [0.011122095897182402, 1.0]
# [0.013078470824949699, 0.6]
# [0.011758819114335751, 0.8]
# [0.011717776115681875, 0.85]
# [0.01213653603034134, 0.6]
# [0.010624841892233746, 1.05]
# [0.00975, 1.15]
# [0.009192546583850932, 0.95]
# [0.012885295603840323, 0.65]
# [0.011066398390342052, 0.9]
# [0.009557344064386318, 1.0]
# ...

# %%
picky_test(100,'Zipf_a:1,1_c:10_s:10000.csv')
# Out:
# [0.019937694704049845, 1.98]
# [0.022369407648087977, 1.71]
# [0.026690167443031602, 1.12]
# [0.023106060606060606, 1.91]
# [0.02074222166687492, 1.76]
# [0.021088095832293485, 1.79]
# [0.016339869281045753, 2.42]
# [0.02716510903426791, 1.39]
# [0.023261599701455405, 1.6]
# [0.019318181818181818, 1.74]
# [0.01669805398618958, 2.37]
# [0.023961063272182705, 1.5]
# [0.01634231536926148, 2.54]
# [0.02212776597074634, 1.56]
# [0.020326724030427734, 2.0]
# [0.02219157472417252, 1.85]
# [0.020991401112797167, 1.74]
# [0.024237096571643853, 1.56]
# [0.022410358565737053, 1.5]
# [0.024566654196283826, 1.78]
# [0.021189081391000873, 1.57]
# [0.019363762102351315, 1.86]
# [0.019563296731036222, 1.68]
# [0.021139240506329114, 2.03]
# [0.01768368617683686, 2.12]
# [0.01940524193548387, 1.86]
# [0.021591765001255335, 1.94]
# [0.027445109780439122, 1.18]
# [0.019517077442762418, 1.83]
# [0.025590062111801242, 1.38]
# [0.02271016311166876, 1.79]
# [0.019034413210639103, 2.27]
# ...

# %%
picky_test(200,'Zipf_a:1,1_c:10_s:10000.csv')
# Out:
# [0.013582554517133956, 0.98]
# [0.0142464383904024, 1.0]
# [0.010323555331738638, 1.48]
# [0.012373737373737374, 0.88]
# [0.013120079970011246, 1.94]
# [0.012353381582231095, 1.86]
# [0.00930115635997989, 1.42]
# [0.013582554517133956, 1.38]
# [0.012688145291702948, 1.0]
# [0.01148989898989899, 1.38]
# [0.01029504080351538, 1.3]
# [0.011481342817920879, 1.6]
# [0.012599800399201597, 0.94]
# [0.01362670333791724, 1.54]
# [0.010101010101010102, 1.72]
# [0.011033099297893681, 1.18]
# [0.011001517450682853, 1.7]
# [0.011930177068943865, 1.28]
# [0.014691235059760957, 0.64]
# [0.012345679012345678, 1.52]
# [0.010469899040259254, 1.62]
# [0.01370551992958632, 1.0]
# [0.010223400227186671, 1.58]
# [0.012278481012658228, 1.26]
# [0.01133250311332503, 1.42]
# [0.01033266129032258, 1.96]
# [0.012804418779814211, 1.04]
# [0.01309880239520958, 1.36]
# [0.01138496184161141, 1.16]
# [0.011801242236024845, 1.66]
# [0.013425345043914681, 0.88]
# [0.013614017395688894, 0.94]
# ...

# %%
picky_test(500,'Zipf_a:1,1_c:10_s:10000.csv')
# Out:
# [0.003987538940809969, 1.45]
# [0.005623594101474632, 0.85]
# [0.0033992194384993074, 1.5]
# [0.005808080808080808, 0.65]
# [0.00462326627514682, 1.1]
# [0.006239081607187422, 0.65]
# [0.005279034690799397, 1.05]
# [0.006355140186915888, 0.6]
# [0.004975743251648215, 1.05]
# [0.006313131313131313, 0.6]
# [0.00514752040175769, 0.95]
# [0.005865468613503058, 0.8]
# [0.0048652694610778445, 1.0]
# [0.006250781347668459, 0.6]
# [0.004863449307893753, 1.15]
# [0.004764292878635908, 1.15]
# [0.006069802731411229, 0.6]
# [0.004520909205073465, 1.5]
# [0.0047310756972111555, 1.35]
# [0.006110487591969073, 0.6]
# [0.0049856662096472645, 1.05]
# [0.006412674462466994, 0.65]
# [0.006310740880979427, 0.6]
# [0.006329113924050633, 0.6]
# [0.00510585305105853, 1.05]
# [0.004914314516129032, 1.1]
# [0.003891539040923927, 1.5]
# [0.004116766467065869, 1.5]
# [0.006630801951707744, 1.0]
# [0.0055900621118012426, 0.95]
# [0.004893350062735257, 1.15]
# [0.005042228665069961, 1.0]
# ...

# %%
picky_test(10,'Zipf_a:1,1_c:20_s:1000.csv')
# Out:
# [0.6078886310904872, 0.0]
# [0.6782810685249709, 0.0]
# [0.6596244131455399, 0.0]
# [0.6478060046189377, 0.0]
# [0.7141176470588235, 0.0]
# [0.6192714453584018, 0.01]
# [0.7226890756302521, 0.0]
# [0.629013079667063, 0.01]
# [0.6588785046728972, 0.0]
# [0.5966981132075472, 0.0]
# [0.6674418604651163, 0.0]
# [0.6209302325581395, 0.0]
# [0.6241457858769932, 0.02]
# [0.6174418604651163, 0.0]
# [0.6304604486422668, 0.0]
# [0.6586206896551724, 0.01]
# [0.6827033218785796, 0.0]
# [0.6257309941520468, 0.0]
# [0.6670520231213873, 0.0]
# [0.6655011655011654, 0.01]
# [0.6362586605080831, 0.0]
# [0.6044083526682135, 0.0]
# [0.640279394644936, 0.0]
# [0.6276849642004774, 0.0]
# [0.5995397008055235, 0.0]
# [0.7104337631887456, 0.0]
# [0.6336056009334889, 0.01]
# [0.6764361078546307, 0.0]
# [0.6171967020023557, 0.0]
# [0.6832151300236406, 0.0]
# [0.6438848920863309, 0.0]
# [0.625, 0.0]
# [0.6601156069364161, 0.0]
# [0.631578947368421, 0.0]
# [0.6462427745664739, 0.0]
# [0.6425178147268409, 0.01]
# ...

# %%
picky_test(20,'Zipf_a:1,1_c:20_s:1000.csv')
# Out:
# [0.2633410672853828, 0.62]
# [0.19279907084785133, 1.24]
# [0.22417840375586853, 0.7]
# [0.23325635103926096, 1.02]
# [0.27647058823529413, 0.48]
# [0.22209165687426558, 0.94]
# [0.22088835534213686, 1.1]
# [0.2140309155766944, 1.06]
# [0.2616822429906542, 0.62]
# [0.2688679245283019, 0.56]
# [0.2686046511627907, 0.74]
# [0.1883720930232558, 1.48]
# [0.28929384965831434, 0.5]
# [0.27325581395348836, 0.58]
# [0.23376623376623376, 0.84]
# [0.20229885057471264, 1.16]
# [0.20962199312714777, 1.08]
# [0.22339181286549709, 1.06]
# [0.24046242774566473, 0.86]
# [0.32167832167832167, 0.44]
# [0.279445727482679, 0.42]
# [0.2273781902552204, 0.82]
# [0.21536670547147846, 1.08]
# [0.2315035799522673, 0.84]
# [0.24856156501726123, 1.14]
# [0.3106682297772567, 0.5]
# [0.2485414235705951, 0.86]
# [0.23798358733880423, 0.98]
# [0.2661955241460542, 0.68]
# [0.20685579196217493, 0.92]
# [0.16906474820143885, 1.56]
# [0.2617924528301887, 0.84]
# [0.18265895953757225, 1.34]
# ...

# %%
picky_test(50,'Zipf_a:1,1_c:20_s:1000.csv')
# Out:
# [0.07308584686774942, 1.85]
# [0.08478513356562137, 1.25]
# [0.06690140845070422, 2.4]
# [0.08775981524249422, 1.1]
# [0.07647058823529412, 2.0]
# [0.07638072855464159, 1.4]
# [0.07563025210084033, 1.95]
# [0.07728894173602854, 1.45]
# [0.09579439252336448, 1.05]
# [0.07429245283018868, 1.5]
# [0.0686046511627907, 2.0]
# [0.07209302325581396, 1.9]
# [0.08997722095671981, 1.5]
# [0.0872093023255814, 1.15]
# [0.11570247933884298, 1.1]
# [0.06436781609195402, 2.2]
# [0.08934707903780069, 1.75]
# [0.0783625730994152, 1.7]
# [0.09710982658959537, 1.0]
# [0.10256410256410256, 1.0]
# [0.07852193995381063, 1.4]
# [0.06380510440835267, 1.8]
# [0.10128055878928988, 1.1]
# [0.07875894988066826, 1.65]
# [0.0667433831990794, 2.05]
# [0.10082063305978899, 0.85]
# [0.08518086347724621, 1.6]
# [0.08206330597889801, 1.55]
# [0.0706713780918728, 1.9]
# [0.08865248226950355, 1.35]
# [0.10191846522781775, 0.75]
# [0.08372641509433962, 1.65]
# [0.06820809248554913, 1.85]
# [0.08187134502923976, 1.7]
# ...

# %%
picky_test(50,'Zipf_a:1,1_c:20_s:5000.csv')
# Out:
# [0.05801169590643275, 2.11]
# [0.07403055229142186, 1.84]
# [0.06426735218508997, 2.31]
# [0.06445542225358739, 2.35]
# [0.06953488372093024, 1.82]
# [0.06724664942393604, 2.09]
# [0.07875671885954662, 1.45]
# [0.0686826066572902, 2.36]
# [0.07027784263366799, 1.81]
# [0.07501161170459823, 1.81]
# [0.07663551401869159, 1.81]
# [0.09201307800093414, 1.35]
# [0.07162921348314606, 2.1]
# [0.07033639143730887, 1.68]
# [0.0699976431769974, 2.25]
# [0.07215279415232256, 1.91]
# [0.06700672385810341, 2.34]
# [0.06984349451062835, 1.98]
# [0.0691104366098529, 2.09]
# [0.0606203007518797, 2.54]
# [0.0693655303030303, 1.94]
# [0.06373471307619943, 2.25]
# [0.07312529110386586, 1.63]
# [0.0637749120750293, 1.83]
# [0.06383970177073625, 2.05]
# [0.06683864915572232, 1.93]
# [0.07423887587822015, 1.9]
# [0.06711565257779842, 2.04]
# [0.07778556412053259, 1.74]
# [0.072778166550035, 1.6]
# [0.0757821552723059, 1.56]
# [0.07412653446647781, 1.68]
# [0.0755691152311664, 1.47]
# ...

# %%
picky_test(100,'Zipf_a:1,1_c:20_s:5000.csv')
# Out:
# [0.03111111111111111, 2.24]
# [0.03384253819036428, 2.16]
# [0.028978733348913297, 2.02]
# [0.03269818866149141, 1.92]
# [0.03627906976744186, 1.66]
# [0.02774512109099459, 2.52]
# [0.033419023136246784, 2.14]
# [0.030707923112986403, 1.96]
# [0.03455521830492645, 1.78]
# [0.04110543427775198, 1.4]
# [0.03364485981308411, 2.06]
# [0.034796823914058854, 1.86]
# [0.037921348314606744, 1.82]
# [0.03575629263702658, 1.76]
# [0.03511666273862833, 1.76]
# [0.031360528177316674, 1.84]
# [0.032228147461163925, 1.88]
# [0.03737444522307872, 1.64]
# [0.03432173710016344, 1.78]
# [0.03148496240601504, 2.08]
# [0.033380681818181816, 2.04]
# [0.03433678269049859, 1.76]
# [0.04052165812761994, 1.62]
# [0.033528722157092614, 1.72]
# [0.03168685927306617, 2.1]
# [0.038461538461538464, 1.64]
# [0.025526932084309135, 2.66]
# [0.04156990246168137, 1.44]
# [0.033169820135482364, 1.9]
# [0.03382318637742011, 1.9]
# [0.03522595596755504, 2.06]
# [0.030453257790368272, 2.26]
# [0.02957052335132598, 2.22]
# ...

# %%
picky_test(250,'Zipf_a:1,1_c:20_s:5000.csv')
# Out:
# [0.019883040935672516, 1.35]
# [0.017861339600470035, 1.75]
# [0.013087169899509232, 2.35]
# [0.017642907551164433, 1.45]
# [0.01953488372093023, 1.1]
# [0.01434281683517517, 2.25]
# [0.015891563449404067, 2.0]
# [0.01804969526488514, 1.25]
# [0.015876721923885128, 2.15]
# [0.01741755689735253, 1.8]
# [0.014719626168224299, 2.15]
# [0.014479215319943952, 2.2]
# [0.0149812734082397, 2.3]
# [0.015055281110326982, 2.1]
# [0.017440490219184538, 1.7]
# [0.018391888705493988, 1.35]
# [0.01831671690238813, 1.85]
# [0.014949778089231487, 2.0]
# [0.012841466261965912, 2.35]
# [0.022556390977443608, 0.8]
# [0.021070075757575756, 1.25]
# [0.01669802445907808, 1.5]
# [0.01560316721006055, 1.85]
# [0.01242672919109027, 2.25]
# [0.02050326188257223, 1.05]
# [0.018058161350844277, 1.6]
# [0.01522248243559719, 2.2]
# [0.015095215977705528, 2.25]
# [0.016584910067741182, 1.85]
# [0.015162118031257289, 1.9]
# [0.018076477404403244, 1.6]
# [0.018885741265344664, 1.55]
# [0.01854024876789486, 1.45]
# ...

# %%
picky_test(100,'Zipf_a:1,1_c:20_s:10000.csv')
# Out:
# [0.032141187470780735, 2.08]
# [0.029765378779035834, 2.1]
# [0.028878755992049573, 2.22]
# [0.03650738286245785, 2.03]
# [0.03297341228375711, 2.12]
# [0.03727942035760196, 1.65]
# [0.03010072616537831, 2.31]
# [0.03250232991612302, 2.18]
# [0.03245079662605436, 1.96]
# [0.02878787878787879, 2.25]
# [0.03579730357973036, 1.89]
# [0.03442240373395566, 2.01]
# [0.032276926675242665, 2.13]
# [0.027336448598130843, 2.57]
# [0.03527357392316647, 1.76]
# [0.028038479587048335, 2.21]
# [0.03450695987834834, 1.74]
# [0.03699788583509514, 1.75]
# [0.025746050321825628, 2.47]
# [0.03250321524611247, 2.19]
# [0.030391583869082407, 2.35]
# [0.03529686769518466, 1.84]
# [0.03204225352112676, 2.05]
# [0.035751840168243953, 1.89]
# [0.0384391380314502, 1.86]
# [0.0372006510113927, 1.67]
# [0.030217849613492623, 2.07]
# [0.02541876537425325, 2.47]
# [0.03551816801028158, 1.86]
# [0.032821474621966946, 2.18]
# [0.03070227032113869, 2.06]
# [0.03573923166472642, 1.77]
# [0.038004196782466776, 1.62]
# ...

# %%
picky_test(200,'Zipf_a:1,1_c:20_s:10000.csv')
# Out:
# [0.01729780271154745, 1.78]
# [0.021244309559939303, 1.4]
# [0.016485443703963522, 2.46]
# [0.01569584931984653, 2.28]
# [0.015906188319981425, 2.22]
# [0.016945191071637257, 1.96]
# [0.01464043101428906, 2.64]
# [0.018872320596458526, 2.22]
# [0.01569821930646673, 2.18]
# [0.012703962703962703, 2.86]
# [0.013482101348210134, 2.66]
# [0.017852975495915985, 2.06]
# [0.014735118699567302, 2.66]
# [0.014953271028037384, 2.42]
# [0.01979045401629802, 1.84]
# [0.015720319099014547, 2.12]
# [0.015908293367645338, 2.12]
# [0.014799154334038054, 2.44]
# [0.01556465769455822, 2.68]
# [0.013796328773529756, 2.66]
# [0.015078901227352426, 2.12]
# [0.015427769985974754, 2.2]
# [0.013967136150234741, 2.12]
# [0.013552985161817969, 2.26]
# [0.01817122888759464, 2.24]
# [0.018367821436875147, 1.98]
# [0.013234949636917312, 2.64]
# [0.019327632657842334, 1.98]
# [0.016240214978385327, 2.3]
# [0.017348493728753956, 2.46]
# [0.014586519233031408, 2.18]
# [0.016763678696158323, 1.96]
# ...

# %%
picky_test(500,'Zipf_a:1,1_c:20_s:10000.csv')
# Out:
# [0.0091164095371669, 1.5]
# [0.009221431072720906, 1.45]
# [0.010171869519466853, 1.3]
# [0.01023136844552959, 1.15]
# [0.009404388714733543, 1.65]
# [0.007011803202056795, 2.2]
# [0.007730147575544624, 2.0]
# [0.009902143522833178, 1.3]
# [0.006326148078725398, 2.55]
# [0.006876456876456876, 2.2]
# [0.009181775918177593, 1.35]
# [0.009218203033838973, 1.5]
# [0.008420067828324173, 1.9]
# [0.008411214953271028, 1.75]
# [0.010011641443538999, 1.5]
# [0.00680431722196152, 2.65]
# [0.00865598315592467, 1.75]
# [0.008339206013624619, 2.25]
# [0.009245172615564658, 1.25]
# [0.011457967964456917, 0.8]
# [0.010753945061367622, 1.2]
# [0.008181393174380552, 1.95]
# [0.00727699530516432, 1.95]
# [0.0077111812127585, 1.8]
# [0.006988934187536401, 2.05]
# [0.008370146477563357, 1.85]
# [0.007964394471773249, 1.55]
# [0.00855101323649994, 1.55]
# [0.007360672975814932, 2.0]
# [0.0059781971632868365, 2.5]
# [0.0059992942006822725, 2.7]
# [0.008032596041909196, 2.4]
# [0.006644905572394498, 2.4]
# ...

# %%
picky_test(10,'Zipf_a:1,1_c:50_s:1000.csv')
# Out:
# [0.9041248606465998, 0.0]
# [0.8728908886389202, 0.0]
# [0.9014396456256921, 0.0]
# [0.8783482142857143, 0.0]
# [0.9029345372460497, 0.0]
# [0.8618063112078346, 0.0]
# [0.8927374301675978, 0.0]
# [0.8866666666666667, 0.0]
# [0.9042316258351893, 0.0]
# [0.8661504424778761, 0.0]
# [0.8885172798216276, 0.0]
# [0.9044444444444445, 0.0]
# [0.8904867256637168, 0.0]
# [0.9090909090909091, 0.0]
# [0.8748603351955307, 0.0]
# [0.898360655737705, 0.0]
# [0.9073660714285714, 0.0]
# [0.8571428571428571, 0.0]
# [0.8923766816143498, 0.0]
# [0.8917700112739572, 0.0]
# [0.8851727982162765, 0.0]
# [0.889763779527559, 0.0]
# [0.884090909090909, 0.0]
# [0.8916201117318435, 0.0]
# [0.8909487459105779, 0.0]
# [0.8745800671892497, 0.0]
# [0.8860335195530726, 0.0]
# [0.9060402684563759, 0.0]
# [0.8958097395243488, 0.0]
# [0.9059734513274337, 0.0]
# [0.90625, 0.0]
# [0.879424778761062, 0.0]
# [0.8961325966850828, 0.0]
# [0.8663697104677061, 0.0]
# [0.9116647791619479, 0.0]
# [0.8845291479820628, 0.0]
# ...

# %%
picky_test(20,'Zipf_a:1,1_c:50_s:1000.csv')
# Out:
# [0.7725752508361204, 0.02]
# [0.7019122609673791, 0.16]
# [0.7397563676633444, 0.0]
# [0.7399553571428571, 0.06]
# [0.708803611738149, 0.0]
# [0.7780195865070729, 0.0]
# [0.7642458100558659, 0.0]
# [0.7511111111111111, 0.02]
# [0.6737193763919822, 0.1]
# [0.6969026548672567, 0.02]
# [0.6120401337792643, 0.28]
# [0.6844444444444444, 0.0]
# [0.7400442477876106, 0.0]
# [0.761640798226164, 0.0]
# [0.8055865921787709, 0.06]
# [0.7366120218579235, 0.0]
# [0.8348214285714286, 0.0]
# [0.7441860465116279, 0.0]
# [0.6748878923766816, 0.04]
# [0.7350620067643743, 0.0]
# [0.7357859531772575, 0.0]
# [0.6861642294713161, 0.1]
# [0.6670454545454545, 0.0]
# [0.7217877094972067, 0.06]
# [0.8157033805888768, 0.02]
# [0.6942889137737962, 0.12]
# [0.7575418994413408, 0.0]
# [0.6577181208053692, 0.16]
# [0.7259343148357871, 0.04]
# [0.7853982300884956, 0.02]
# [0.7254464285714286, 0.04]
# [0.7787610619469026, 0.0]
# [0.7348066298342542, 0.04]
# [0.6948775055679287, 0.1]
# [0.7746319365798414, 0.0]
# ...

# %%
picky_test(50,'Zipf_a:1,1_c:50_s:1000.csv')
# Out:
# [0.15830546265328874, 2.3]
# [0.14623172103487064, 2.65]
# [0.16279069767441862, 2.4]
# [0.17299107142857142, 1.7]
# [0.15349887133182843, 2.25]
# [0.15233949945593037, 2.45]
# [0.15307262569832403, 2.5]
# [0.16333333333333333, 2.25]
# [0.155902004454343, 2.35]
# [0.15486725663716813, 2.35]
# [0.16610925306577481, 1.85]
# [0.16, 2.1]
# [0.16924778761061948, 1.85]
# [0.17405764966740578, 1.9]
# [0.15195530726256984, 2.15]
# [0.16174863387978142, 2.0]
# [0.18303571428571427, 1.5]
# [0.16057585825027684, 2.1]
# [0.15582959641255606, 2.0]
# [0.15219842164599776, 2.4]
# [0.15384615384615385, 2.4]
# [0.140607424071991, 2.45]
# [0.15113636363636362, 2.55]
# [0.15195530726256984, 2.65]
# [0.1777535441657579, 1.9]
# [0.1601343784994401, 2.1]
# [0.1452513966480447, 2.45]
# [0.14205816554809844, 2.45]
# [0.14722536806342015, 2.65]
# [0.16924778761061948, 2.4]
# [0.16071428571428573, 2.15]
# [0.1504424778761062, 2.45]
# [0.14696132596685083, 2.5]
# [0.155902004454343, 2.3]
# ...

# %%
picky_test(50,'Zipf_a:1,1_c:50_s:5000.csv')
# Out:
# [0.14062150681868993, 2.42]
# [0.13221476510067115, 2.34]
# [0.13196152985909193, 2.88]
# [0.14000886132033674, 2.34]
# [0.13071603836716483, 2.56]
# [0.144, 2.18]
# [0.14355773517610343, 2.41]
# [0.13972055888223553, 2.39]
# [0.14158504007123776, 2.24]
# [0.13977298019140885, 2.34]
# [0.14225383418537452, 2.14]
# [0.13541899441340782, 2.67]
# [0.14183284786018374, 2.53]
# [0.14001766784452296, 2.23]
# [0.13411078717201166, 2.47]
# [0.13694338778250167, 2.44]
# [0.12425644415069398, 2.67]
# [0.14339875111507583, 2.35]
# [0.12853356890459364, 2.44]
# [0.1359590565198042, 2.45]
# [0.1309655937846837, 2.74]
# [0.13333333333333333, 2.57]
# [0.14194682487365415, 2.18]
# [0.13514109347442682, 2.42]
# [0.13145017793594305, 2.74]
# [0.13450814186928395, 2.32]
# [0.14384017758046616, 2.29]
# [0.136788256227758, 2.31]
# [0.14022222222222222, 2.49]
# [0.13512304250559284, 2.42]
# [0.1435886019590383, 2.32]
# [0.1490933512424446, 2.09]
# [0.13678083725095141, 2.47]
# [0.12751228226887004, 2.85]
# ...

# %%
picky_test(100,'Zipf_a:1,1_c:50_s:5000.csv')
# Out:
# [0.07176391683433937, 2.72]
# [0.07136465324384787, 2.88]
# [0.06128382912100201, 3.54]
# [0.07244129375276916, 2.98]
# [0.06513495427169307, 3.14]
# [0.07466666666666667, 2.7]
# [0.06776638430673206, 3.46]
# [0.07119095143047238, 2.88]
# [0.07101513802315228, 2.96]
# [0.07300244825283775, 2.9]
# [0.07535007779506557, 2.96]
# [0.07620111731843575, 3.16]
# [0.05982522966614385, 3.28]
# [0.07906360424028269, 2.32]
# [0.0630186140390222, 3.46]
# [0.07563213246811368, 2.46]
# [0.06983917162370566, 3.04]
# [0.07136485280999108, 2.68]
# [0.07332155477031801, 2.58]
# [0.07098353360035603, 2.66]
# [0.07014428412874583, 2.72]
# [0.06956521739130435, 3.02]
# [0.06877609316633707, 3.06]
# [0.07297178130511464, 2.92]
# [0.06405693950177936, 3.48]
# [0.06535801918358242, 3.08]
# [0.06526082130965594, 3.14]
# [0.06694839857651246, 3.06]
# [0.074, 2.6]
# [0.07046979865771812, 2.98]
# [0.06967943009795191, 3.28]
# [0.0662637116633087, 2.74]
# [0.06447280053727333, 3.08]
# ...

# %%
picky_test(250,'Zipf_a:1,1_c:50_s:5000.csv')
# Out:
# [0.028839704896042925, 3.45]
# [0.032885906040268455, 3.5]
# [0.03086557817043167, 3.85]
# [0.03190075321222862, 3.1]
# [0.024760205219718938, 4.1]
# [0.034, 3.65]
# [0.03209986625055729, 3.8]
# [0.031492570414726105, 3.5]
# [0.03272484416740873, 3.45]
# [0.02848876029379034, 3.5]
# [0.02689486552567237, 3.75]
# [0.033743016759776534, 3.3]
# [0.02688774367017701, 3.3]
# [0.030477031802120143, 3.9]
# [0.030500112132765194, 3.25]
# [0.027075408368762585, 3.5]
# [0.03150473672615114, 3.2]
# [0.03144513826940232, 3.45]
# [0.03312720848056537, 3.35]
# [0.03471295060080107, 3.2]
# [0.03240843507214206, 3.4]
# [0.03366778149386845, 3.75]
# [0.028345418589321027, 3.15]
# [0.03218694885361552, 3.65]
# [0.03425266903914591, 3.65]
# [0.029890698193174213, 3.45]
# [0.03107658157602664, 3.05]
# [0.029137010676156583, 4.4]
# [0.03088888888888889, 3.15]
# [0.03154362416107383, 3.3]
# [0.03227960819234194, 3.35]
# [0.029550033579583614, 3.35]
# [0.03066935303335572, 3.05]
# ...

# %%
picky_test(100,'Zipf_a:1,1_c:50_s:10000.csv')
# Out:
# [0.06731413261888815, 2.96]
# [0.07389656709763709, 2.65]
# [0.06424581005586592, 3.12]
# [0.06497112394491338, 3.44]
# [0.06405417406749556, 3.07]
# [0.06732274658912994, 2.93]
# [0.07084074733096085, 2.67]
# [0.0705765407554672, 2.92]
# [0.06623030840914133, 3.19]
# [0.06537180910099889, 3.17]
# [0.06671864557807974, 2.91]
# [0.05991456834532374, 3.37]
# [0.07032991529201961, 2.91]
# [0.06330806954971022, 3.25]
# [0.07023559340780887, 2.95]
# [0.06685113447703375, 3.18]
# [0.06527299010341377, 3.02]
# [0.06519804183355585, 3.01]
# [0.06318496980541266, 3.25]
# [0.061883109681712324, 3.27]
# [0.0669404973357016, 2.98]
# [0.0632260947274352, 3.06]
# [0.06641450661920124, 3.02]
# [0.06842750473643151, 2.88]
# [0.06593649740015488, 3.04]
# [0.06071109123434705, 3.56]
# [0.0721981561701655, 2.9]
# [0.06579535299374442, 2.92]
# [0.06754658385093168, 3.05]
# [0.06261120996441281, 3.21]
# [0.06323890252063351, 3.02]
# [0.06945059813912273, 3.17]
# [0.07106373528758606, 3.03]
# ...

# %%
picky_test(200,'Zipf_a:1,1_c:50_s:10000.csv')
# Out:
# [0.029582496092877875, 3.82]
# [0.03165403477485511, 3.96]
# [0.02893854748603352, 4.04]
# [0.03198578409595735, 3.48]
# [0.03441385435168739, 3.3]
# [0.030082755535674344, 4.14]
# [0.031917259786476866, 3.76]
# [0.030704660923348795, 3.56]
# [0.028733081872642556, 4.18]
# [0.033518312985571584, 3.32]
# [0.029405212742258855, 4.02]
# [0.030238309352517985, 3.8]
# [0.032545697726259475, 3.7]
# [0.03466339723584485, 3.78]
# [0.03307156288021237, 3.9]
# [0.037188710570005536, 3.26]
# [0.036361614589124874, 3.12]
# [0.03337783711615487, 3.14]
# [0.032543055244911655, 3.9]
# [0.0327159809249196, 3.46]
# [0.03641207815275311, 3.56]
# [0.03049597855227882, 3.94]
# [0.036155300923350765, 3.08]
# [0.03488242505293659, 3.08]
# [0.030644982852085407, 3.7]
# [0.028510733452593917, 4.26]
# [0.031433966455625906, 3.46]
# [0.03708668453976765, 3.82]
# [0.03527062999112689, 3.6]
# [0.031694839857651244, 3.58]
# [0.03178674994423377, 3.32]
# [0.03622064687638458, 3.28]
# [0.0313124583610926, 3.46]
# ...

# %%
picky_test(500,'Zipf_a:1,1_c:50_s:10000.csv')
# Out:
# [0.017526233534271043, 3.9]
# [0.01560410164957646, 4.05]
# [0.018100558659217877, 2.5]
# [0.017214571301643715, 2.85]
# [0.014764653641207815, 3.1]
# [0.013419816595839858, 3.95]
# [0.0185720640569395, 2.55]
# [0.01634636624696267, 4.4]
# [0.013312624805857555, 4.55]
# [0.0146503884572697, 3.45]
# [0.01659612385832034, 3.65]
# [0.01731115107913669, 3.0]
# [0.018167632634864022, 3.35]
# [0.01683013820775747, 3.6]
# [0.018360800796372083, 3.0]
# [0.01383508577753182, 3.6]
# [0.017791615701100855, 3.05]
# [0.016688918558077435, 3.25]
# [0.017333929769626482, 3.25]
# [0.01829876899190418, 2.55]
# [0.015208703374777975, 3.75]
# [0.014857015192135836, 3.4]
# [0.015908332406274334, 4.0]
# [0.015045135406218655, 3.3]
# [0.015045912158424605, 4.6]
# [0.01677101967799642, 3.45]
# [0.01732755748083972, 4.4]
# [0.014745308310991957, 4.25]
# [0.017080745341614908, 3.7]
# [0.013790035587188613, 4.6]
# [0.014276154360919028, 3.6]
# [0.01561807709348693, 3.8]
# [0.01587830335332001, 3.4]
# ...
