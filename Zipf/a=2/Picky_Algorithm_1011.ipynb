# %%
#all necessary side algorithms

#finds the number of color changes in a given list
def nb_of_change(x):
    count=0
    i=0
    while i<(len(x)-1):
        if x[i]!=x[i+1]:
            count=count+1
            i=i+1
        else:
            i=i+1
    return count

#adds k items to the buffer from the input
def add(k, data,buffer):
    while k>0:
        buffer.append(data.pop(0))
        k=k-1
        
#finds and lists the unique items in a given list
def unique(list1): 
    unique_list = [] 
    for x in list1: 
        if x not in unique_list: 
            unique_list.append(x)
    return unique_list

#finds the most freq color in buffer
def most_freq(List): 
    return max(set(List), key = List.count)

#evicts c_act, appends output, removes from buffer, fills buffer till there is no c_act in buffer 
def evict(c_act, data, buffer,output_,k):
    while (c_act in buffer)==True:
        count=0
        buffer.remove(c_act)
        count=count+1
        for i in range(0,count):
            output_.append(c_act)
        while len(buffer)<k and len(data)!=0:
            add(k-len(buffer), data,buffer)
    return output_

#finds the second most frequent color in a given list
def second_most_freq(List): 
    from collections import Counter 
    occurence_count = Counter(List) 
    if len(occurence_count)>=2:
        return occurence_count.most_common(2)[1][0]
    else:
        return -1
    
#finds the occurence of a given color in a given list      
def occurence(List, x): 
    count=0
    for i in range (0, len(List)):
        if List[i]==x:
            count=count+1
    return count


#finds the least freq color in buffer
def least_freq(List): 
    return min(set(List), key = List.count)

# %%
def picky(k,input_):
    import numpy as np
    import math
    buffer=input_[0:0]
    output_=input_[0:0]
    data=input_[:]
    nb_of_delays=0
    c_act=-1
    result=[0]*2
    

    while len(data)!=0:
        ex=0
        while len(buffer)<k and len(data)!=0:

            add(min((k-len(buffer)), len(data)), data, buffer)
            

            if (c_act!=-1 and (c_act in buffer)==True):
                while (c_act in buffer)==True:
                    buffer.remove(c_act)
                    output_.append(c_act)

                    add(min(1,len(data)), data, buffer)
            else:
                continue
            if len(buffer)==0:
                break
                
            #nb of colors in the buffer is sigma
            sigma=len(unique(buffer))
            #most frequent color in the buffer
            o_1=most_freq(buffer)
            size_of_o1=occurence(buffer,o_1)
        

            while (size_of_o1 >= 2 * (math.ceil(len(buffer)/sigma))) and ex<len(data):

                delayed=least_freq(buffer)
                while (delayed in buffer)==True:
                    nb_of_delays=nb_of_delays+1
                    ex=ex+1
                    buffer.remove(delayed)
                    data.append(delayed)
                if len(buffer)==0:
                    break
                    
                    

        if len(buffer)!=0:
            c_act=most_freq(buffer)
            while(c_act in buffer)==True:
                buffer.remove(c_act)
                output_.append(c_act)
            

    while len(buffer)!=0:
        c_act=most_freq(buffer)
        while (c_act in buffer)==True:
            buffer.remove(c_act)
            output_.append(c_act)
            
    result[0]=float(nb_of_change(output_)/nb_of_change(input_))
    result[1]=float(nb_of_delays/len(input_))
    print(result)

# %%
#reads data from given text and makes test of delay alg.
def picky_test(k,text):
    import pandas as pd
    data=pd.read_csv(text, header=None)

    input_1=(data.iloc[0]).tolist()
    input_2=(data.iloc[1]).tolist()
    input_3=(data.iloc[2]).tolist()
    input_4=(data.iloc[3]).tolist()
    input_5=(data.iloc[4]).tolist()
    input_6=(data.iloc[5]).tolist()
    input_7=(data.iloc[6]).tolist()
    input_8=(data.iloc[7]).tolist()
    input_9=(data.iloc[8]).tolist()
    input_10=(data.iloc[9]).tolist()

    input_11=(data.iloc[10]).tolist()
    input_12=(data.iloc[11]).tolist()
    input_13=(data.iloc[12]).tolist()
    input_14=(data.iloc[13]).tolist()
    input_15=(data.iloc[14]).tolist()
    input_16=(data.iloc[15]).tolist()
    input_17=(data.iloc[16]).tolist()
    input_18=(data.iloc[17]).tolist()
    input_19=(data.iloc[18]).tolist()
    input_20=(data.iloc[19]).tolist()

    input_21=(data.iloc[20]).tolist()
    input_22=(data.iloc[21]).tolist()
    input_23=(data.iloc[22]).tolist()
    input_24=(data.iloc[23]).tolist()
    input_25=(data.iloc[24]).tolist()
    input_26=(data.iloc[25]).tolist()
    input_27=(data.iloc[26]).tolist()
    input_28=(data.iloc[27]).tolist()
    input_29=(data.iloc[28]).tolist()
    input_30=(data.iloc[29]).tolist()

    input_31=(data.iloc[30]).tolist()
    input_32=(data.iloc[31]).tolist()
    input_33=(data.iloc[32]).tolist()
    input_34=(data.iloc[33]).tolist()
    input_35=(data.iloc[34]).tolist()
    input_36=(data.iloc[35]).tolist()
    input_37=(data.iloc[36]).tolist()
    input_38=(data.iloc[37]).tolist()
    input_39=(data.iloc[38]).tolist()
    input_40=(data.iloc[39]).tolist()

    input_41=(data.iloc[40]).tolist()
    input_42=(data.iloc[41]).tolist()
    input_43=(data.iloc[42]).tolist()
    input_44=(data.iloc[43]).tolist()
    input_45=(data.iloc[44]).tolist()
    input_46=(data.iloc[45]).tolist()
    input_47=(data.iloc[46]).tolist()
    input_48=(data.iloc[47]).tolist()
    input_49=(data.iloc[48]).tolist()
    input_50=(data.iloc[49]).tolist()

    picky(k,input_1)
    picky(k,input_2)
    picky(k,input_3)
    picky(k,input_4)
    picky(k,input_5)
    picky(k,input_6)
    picky(k,input_7)
    picky(k,input_8)
    picky(k,input_9)
    picky(k,input_10)

    picky(k,input_11)
    picky(k,input_12)
    picky(k,input_13)
    picky(k,input_14)
    picky(k,input_15)
    picky(k,input_16)
    picky(k,input_17)
    picky(k,input_18)
    picky(k,input_19)
    picky(k,input_20)

    picky(k,input_21)
    picky(k,input_22)
    picky(k,input_23)
    picky(k,input_24)
    picky(k,input_25)
    picky(k,input_26)
    picky(k,input_27)
    picky(k,input_28)
    picky(k,input_29)
    picky(k,input_30)

    picky(k,input_31)
    picky(k,input_32)
    picky(k,input_33)
    picky(k,input_34)
    picky(k,input_35)
    picky(k,input_36)
    picky(k,input_37)
    picky(k,input_38)
    picky(k,input_39)
    picky(k,input_40)

    picky(k,input_41)
    picky(k,input_42)
    picky(k,input_43)
    picky(k,input_44)
    picky(k,input_45)
    picky(k,input_46)
    picky(k,input_47)
    picky(k,input_48)
    picky(k,input_49)
    picky(k,input_50)

# %%
picky_test(10,'Zipf_a:2_c:10_s:1000.csv')
# Out:
# [0.2808219178082192, 0.17]
# [0.22826086956521738, 0.27]
# [0.266199649737303, 0.21]
# [0.19038817005545286, 0.28]
# [0.22597864768683273, 0.2]
# [0.2742857142857143, 0.18]
# [0.3025210084033613, 0.15]
# [0.29061371841155237, 0.13]
# [0.22142857142857142, 0.25]
# [0.25272727272727274, 0.18]
# [0.26344086021505375, 0.23]
# [0.25884543761638734, 0.16]
# [0.2530541012216405, 0.18]
# [0.3049645390070922, 0.14]
# [0.21256931608133087, 0.34]
# [0.2509090909090909, 0.15]
# [0.28776978417266186, 0.16]
# [0.30347349177330896, 0.13]
# [0.2737430167597765, 0.12]
# [0.25140712945590993, 0.18]
# [0.24356775300171526, 0.24]
# [0.32633587786259544, 0.11]
# [0.21858864027538727, 0.19]
# [0.25183823529411764, 0.18]
# [0.3014705882352941, 0.11]
# [0.31881533101045295, 0.09]
# [0.28169014084507044, 0.16]
# [0.26455026455026454, 0.17]
# [0.21755027422303475, 0.25]
# [0.2983425414364641, 0.13]
# [0.2427843803056027, 0.18]
# [0.23688969258589512, 0.15]
# [0.22241992882562278, 0.21]
# ...

# %%
picky_test(20,'Zipf_a:2_c:10_s:1000.csv')
# Out:
# [0.09417808219178082, 0.72]
# [0.08876811594202899, 0.62]
# [0.08231173380035026, 0.48]
# [0.09611829944547134, 0.36]
# [0.07295373665480427, 0.62]
# [0.08761904761904762, 0.44]
# [0.07899159663865546, 0.74]
# [0.11913357400722022, 0.56]
# [0.048214285714285716, 0.6]
# [0.10909090909090909, 0.46]
# [0.06272401433691756, 0.8]
# [0.07076350093109869, 0.58]
# [0.08900523560209424, 0.38]
# [0.09219858156028368, 0.54]
# [0.08687615526802218, 0.58]
# [0.05454545454545454, 0.7]
# [0.07553956834532374, 0.88]
# [0.11517367458866545, 0.26]
# [0.061452513966480445, 0.6]
# [0.08630393996247655, 0.5]
# [0.08747855917667238, 0.44]
# [0.07442748091603053, 0.44]
# [0.08261617900172118, 0.44]
# [0.0625, 0.84]
# [0.07169117647058823, 0.5]
# [0.08536585365853659, 0.44]
# [0.07394366197183098, 0.62]
# [0.10758377425044091, 0.36]
# [0.08226691042047532, 0.56]
# [0.04788213627992634, 0.64]
# [0.09847198641765705, 0.56]
# [0.08860759493670886, 0.42]
# [0.07295373665480427, 0.42]
# ...

# %%
picky_test(50,'Zipf_a:2_c:10_s:1000.csv')
# Out:
# [0.04280821917808219, 0.4]
# [0.034420289855072464, 0.7]
# [0.03152364273204904, 0.65]
# [0.04251386321626617, 0.35]
# [0.01601423487544484, 0.6]
# [0.03619047619047619, 0.45]
# [0.02857142857142857, 0.55]
# [0.02707581227436823, 0.6]
# [0.033928571428571426, 0.45]
# [0.034545454545454546, 0.6]
# [0.01971326164874552, 0.65]
# [0.0260707635009311, 0.55]
# [0.04363001745200698, 0.35]
# [0.031914893617021274, 0.5]
# [0.04251386321626617, 0.4]
# [0.02181818181818182, 0.65]
# [0.030575539568345324, 0.55]
# [0.029250457038391225, 0.55]
# [0.0260707635009311, 0.55]
# [0.0375234521575985, 0.35]
# [0.029159519725557463, 0.55]
# [0.02099236641221374, 0.65]
# [0.029259896729776247, 0.55]
# [0.025735294117647058, 0.55]
# [0.027573529411764705, 0.5]
# [0.03484320557491289, 0.5]
# [0.028169014084507043, 0.7]
# [0.05291005291005291, 0.75]
# [0.02376599634369287, 0.45]
# [0.03130755064456722, 0.5]
# [0.02037351443123939, 0.65]
# [0.03074141048824593, 0.45]
# [0.021352313167259787, 0.6]
# ...

# %%
picky_test(50,'Zipf_a:2_c:10_s:5000.csv')
# Out:
# [0.024070021881838075, 0.53]
# [0.017660044150110375, 0.67]
# [0.022867513611615244, 0.93]
# [0.02498240675580577, 1.0]
# [0.020931071815229157, 0.72]
# [0.02013177159590044, 0.7]
# [0.01818181818181818, 0.69]
# [0.01908256880733945, 0.68]
# [0.01898960945897528, 0.68]
# [0.011909058101768314, 0.73]
# [0.02459618208516887, 0.63]
# [0.011322132943754566, 1.19]
# [0.01775147928994083, 0.7]
# [0.015253636041149344, 0.82]
# [0.017664023071377072, 0.81]
# [0.01772525849335303, 0.67]
# [0.019065420560747663, 0.55]
# [0.0276707530647986, 0.66]
# [0.03089080459770115, 0.49]
# [0.01956521739130435, 0.73]
# [0.015716374269005847, 0.67]
# [0.019765739385065886, 0.72]
# [0.02290909090909091, 0.69]
# [0.02242493348536678, 0.67]
# [0.01806118687799484, 0.63]
# [0.014197306152166, 0.75]
# [0.022884126407555393, 0.6]
# [0.023204419889502764, 0.7]
# [0.0227765726681128, 0.63]
# [0.022719328905976933, 0.67]
# [0.017653549098933432, 0.82]
# [0.01901686401148188, 0.95]
# [0.02371987951807229, 0.64]
# ...

# %%
picky_test(100,'Zipf_a:2_c:10_s:5000.csv')
# Out:
# [0.012035010940919038, 0.68]
# [0.01177336276674025, 0.52]
# [0.008711433756805808, 0.72]
# [0.009500351864883884, 0.72]
# [0.011187297004691447, 0.56]
# [0.010980966325036604, 0.7]
# [0.008912655971479501, 0.84]
# [0.008807339449541285, 0.64]
# [0.012182013615191688, 0.56]
# [0.008300252616383976, 0.68]
# [0.007342143906020558, 0.66]
# [0.008765522279035792, 0.66]
# [0.01220414201183432, 0.52]
# [0.010642071656615822, 0.68]
# [0.00829127613554434, 0.84]
# [0.01070901033973412, 0.68]
# [0.010841121495327103, 0.62]
# [0.01436077057793345, 0.66]
# [0.013649425287356323, 0.58]
# [0.013043478260869565, 0.72]
# [0.006944444444444444, 0.7]
# [0.00841874084919473, 0.86]
# [0.009454545454545455, 0.6]
# [0.008741923223109084, 0.66]
# [0.007740508661997788, 0.68]
# [0.010192937750273025, 0.56]
# [0.00980748274609517, 0.64]
# [0.006998158379373849, 0.78]
# [0.01012292118582791, 0.72]
# [0.008039147151345682, 0.78]
# [0.016182420007355647, 0.46]
# [0.009329027628274129, 0.68]
# ...

# %%
picky_test(250,'Zipf_a:2_c:10_s:5000.csv')
# Out:
# [0.0040116703136396795, 0.7]
# [0.0051508462104488595, 0.5]
# [0.005807622504537205, 0.5]
# [0.005981703026038001, 0.6]
# [0.003608805485384338, 0.65]
# [0.005856515373352855, 0.5]
# [0.004634581105169341, 0.65]
# [0.005504587155963303, 0.5]
# [0.005374417771408097, 0.5]
# [0.00577408877661494, 0.55]
# [0.0047723935389133625, 0.6]
# [0.003652300949598247, 0.65]
# [0.0040680473372781065, 0.6]
# [0.005321035828307911, 0.5]
# [0.005407354001441961, 0.5]
# [0.005908419497784343, 0.7]
# [0.005233644859813084, 0.45]
# [0.005954465849387041, 0.65]
# [0.005747126436781609, 0.5]
# [0.004347826086956522, 0.6]
# [0.0043859649122807015, 0.6]
# [0.004758418740849195, 0.65]
# [0.0036363636363636364, 0.7]
# [0.004180919802356519, 0.7]
# [0.005897530409141172, 0.5]
# [0.0036403349108117948, 0.65]
# [0.005811841627315656, 0.5]
# [0.004051565377532229, 0.6]
# [0.005422993492407809, 0.5]
# [0.009437259699405802, 0.35]
# [0.006987863184994484, 0.45]
# [0.006099748833871547, 0.5]
# ...

# %%
picky_test(100,'Zipf_a:2_c:10_s:10000.csv')
# Out:
# [0.0057960514399565295, 0.7]
# [0.008686210640608035, 0.62]
# [0.008460548096376677, 0.85]
# [0.004026354319180088, 0.79]
# [0.009744438315866888, 0.66]
# [0.009780836804926644, 0.61]
# [0.011521580102414046, 0.76]
# [0.006546644844517185, 0.96]
# [0.009599409267122024, 0.79]
# [0.00842645173108628, 0.7]
# [0.00974264705882353, 0.76]
# [0.004889532777978993, 0.96]
# [0.005494505494505495, 0.79]
# [0.008310249307479225, 0.72]
# [0.007043525374751671, 0.76]
# [0.008239297868529465, 0.91]
# [0.01007737988123088, 0.65]
# [0.008786085709162632, 0.63]
# [0.009164420485175202, 0.62]
# [0.007186290768380321, 0.75]
# [0.007614213197969543, 0.66]
# [0.004609144542772861, 0.86]
# [0.005746094451427546, 1.0]
# [0.007787033683448026, 0.77]
# [0.010216884746370317, 0.67]
# [0.012217697149203998, 0.62]
# [0.008601756954612006, 0.65]
# [0.009827115559599637, 0.75]
# [0.008183306055646482, 0.72]
# [0.009606670291825267, 0.68]
# [0.006835396268243118, 0.74]
# [0.007334066740007334, 0.71]
# ...

# %%
picky_test(200,'Zipf_a:2_c:10_s:10000.csv')
# Out:
# [0.003260278934975548, 0.68]
# [0.003981179876945349, 0.7]
# [0.0068052234688247195, 0.5]
# [0.004209370424597365, 0.66]
# [0.004044861187718331, 0.78]
# [0.004528165187466039, 0.66]
# [0.0038405267008046816, 0.74]
# [0.006001091107474086, 0.64]
# [0.006830348901606055, 0.6]
# [0.007327349331379373, 0.64]
# [0.004411764705882353, 0.7]
# [0.004708438971387179, 0.66]
# [0.003663003663003663, 0.72]
# [0.0046168051708217915, 0.62]
# [0.003973270724218891, 0.72]
# [0.0041196489342647325, 0.68]
# [0.003958970667626417, 0.72]
# [0.004482696790389098, 0.66]
# [0.004672057502246182, 0.64]
# [0.005343652109821264, 0.62]
# [0.005438723712835388, 0.84]
# [0.004424778761061947, 0.66]
# [0.005027832644999102, 0.72]
# [0.005613908004346252, 0.66]
# [0.005735794945330704, 0.72]
# [0.004998148833765272, 0.64]
# [0.005856515373352855, 0.62]
# [0.004549590536851683, 0.76]
# [0.0032733224222585926, 0.76]
# [0.0036251586006887803, 0.68]
# [0.005911694069831886, 0.52]
# [0.004217088375504217, 0.68]
# ...

# %%
picky_test(500,'Zipf_a:2_c:10_s:10000.csv')
# Out:
# [0.0018112660749864155, 0.65]
# [0.0027144408251900108, 0.5]
# [0.0033106492551039177, 0.55]
# [0.0018301610541727673, 0.65]
# [0.0027578599007170436, 0.5]
# [0.0018112660749864155, 0.65]
# [0.0027432333577176297, 0.5]
# [0.0032733224222585926, 0.6]
# [0.003322872438619162, 0.55]
# [0.0018318373328448433, 0.65]
# [0.0022058823529411764, 0.65]
# [0.0025353132922854038, 0.5]
# [0.0018315018315018315, 0.65]
# [0.002770083102493075, 0.8]
# [0.0027090482210583348, 0.5]
# [0.002328497223714849, 0.7]
# [0.0019794853338132084, 0.7]
# [0.002510310202617895, 0.6]
# [0.001976639712488769, 0.6]
# [0.0023954302561267735, 0.6]
# [0.001994198694706309, 0.6]
# [0.00331858407079646, 0.55]
# [0.003411743580535105, 0.45]
# [0.0034407823252444766, 0.55]
# [0.0021509231044990144, 0.65]
# [0.002406516105146242, 0.6]
# [0.0029282576866764276, 0.7]
# [0.0029117379435850774, 0.5]
# [0.002727768685215494, 0.5]
# [0.0029001268805510243, 0.5]
# [0.002032144836504711, 0.6]
# [0.002016868353502017, 0.6]
# ...

# %%
picky_test(10,'Zipf_a:2_c:20_s:1000.csv')
# Out:
# [0.4991119005328597, 0.07]
# [0.39600665557404324, 0.1]
# [0.48175182481751827, 0.11]
# [0.6099290780141844, 0.02]
# [0.6097972972972973, 0.08]
# [0.5355987055016181, 0.08]
# [0.6264462809917355, 0.02]
# [0.4103448275862069, 0.09]
# [0.40252707581227437, 0.15]
# [0.6702898550724637, 0.0]
# [0.5754884547069272, 0.02]
# [0.3797909407665505, 0.17]
# [0.32124352331606215, 0.2]
# [0.5322862129144852, 0.05]
# [0.5591397849462365, 0.01]
# [0.4991364421416235, 0.06]
# [0.47130434782608693, 0.07]
# [0.5555555555555556, 0.02]
# [0.45595854922279794, 0.11]
# [0.5423728813559322, 0.08]
# [0.3501628664495114, 0.13]
# [0.4543795620437956, 0.12]
# [0.6068222621184919, 0.05]
# [0.46846846846846846, 0.11]
# [0.6053962900505903, 0.04]
# [0.6342756183745583, 0.01]
# [0.5091575091575091, 0.08]
# [0.526595744680851, 0.03]
# [0.34797891036906853, 0.1]
# [0.507908611599297, 0.05]
# [0.5124792013311148, 0.07]
# [0.6331058020477816, 0.07]
# [0.5276872964169381, 0.02]
# [0.33992805755395683, 0.19]
# ...

# %%
picky_test(20,'Zipf_a:2_c:20_s:1000.csv')
# Out:
# [0.1172291296625222, 0.54]
# [0.07820299500831947, 0.74]
# [0.08759124087591241, 0.72]
# [0.10106382978723404, 0.66]
# [0.08783783783783784, 0.64]
# [0.10032362459546926, 0.76]
# [0.07768595041322314, 0.76]
# [0.07931034482758621, 0.62]
# [0.0812274368231047, 0.62]
# [0.09239130434782608, 0.62]
# [0.0586145648312611, 1.04]
# [0.09059233449477352, 0.86]
# [0.09844559585492228, 0.64]
# [0.08726003490401396, 0.88]
# [0.12186379928315412, 0.7]
# [0.08808290155440414, 0.86]
# [0.09391304347826086, 0.66]
# [0.09700176366843033, 0.62]
# [0.07253886010362694, 0.7]
# [0.08305084745762711, 0.62]
# [0.0749185667752443, 0.92]
# [0.08211678832116788, 0.66]
# [0.09156193895870736, 0.74]
# [0.08648648648648649, 0.68]
# [0.11973018549747048, 0.88]
# [0.07773851590106007, 0.72]
# [0.10256410256410256, 0.76]
# [0.09219858156028368, 0.56]
# [0.08963093145869948, 0.58]
# [0.0984182776801406, 0.64]
# [0.09317803660565724, 0.92]
# [0.06996587030716724, 0.76]
# [0.0781758957654723, 0.9]
# ...

# %%
picky_test(50,'Zipf_a:2_c:20_s:1000.csv')
# Out:
# [0.04085257548845471, 0.7]
# [0.04159733777038269, 0.8]
# [0.043795620437956206, 0.65]
# [0.044326241134751775, 0.75]
# [0.04054054054054054, 0.7]
# [0.03559870550161812, 0.9]
# [0.03966942148760331, 0.85]
# [0.04482758620689655, 0.5]
# [0.04332129963898917, 0.75]
# [0.03804347826086957, 0.75]
# [0.035523978685612786, 0.8]
# [0.04355400696864112, 0.8]
# [0.037996545768566495, 0.75]
# [0.03315881326352531, 0.75]
# [0.06093189964157706, 0.65]
# [0.037996545768566495, 0.8]
# [0.043478260869565216, 0.9]
# [0.037037037037037035, 0.75]
# [0.037996545768566495, 0.8]
# [0.03559322033898305, 0.75]
# [0.03908794788273615, 0.85]
# [0.041970802919708027, 0.65]
# [0.0466786355475763, 0.75]
# [0.04864864864864865, 0.55]
# [0.03541315345699832, 0.85]
# [0.045936395759717315, 0.75]
# [0.040293040293040296, 0.7]
# [0.044326241134751775, 0.65]
# [0.03866432337434095, 0.7]
# [0.04569420035149385, 0.75]
# [0.04492512479201331, 0.8]
# [0.04607508532423208, 0.7]
# [0.04560260586319218, 0.75]
# ...

# %%
picky_test(50,'Zipf_a:2_c:20_s:5000.csv')
# Out:
# [0.020670958996950185, 0.9]
# [0.015373864430468204, 0.96]
# [0.011789181692094313, 1.24]
# [0.01692573402417962, 0.94]
# [0.011728182131769576, 1.04]
# [0.018893850910340088, 1.02]
# [0.018616087109237796, 1.08]
# [0.020911895783339046, 1.01]
# [0.016666666666666666, 0.98]
# [0.014861995753715499, 1.06]
# [0.02456140350877193, 0.92]
# [0.01822477219034762, 0.96]
# [0.023312456506610995, 0.97]
# [0.020336605890603085, 0.87]
# [0.01899171270718232, 0.93]
# [0.022688209006531453, 1.01]
# [0.01949182039679777, 0.93]
# [0.02062937062937063, 0.96]
# [0.02336937565399372, 1.03]
# [0.022027972027972027, 1.2]
# [0.020306376914855716, 0.88]
# [0.016364283173247954, 1.0]
# [0.015785861358956762, 0.98]
# [0.01900739176346357, 0.87]
# [0.022268615170494086, 0.92]
# [0.02038700760193504, 0.94]
# [0.021164021164021163, 1.03]
# [0.01621808143547274, 0.98]
# [0.027719298245614036, 0.81]
# [0.018200910045502276, 0.96]
# [0.020442930153321975, 1.01]
# [0.024501225061253063, 0.99]
# ...

# %%
picky_test(100,'Zipf_a:2_c:20_s:5000.csv')
# Out:
# [0.012876990850559133, 0.84]
# [0.011530398322851153, 0.86]
# [0.01144244105409154, 1.0]
# [0.014162348877374784, 0.98]
# [0.008278716798896172, 1.06]
# [0.015458605290278255, 0.9]
# [0.012293642430628733, 0.96]
# [0.011998628728145356, 0.98]
# [0.010416666666666666, 0.94]
# [0.008846426043878274, 0.92]
# [0.011929824561403509, 0.94]
# [0.009787377657779277, 1.08]
# [0.012526096033402923, 0.94]
# [0.011921458625525946, 0.88]
# [0.010359116022099447, 1.12]
# [0.012719147473358542, 0.92]
# [0.013922728854855551, 0.82]
# [0.01013986013986014, 0.98]
# [0.013951866062085804, 0.94]
# [0.012237762237762238, 1.0]
# [0.012112575703598147, 0.9]
# [0.01031661330487371, 1.0]
# [0.016815374056280027, 0.74]
# [0.013375571981696586, 0.82]
# [0.017049408489909535, 0.84]
# [0.011748445058742226, 0.98]
# [0.010934744268077601, 0.94]
# [0.011042097998619738, 1.04]
# [0.009473684210526316, 1.06]
# [0.013650682534126707, 0.82]
# [0.011584327086882453, 1.06]
# [0.01575078753937697, 0.78]
# ...

# %%
picky_test(250,'Zipf_a:2_c:20_s:5000.csv')
# Out:
# [0.007455099966113182, 0.75]
# [0.007337526205450734, 0.8]
# [0.007281553398058253, 0.85]
# [0.007944732297063902, 0.7]
# [0.008623663332183512, 0.65]
# [0.008931638612160769, 0.8]
# [0.007727432384966632, 0.85]
# [0.0075419952005485085, 1.0]
# [0.008680555555555556, 0.75]
# [0.0074309978768577496, 0.8]
# [0.009824561403508772, 0.85]
# [0.008774890313871077, 0.75]
# [0.006958942240779402, 0.95]
# [0.00876577840112202, 0.85]
# [0.006906077348066298, 0.85]
# [0.006875214850464077, 0.85]
# [0.007309432648799165, 0.95]
# [0.0073426573426573424, 0.85]
# [0.0076735263341471925, 0.9]
# [0.01048951048951049, 0.6]
# [0.008550053437833986, 0.65]
# [0.008893632159373888, 0.7]
# [0.007206588881262869, 0.8]
# [0.008447729672650475, 0.8]
# [0.007306889352818371, 0.95]
# [0.009329647546648237, 0.75]
# [0.008818342151675485, 0.75]
# [0.006901311249137336, 0.9]
# [0.007368421052631579, 0.85]
# [0.008050402520126006, 0.8]
# [0.007155025553662692, 0.8]
# [0.010150507525376268, 0.65]
# ...

# %%
picky_test(100,'Zipf_a:2_c:20_s:10000.csv')
# Out:
# [0.010381242169321639, 1.21]
# [0.008641548565502939, 1.0]
# [0.010709269662921348, 0.92]
# [0.009860891001936961, 1.09]
# [0.008703220191470844, 1.05]
# [0.008641548565502939, 1.09]
# [0.012705404031848213, 0.92]
# [0.00916955017301038, 0.97]
# [0.00840042002100105, 1.0]
# [0.008115737473535639, 0.96]
# [0.009036144578313253, 0.92]
# [0.009163208852005533, 1.04]
# [0.008871108018785876, 0.98]
# [0.00699912510936133, 1.14]
# [0.009272467902995721, 1.02]
# [0.011333914559721011, 0.98]
# [0.011514305652477321, 0.95]
# [0.005881335409098772, 1.07]
# [0.009695290858725761, 1.1]
# [0.00860733344809778, 1.09]
# [0.006993006993006993, 1.12]
# [0.0096411355115158, 0.95]
# [0.007487375935921992, 1.13]
# [0.009565217391304347, 0.98]
# [0.008610297916307904, 1.11]
# [0.007230160096402135, 1.13]
# [0.007161572052401747, 1.08]
# [0.010405643738977073, 1.01]
# [0.011075949367088608, 1.05]
# [0.010357327809425169, 0.93]
# [0.00728500355366027, 1.05]
# [0.008616142078424477, 0.94]
# ...

# %%
picky_test(200,'Zipf_a:2_c:20_s:10000.csv')
# Out:
# [0.0046536602827993555, 0.92]
# [0.0067404078810922915, 1.0]
# [0.006671348314606741, 1.12]
# [0.005986969536890298, 0.84]
# [0.006614447345517842, 0.86]
# [0.0077773937089526445, 0.8]
# [0.007792647806200237, 0.8]
# [0.004152249134948097, 1.02]
# [0.00647532376618831, 0.82]
# [0.0061750176429075515, 0.88]
# [0.006024096385542169, 1.0]
# [0.006051175656984786, 1.06]
# [0.005392242129065925, 1.06]
# [0.005774278215223097, 0.88]
# [0.007132667617689016, 0.86]
# [0.005928509154315606, 0.92]
# [0.00837404047452896, 0.84]
# [0.006054315862307559, 0.98]
# [0.009695290858725761, 1.04]
# [0.005680840075744534, 0.92]
# [0.006293706293706294, 1.04]
# [0.005356186395286556, 0.86]
# [0.005223750652968832, 1.14]
# [0.0052173913043478265, 1.04]
# [0.008610297916307904, 1.2]
# [0.008435186779135824, 0.86]
# [0.00611353711790393, 1.0]
# [0.006525573192239859, 0.94]
# [0.0065049226441631506, 1.04]
# [0.006732263076126359, 1.02]
# [0.005152807391613362, 0.96]
# [0.005802707930367505, 0.92]
# ...

# %%
picky_test(500,'Zipf_a:2_c:20_s:10000.csv')
# Out:
# [0.00393771254698407, 0.8]
# [0.0038022813688212928, 0.85]
# [0.004740168539325843, 0.7]
# [0.004226096143687269, 0.85]
# [0.004003481288076588, 0.9]
# [0.0032837884548911167, 0.85]
# [0.0035575131289174995, 0.9]
# [0.0038062283737024223, 0.8]
# [0.0038501925096254812, 0.85]
# [0.004763585038814397, 0.6]
# [0.004961020552799433, 0.55]
# [0.003457814661134163, 0.85]
# [0.003652809184205949, 0.8]
# [0.004374453193350831, 0.8]
# [0.003744650499286733, 0.85]
# [0.0036617262423714035, 0.85]
# [0.00366364270760642, 0.95]
# [0.0041515308770108976, 0.7]
# [0.0034626038781163434, 0.85]
# [0.003959373386124979, 0.85]
# [0.0038461538461538464, 0.85]
# [0.004463488662738797, 0.7]
# [0.00383075047884381, 0.85]
# [0.0038260869565217392, 0.8]
# [0.003960737041501636, 0.8]
# [0.0036150800482010674, 0.85]
# [0.004366812227074236, 0.8]
# [0.004409171075837742, 0.85]
# [0.004395218002812939, 0.7]
# [0.003797686863455895, 0.8]
# [0.0042643923240938165, 0.8]
# [0.0038684719535783366, 0.85]
# ...

# %%
picky_test(10,'Zipf_a:2_c:50_s:1000.csv')
# Out:
# [0.6902086677367576, 0.03]
# [0.7491694352159468, 0.08]
# [0.8036006546644845, 0.02]
# [0.8497316636851521, 0.03]
# [0.7876254180602007, 0.03]
# [0.8492201039861352, 0.01]
# [0.7596638655462185, 0.02]
# [0.7696335078534031, 0.02]
# [0.7914614121510674, 0.02]
# [0.813953488372093, 0.02]
# [0.8542713567839196, 0.02]
# [0.5574614065180102, 0.08]
# [0.8206896551724138, 0.01]
# [0.48947368421052634, 0.13]
# [0.7847457627118644, 0.0]
# [0.6418685121107266, 0.05]
# [0.8301886792452831, 0.0]
# [0.9010238907849829, 0.0]
# [0.7875210792580101, 0.04]
# [0.8787878787878788, 0.01]
# [0.8478632478632478, 0.01]
# [0.8573913043478261, 0.0]
# [0.7600700525394045, 0.05]
# [0.8257956448911222, 0.02]
# [0.7610169491525424, 0.05]
# [0.8684654300168634, 0.0]
# [0.8456140350877193, 0.01]
# [0.7487520798668885, 0.03]
# [0.802013422818792, 0.01]
# [0.8123924268502581, 0.03]
# [0.6717428087986463, 0.05]
# [0.7346938775510204, 0.03]
# [0.8404074702886248, 0.0]
# [0.8130217028380634, 0.01]
# ...

# %%
picky_test(20,'Zipf_a:2_c:50_s:1000.csv')
# Out:
# [0.1043338683788122, 0.84]
# [0.13122923588039867, 0.84]
# [0.11292962356792144, 0.82]
# [0.1806797853309481, 0.42]
# [0.13377926421404682, 0.62]
# [0.12131715771230503, 0.68]
# [0.14285714285714285, 0.92]
# [0.1099476439790576, 0.68]
# [0.1297208538587849, 0.6]
# [0.13178294573643412, 0.74]
# [0.12060301507537688, 0.84]
# [0.14922813036020582, 0.72]
# [0.11896551724137931, 0.82]
# [0.09649122807017543, 0.72]
# [0.1288135593220339, 0.7]
# [0.1245674740484429, 0.72]
# [0.10120068610634649, 0.7]
# [0.19795221843003413, 0.36]
# [0.11467116357504216, 0.78]
# [0.14983164983164984, 0.64]
# [0.147008547008547, 0.8]
# [0.12, 0.82]
# [0.10507880910683012, 0.72]
# [0.10385259631490787, 0.76]
# [0.12542372881355932, 0.76]
# [0.1315345699831366, 0.62]
# [0.11228070175438597, 0.64]
# [0.10149750415973377, 0.9]
# [0.13590604026845637, 0.68]
# [0.12220309810671257, 0.72]
# [0.08460236886632826, 0.94]
# [0.11394557823129252, 0.68]
# [0.12393887945670629, 0.84]
# [0.1352253756260434, 0.82]
# ...

# %%
picky_test(50,'Zipf_a:2_c:50_s:1000.csv')
# Out:
# [0.060995184590690206, 0.95]
# [0.0681063122923588, 1.05]
# [0.062193126022913256, 0.85]
# [0.07513416815742398, 0.65]
# [0.056856187290969896, 0.9]
# [0.06932409012131716, 0.75]
# [0.06386554621848739, 0.95]
# [0.0506108202443281, 0.85]
# [0.05090311986863711, 0.95]
# [0.05736434108527132, 1.0]
# [0.07202680067001675, 0.7]
# [0.07032590051457976, 0.95]
# [0.05862068965517241, 0.75]
# [0.06315789473684211, 0.65]
# [0.059322033898305086, 0.7]
# [0.058823529411764705, 0.85]
# [0.0548885077186964, 0.85]
# [0.07337883959044368, 0.85]
# [0.07082630691399663, 0.9]
# [0.0723905723905724, 0.75]
# [0.05982905982905983, 1.0]
# [0.0782608695652174, 0.75]
# [0.07180385288966724, 0.8]
# [0.05360134003350084, 0.95]
# [0.06779661016949153, 1.0]
# [0.06408094435075885, 0.85]
# [0.05789473684210526, 0.85]
# [0.0632279534109817, 0.7]
# [0.06879194630872483, 0.85]
# [0.058519793459552494, 0.9]
# [0.05245346869712352, 0.95]
# [0.05272108843537415, 0.85]
# [0.06112054329371817, 1.0]
# ...

# %%
picky_test(50,'Zipf_a:2_c:50_s:5000.csv')
# Out:
# [0.028855721393034824, 1.27]
# [0.04222520107238606, 0.95]
# [0.036104670420669095, 1.16]
# [0.0409670920080591, 1.1]
# [0.03434343434343434, 1.09]
# [0.03171390013495277, 1.26]
# [0.03370407819346141, 1.06]
# [0.027392627663172135, 1.3]
# [0.043243243243243246, 1.04]
# [0.03230240549828179, 0.99]
# [0.035245335176226675, 1.06]
# [0.03421142661648991, 1.08]
# [0.03241812768772742, 1.16]
# [0.031452991452991456, 1.07]
# [0.03823427181091415, 0.92]
# [0.035906040268456375, 0.99]
# [0.03702468312208139, 1.09]
# [0.03329935440027183, 1.09]
# [0.039235412474849095, 1.2]
# [0.035249828884325804, 1.19]
# [0.03681592039800995, 1.07]
# [0.03544390915347557, 1.01]
# [0.033824514400535834, 1.28]
# [0.035223079503522305, 1.27]
# [0.03468208092485549, 1.12]
# [0.03843560350640594, 1.05]
# [0.03607896528250511, 1.27]
# [0.035909712722298225, 1.07]
# [0.03447110510307536, 1.13]
# [0.03638218293097586, 1.01]
# [0.030560271646859084, 1.11]
# [0.02851182197496523, 1.14]
# [0.03241978609625668, 1.21]
# ...

# %%
picky_test(100,'Zipf_a:2_c:50_s:5000.csv')
# Out:
# [0.024543946932006632, 1.14]
# [0.02546916890080429, 1.16]
# [0.02848625372639947, 0.9]
# [0.018132975151108125, 1.36]
# [0.0265993265993266, 1.06]
# [0.022941970310391364, 1.18]
# [0.021907650825749917, 1.36]
# [0.019952654717619207, 1.14]
# [0.02364864864864865, 1.24]
# [0.021993127147766325, 0.96]
# [0.025224602626123013, 1.04]
# [0.021553198768388643, 1.06]
# [0.01885544161429044, 1.2]
# [0.020854700854700856, 1.02]
# [0.023288147375738616, 1.08]
# [0.020134228187919462, 1.14]
# [0.021681120747164776, 1.28]
# [0.021406727828746176, 1.26]
# [0.022803487592219986, 1.3]
# [0.020191649555099247, 1.14]
# [0.028192371475953566, 1.08]
# [0.021679284239504472, 1.1]
# [0.026121902210314803, 1.16]
# [0.020462931902046292, 1.26]
# [0.024821489289357363, 1.12]
# [0.024612272420768713, 1.14]
# [0.02654867256637168, 1.14]
# [0.02051983584131327, 1.12]
# [0.022304832713754646, 1.18]
# [0.025161509690581434, 1.12]
# [0.022410865874363327, 1.12]
# [0.022253129346314324, 1.12]
# ...

# %%
picky_test(250,'Zipf_a:2_c:50_s:5000.csv')
# Out:
# [0.01691542288557214, 0.95]
# [0.018431635388739945, 1.4]
# [0.019542894998343822, 0.8]
# [0.021490933512424447, 0.65]
# [0.016835016835016835, 1.05]
# [0.0199055330634278, 0.8]
# [0.016852039096730706, 0.9]
# [0.01657084883327697, 1.0]
# [0.01756756756756757, 1.2]
# [0.018213058419243987, 0.85]
# [0.017277125086385625, 0.8]
# [0.016079370509750255, 0.85]
# [0.01587826662256037, 0.9]
# [0.016068376068376067, 0.95]
# [0.016336461591936045, 0.95]
# [0.016778523489932886, 0.9]
# [0.016344229486324215, 1.1]
# [0.01766904519198097, 0.8]
# [0.02012072434607646, 0.85]
# [0.018480492813141684, 0.85]
# [0.01658374792703151, 1.25]
# [0.017205781142463867, 0.9]
# [0.016744809109176157, 1.05]
# [0.01677289500167729, 1.1]
# [0.018361101666099965, 0.85]
# [0.01753202966958867, 1.0]
# [0.018379850238257316, 1.05]
# [0.016757865937072503, 0.85]
# [0.017573504562352148, 1.05]
# [0.01972118327099626, 0.7]
# [0.01731748726655348, 0.9]
# [0.018776077885952713, 0.85]
# [0.01771390374331551, 1.1]
# ...

# %%
picky_test(100,'Zipf_a:2_c:50_s:10000.csv')
# Out:
# [0.017845003399048265, 1.24]
# [0.01647175094712568, 1.38]
# [0.014755197853789403, 1.12]
# [0.02047723811135556, 1.07]
# [0.016382480775660315, 1.3]
# [0.016980497646267655, 1.18]
# [0.01682935038707506, 1.45]
# [0.017049408489909535, 1.18]
# [0.01839352008099899, 1.19]
# [0.01728813559322034, 1.08]
# [0.017985611510791366, 1.26]
# [0.018060998466519, 1.31]
# [0.020531807472231572, 1.21]
# [0.01577073088010853, 1.18]
# [0.016629135631387494, 1.23]
# [0.018883830719946045, 1.24]
# [0.016426416359369762, 1.18]
# [0.016104163097481583, 1.22]
# [0.01833616298811545, 1.16]
# [0.01690285128905583, 1.2]
# [0.01366627298802092, 1.21]
# [0.019031719532554257, 1.26]
# [0.02030800473853444, 1.13]
# [0.013306383695469092, 1.42]
# [0.020248426067721627, 1.2]
# [0.016492763379333558, 1.2]
# [0.01817264008076729, 1.15]
# [0.015730337078651686, 1.27]
# [0.018921161825726143, 1.3]
# [0.01854714064914992, 1.27]
# [0.017136266271214368, 1.21]
# [0.016511007338225483, 1.17]
# ...

# %%
picky_test(200,'Zipf_a:2_c:50_s:10000.csv')
# Out:
# [0.012066621346023114, 1.08]
# [0.011200790644045461, 1.5]
# [0.012575452716297788, 1.08]
# [0.011507869351836182, 1.2]
# [0.011200267469073889, 1.26]
# [0.012273032952252858, 1.24]
# [0.012958599798047796, 1.18]
# [0.012352122477383438, 1.02]
# [0.012149848126898413, 1.1]
# [0.01440677966101695, 0.9]
# [0.013360739979445015, 1.06]
# [0.011415914125063894, 1.18]
# [0.0139683608212723, 1.12]
# [0.013735797863320333, 1.1]
# [0.011778971072232807, 1.26]
# [0.012982633619962906, 1.26]
# [0.011062688568555145, 1.2]
# [0.010793215692992976, 1.24]
# [0.014431239388794566, 0.88]
# [0.012292982755676968, 1.06]
# [0.011979078791968956, 1.18]
# [0.01018363939899833, 1.18]
# [0.012184802843120663, 1.12]
# [0.013306383695469092, 1.04]
# [0.011570529181555215, 1.2]
# [0.012285425782564793, 1.06]
# [0.011946828201245163, 1.2]
# [0.011754537597234226, 1.18]
# [0.015435684647302904, 0.98]
# [0.013910355486862442, 1.22]
# [0.01054539462843961, 1.24]
# [0.011674449633088725, 1.1]
# ...

# %%
picky_test(500,'Zipf_a:2_c:50_s:10000.csv')
# Out:
# [0.010367097212780422, 0.9]
# [0.01021248558721792, 0.75]
# [0.009221998658618377, 1.0]
# [0.009815535623624978, 0.85]
# [0.0091942494149114, 1.2]
# [0.008910558170813718, 1.05]
# [0.009761023224503534, 0.95]
# [0.009394572025052192, 1.05]
# [0.009956125548430644, 0.75]
# [0.010677966101694915, 0.75]
# [0.009421034600890716, 0.95]
# [0.009371272789231555, 1.0]
# [0.010097610232245036, 0.95]
# [0.009665931829743938, 0.85]
# [0.01021998960679023, 0.85]
# [0.009610520991401113, 1.05]
# [0.009051290646999664, 1.0]
# [0.009936611272914168, 0.85]
# [0.01035653650254669, 0.85]
# [0.009902680553184225, 0.9]
# [0.009448287497891008, 0.95]
# [0.009348914858096828, 0.9]
# [0.008969368759519378, 1.05]
# [0.008590197069226882, 1.05]
# [0.008848051727071635, 0.9]
# [0.008751262201279031, 1.0]
# [0.009927645970048797, 0.85]
# [0.00864304235090752, 0.95]
# [0.009460580912863071, 0.95]
# [0.009101837540786537, 0.9]
# [0.008238589553468446, 1.25]
# [0.009839893262174782, 0.85]
# ...
